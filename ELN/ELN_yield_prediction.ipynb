# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
from scipy.stats import pearsonr, spearmanr

# %%
df_cat = pd.read_csv('./ELN_reaction_representation.csv')
# Out:
# /tmp/ipykernel_2417598/614745552.py:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cat = pd.read_csv('./ELN_reaction_representation.csv')

# %%
y = df_cat['yield']
y
# Out:
# 0      65.39
# 1      57.47
# 2      65.43
# 3      75.07
# 4      46.32
#        ...
# 744    42.82
# 745    42.75
# 746    46.13
# 747    24.34
# 748    29.00
# Name: yield, Length: 749, dtype: float64

# %% [markdown]
# # ELN descriptors

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
    if 'ReactSeq_all' in i:
        continue
    if 'AP3_256' in i:
        continue
    if 'Drfp' in i:
        continue
    if 'rxnfp_pretrained' in i:
        continue
    if 'rxnfp_ft_10k' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'halide_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'amine_MaxEStateIndex',
#  'amine_MinEStateIndex',
#  'amine_MaxAbsEStateIndex',
#  'amine_MinAbsEStateIndex',
#  'amine_qed',
#  'amine_MolWt',
#  'amine_HeavyAtomMolWt',
#  'amine_ExactMolWt',
#  'amine_NumValenceElectrons',
#  'amine_MaxPartialCharge',
#  'amine_MinPartialCharge',
#  'amine_MaxAbsPartialCharge',
#  'amine_MinAbsPartialCharge',
#  'amine_FpDensityMorgan1',
#  'amine_FpDensityMorgan2',
#  'amine_FpDensityMorgan3',
#  'amine_BCUT2D_MWHI',
#  'amine_BCUT2D_MWLOW',
#  'amine_BCUT2D_CHGHI',
#  'amine_BCUT2D_CHGLO',
#  'amine_BCUT2D_LOGPHI',
#  'amine_BCUT2D_LOGPLOW',
#  'amine_BCUT2D_MRHI',
#  'amine_BCUT2D_MRLOW',
#  'amine_BalabanJ',
#  'amine_BertzCT',
#  'amine_Chi0',
#  'amine_Chi0n',
#  'amine_Chi0v',
#  'amine_Chi1',
#  'amine_Chi1n',
#  'amine_Chi1v',
#  'amine_Chi2n',
#  'amine_Chi2v',
#  'amine_Chi3n',
#  'amine_Chi3v',
#  'amine_Chi4n',
#  'amine_Chi4v',
#  'amine_HallKierAlpha',
#  'amine_Ipc',
#  'amine_Kappa1',
#  'amine_Kappa2',
#  'amine_Kappa3',
#  'amine_LabuteASA',
#  'amine_PEOE_VSA1',
#  'amine_PEOE_VSA10',
#  'amine_PEOE_VSA11',
#  'amine_PEOE_VSA12',
#  'amine_PEOE_VSA13',
#  'amine_PEOE_VSA14',
#  'amine_PEOE_VSA2',
#  'amine_PEOE_VSA3',
#  'amine_PEOE_VSA4',
#  'amine_PEOE_VSA5',
#  'amine_PEOE_VSA6',
#  'amine_PEOE_VSA7',
#  'amine_PEOE_VSA8',
#  'amine_PEOE_VSA9',
#  'amine_SMR_VSA1',
#  'amine_SMR_VSA10',
#  'amine_SMR_VSA2',
#  'amine_SMR_VSA3',
#  'amine_SMR_VSA4',
#  'amine_SMR_VSA5',
#  'amine_SMR_VSA6',
#  'amine_SMR_VSA7',
#  'amine_SMR_VSA9',
#  'amine_SlogP_VSA1',
#  'amine_SlogP_VSA10',
#  'amine_SlogP_VSA11',
#  'amine_SlogP_VSA12',
#  'amine_SlogP_VSA2',
#  'amine_SlogP_VSA3',
#  'amine_SlogP_VSA4',
#  'amine_SlogP_VSA5',
#  'amine_SlogP_VSA6',
#  'amine_SlogP_VSA7',
#  'amine_SlogP_VSA8',
#  'amine_TPSA',
#  'amine_EState_VSA1',
#  'amine_EState_VSA10',
#  'amine_EState_VSA11',
#  'amine_EState_VSA2',
#  'amine_EState_VSA3',
#  'amine_EState_VSA4',
#  'amine_EState_VSA5',
#  'amine_EState_VSA6',
#  'amine_EState_VSA8',
#  'amine_EState_VSA9',
#  'amine_VSA_EState1',
#  'amine_VSA_EState10',
#  'amine_VSA_EState2',
#  'amine_VSA_EState3',
#  'amine_VSA_EState4',
#  'amine_VSA_EState5',
#  'amine_VSA_EState6',
#  'amine_VSA_EState7',
#  'amine_VSA_EState8',
#  'amine_VSA_EState9',
#  'amine_FractionCSP3',
#  'amine_HeavyAtomCount',
#  'amine_NHOHCount',
#  'amine_NOCount',
#  'amine_NumAliphaticCarbocycles',
#  'amine_NumAliphaticHeterocycles',
#  'amine_NumAliphaticRings',
#  'amine_NumAromaticCarbocycles',
#  'amine_NumAromaticHeterocycles',
#  'amine_NumAromaticRings',
#  'amine_NumHAcceptors',
#  'amine_NumHDonors',
#  'amine_NumHeteroatoms',
#  'amine_NumRotatableBonds',
#  'amine_NumSaturatedCarbocycles',
#  'amine_NumSaturatedHeterocycles',
#  'amine_NumSaturatedRings',
#  'amine_RingCount',
#  'amine_MolLogP',
#  'amine_MolMR',
#  'amine_fr_Al_OH',
#  'amine_fr_ArN',
#  'amine_fr_Ar_N',
#  'amine_fr_Ar_NH',
#  'amine_fr_C_O',
#  'amine_fr_C_O_noCOO',
#  'amine_fr_HOCCN',
#  'amine_fr_Imine',
#  'amine_fr_NH0',
#  'amine_fr_NH1',
#  'amine_fr_NH2',
#  'amine_fr_N_O',
#  'amine_fr_Ndealkylation1',
#  'amine_fr_Ndealkylation2',
#  'amine_fr_Nhpyrrole',
#  'amine_fr_aldehyde',
#  'amine_fr_alkyl_carbamate',
#  'amine_fr_alkyl_halide',
#  'amine_fr_allylic_oxid',
#  'amine_fr_amide',
#  'amine_fr_aniline',
#  'amine_fr_aryl_methyl',
#  'amine_fr_benzene',
#  'amine_fr_bicyclic',
#  'amine_fr_ester',
#  'amine_fr_ether',
#  'amine_fr_halogen',
#  'amine_fr_imidazole',
#  'amine_fr_ketone',
#  'amine_fr_ketone_Topliss',
#  'amine_fr_lactone',
#  'amine_fr_methoxy',
#  'amine_fr_morpholine',
#  'amine_fr_nitrile',
#  'amine_fr_nitro',
#  'amine_fr_nitro_arom',
#  'amine_fr_oxazole',
#  'amine_fr_para_hydroxylation',
#  'amine_fr_piperdine',
#  'amine_fr_piperzine',
#  'amine_fr_priamide',
#  'amine_fr_pyridine',
#  'amine_fr_sulfonamd',
#  'amine_fr_sulfone',
#  'amine_fr_thiazole',
#  'amine_fr_urea',
#  'amine_molecular_weight',
#  'amine_molecular_volume',
#  'amine_surface_area',
#  'amine_ovality',
#  'amine_hardness',
#  'amine_dipole_moment',
#  'amine_electronegativity',
#  'amine_E_HOMO',
#  'amine_E_LOMO',
#  'amine_.N1_electrostatic_charge',
#  'amine_.N1_NMR_shift',
#  'amine_.C1_electrostatic_charge',
#  'amine_.C1_NMR_shift',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'product_MaxEStateIndex',
#  'product_MinEStateIndex',
#  'product_MaxAbsEStateIndex',
#  'product_MinAbsEStateIndex',
#  'product_qed',
#  'product_MolWt',
#  'product_HeavyAtomMolWt',
#  'product_ExactMolWt',
#  'product_NumValenceElectrons',
#  'product_MaxPartialCharge',
#  'product_MinPartialCharge',
#  'product_MaxAbsPartialCharge',
#  'product_MinAbsPartialCharge',
#  'product_FpDensityMorgan1',
#  'product_FpDensityMorgan2',
#  'product_FpDensityMorgan3',
#  'product_BCUT2D_MWHI',
#  'product_BCUT2D_MWLOW',
#  'product_BCUT2D_CHGHI',
#  'product_BCUT2D_CHGLO',
#  'product_BCUT2D_LOGPHI',
#  'product_BCUT2D_LOGPLOW',
#  'product_BCUT2D_MRHI',
#  'product_BCUT2D_MRLOW',
#  'product_BalabanJ',
#  'product_BertzCT',
#  'product_Chi0',
#  'product_Chi0n',
#  'product_Chi0v',
#  'product_Chi1',
#  'product_Chi1n',
#  'product_Chi1v',
#  'product_Chi2n',
#  'product_Chi2v',
#  'product_Chi3n',
#  'product_Chi3v',
#  'product_Chi4n',
#  'product_Chi4v',
#  'product_HallKierAlpha',
#  'product_Ipc',
#  'product_Kappa1',
#  'product_Kappa2',
#  'product_Kappa3',
#  'product_LabuteASA',
#  'product_PEOE_VSA1',
#  'product_PEOE_VSA10',
#  'product_PEOE_VSA11',
#  'product_PEOE_VSA12',
#  'product_PEOE_VSA13',
#  'product_PEOE_VSA14',
#  'product_PEOE_VSA2',
#  'product_PEOE_VSA3',
#  'product_PEOE_VSA4',
#  'product_PEOE_VSA5',
#  'product_PEOE_VSA6',
#  'product_PEOE_VSA7',
#  'product_PEOE_VSA8',
#  'product_PEOE_VSA9',
#  'product_SMR_VSA1',
#  'product_SMR_VSA10',
#  'product_SMR_VSA2',
#  'product_SMR_VSA3',
#  'product_SMR_VSA4',
#  'product_SMR_VSA5',
#  'product_SMR_VSA6',
#  'product_SMR_VSA7',
#  'product_SMR_VSA9',
#  'product_SlogP_VSA1',
#  'product_SlogP_VSA10',
#  'product_SlogP_VSA11',
#  'product_SlogP_VSA12',
#  'product_SlogP_VSA2',
#  'product_SlogP_VSA3',
#  'product_SlogP_VSA4',
#  'product_SlogP_VSA5',
#  'product_SlogP_VSA6',
#  'product_SlogP_VSA7',
#  'product_SlogP_VSA8',
#  'product_TPSA',
#  'product_EState_VSA1',
#  'product_EState_VSA10',
#  'product_EState_VSA11',
#  'product_EState_VSA2',
#  'product_EState_VSA3',
#  'product_EState_VSA4',
#  'product_EState_VSA5',
#  'product_EState_VSA6',
#  'product_EState_VSA8',
#  'product_EState_VSA9',
#  'product_VSA_EState1',
#  'product_VSA_EState10',
#  'product_VSA_EState2',
#  'product_VSA_EState3',
#  'product_VSA_EState4',
#  'product_VSA_EState5',
#  'product_VSA_EState6',
#  'product_VSA_EState7',
#  'product_VSA_EState8',
#  'product_VSA_EState9',
#  'product_FractionCSP3',
#  'product_HeavyAtomCount',
#  'product_NHOHCount',
#  'product_NOCount',
#  'product_NumAliphaticCarbocycles',
#  'product_NumAliphaticHeterocycles',
#  'product_NumAliphaticRings',
#  'product_NumAromaticCarbocycles',
#  'product_NumAromaticHeterocycles',
#  'product_NumAromaticRings',
#  'product_NumHAcceptors',
#  'product_NumHDonors',
#  'product_NumHeteroatoms',
#  'product_NumRotatableBonds',
#  'product_NumSaturatedCarbocycles',
#  'product_NumSaturatedHeterocycles',
#  'product_NumSaturatedRings',
#  'product_RingCount',
#  'product_MolLogP',
#  'product_MolMR',
#  'product_fr_Al_COO',
#  'product_fr_Al_OH',
#  'product_fr_ArN',
#  'product_fr_Ar_COO',
#  'product_fr_Ar_N',
#  'product_fr_Ar_NH',
#  'product_fr_Ar_OH',
#  'product_fr_COO',
#  'product_fr_COO2',
#  'product_fr_C_O',
#  'product_fr_C_O_noCOO',
#  'product_fr_HOCCN',
#  'product_fr_Imine',
#  'product_fr_NH0',
#  'product_fr_NH1',
#  'product_fr_NH2',
#  'product_fr_N_O',
#  'product_fr_Ndealkylation1',
#  'product_fr_Ndealkylation2',
#  'product_fr_Nhpyrrole',
#  'product_fr_aldehyde',
#  'product_fr_alkyl_carbamate',
#  'product_fr_alkyl_halide',
#  'product_fr_allylic_oxid',
#  'product_fr_amide',
#  'product_fr_amidine',
#  'product_fr_aniline',
#  'product_fr_aryl_methyl',
#  'product_fr_benzene',
#  'product_fr_bicyclic',
#  'product_fr_ester',
#  'product_fr_ether',
#  'product_fr_furan',
#  'product_fr_halogen',
#  'product_fr_imidazole',
#  'product_fr_ketone',
#  'product_fr_ketone_Topliss',
#  'product_fr_lactone',
#  'product_fr_methoxy',
#  'product_fr_morpholine',
#  'product_fr_nitrile',
#  'product_fr_nitro',
#  'product_fr_nitro_arom',
#  'product_fr_oxazole',
#  'product_fr_para_hydroxylation',
#  'product_fr_phenol',
#  'product_fr_phenol_noOrthoHbond',
#  'product_fr_piperdine',
#  'product_fr_piperzine',
#  'product_fr_priamide',
#  'product_fr_pyridine',
#  'product_fr_sulfonamd',
#  'product_fr_sulfone',
#  'product_fr_thiazole',
#  'product_fr_thiophene',
#  'product_fr_urea',
#  'halide_MaxEStateIndex',
#  'halide_MinEStateIndex',
#  'halide_MaxAbsEStateIndex',
#  'halide_MinAbsEStateIndex',
#  'halide_qed',
#  'halide_MolWt',
#  'halide_HeavyAtomMolWt',
#  'halide_ExactMolWt',
#  'halide_NumValenceElectrons',
#  'halide_MaxPartialCharge',
#  'halide_MinPartialCharge',
#  'halide_MaxAbsPartialCharge',
#  'halide_MinAbsPartialCharge',
#  'halide_FpDensityMorgan1',
#  'halide_FpDensityMorgan2',
#  'halide_FpDensityMorgan3',
#  'halide_BCUT2D_MWHI',
#  'halide_BCUT2D_MWLOW',
#  'halide_BCUT2D_CHGHI',
#  'halide_BCUT2D_CHGLO',
#  'halide_BCUT2D_LOGPHI',
#  'halide_BCUT2D_LOGPLOW',
#  'halide_BCUT2D_MRHI',
#  'halide_BCUT2D_MRLOW',
#  'halide_BalabanJ',
#  'halide_BertzCT',
#  'halide_Chi0',
#  'halide_Chi0n',
#  'halide_Chi0v',
#  'halide_Chi1',
#  'halide_Chi1n',
#  'halide_Chi1v',
#  'halide_Chi2n',
#  'halide_Chi2v',
#  'halide_Chi3n',
#  'halide_Chi3v',
#  'halide_Chi4n',
#  'halide_Chi4v',
#  'halide_HallKierAlpha',
#  'halide_Ipc',
#  'halide_Kappa1',
#  'halide_Kappa2',
#  'halide_Kappa3',
#  'halide_LabuteASA',
#  'halide_PEOE_VSA1',
#  'halide_PEOE_VSA10',
#  'halide_PEOE_VSA11',
#  'halide_PEOE_VSA12',
#  'halide_PEOE_VSA13',
#  'halide_PEOE_VSA14',
#  'halide_PEOE_VSA2',
#  'halide_PEOE_VSA3',
#  'halide_PEOE_VSA4',
#  'halide_PEOE_VSA5',
#  'halide_PEOE_VSA6',
#  'halide_PEOE_VSA7',
#  'halide_PEOE_VSA8',
#  'halide_PEOE_VSA9',
#  'halide_SMR_VSA1',
#  'halide_SMR_VSA10',
#  'halide_SMR_VSA2',
#  'halide_SMR_VSA3',
#  'halide_SMR_VSA4',
#  'halide_SMR_VSA5',
#  'halide_SMR_VSA6',
#  'halide_SMR_VSA7',
#  'halide_SMR_VSA9',
#  'halide_SlogP_VSA1',
#  'halide_SlogP_VSA10',
#  'halide_SlogP_VSA11',
#  'halide_SlogP_VSA12',
#  'halide_SlogP_VSA2',
#  'halide_SlogP_VSA3',
#  'halide_SlogP_VSA4',
#  'halide_SlogP_VSA5',
#  'halide_SlogP_VSA6',
#  'halide_SlogP_VSA7',
#  'halide_SlogP_VSA8',
#  'halide_TPSA',
#  'halide_EState_VSA1',
#  'halide_EState_VSA10',
#  'halide_EState_VSA11',
#  'halide_EState_VSA2',
#  'halide_EState_VSA3',
#  'halide_EState_VSA4',
#  'halide_EState_VSA5',
#  'halide_EState_VSA6',
#  'halide_EState_VSA7',
#  'halide_EState_VSA8',
#  'halide_EState_VSA9',
#  'halide_VSA_EState1',
#  'halide_VSA_EState10',
#  'halide_VSA_EState2',
#  'halide_VSA_EState3',
#  'halide_VSA_EState4',
#  'halide_VSA_EState5',
#  'halide_VSA_EState6',
#  'halide_VSA_EState7',
#  'halide_VSA_EState8',
#  'halide_VSA_EState9',
#  'halide_FractionCSP3',
#  'halide_HeavyAtomCount',
#  'halide_NHOHCount',
#  'halide_NOCount',
#  'halide_NumAliphaticCarbocycles',
#  'halide_NumAliphaticHeterocycles',
#  'halide_NumAliphaticRings',
#  'halide_NumAromaticCarbocycles',
#  'halide_NumAromaticHeterocycles',
#  'halide_NumAromaticRings',
#  'halide_NumHAcceptors',
#  'halide_NumHDonors',
#  'halide_NumHeteroatoms',
#  'halide_NumRotatableBonds',
#  'halide_NumSaturatedCarbocycles',
#  'halide_NumSaturatedHeterocycles',
#  'halide_NumSaturatedRings',
#  'halide_RingCount',
#  'halide_MolLogP',
#  'halide_MolMR',
#  'halide_fr_Al_COO',
#  'halide_fr_Al_OH',
#  'halide_fr_ArN',
#  'halide_fr_Ar_COO',
#  'halide_fr_Ar_N',
#  'halide_fr_Ar_NH',
#  'halide_fr_Ar_OH',
#  'halide_fr_COO',
#  'halide_fr_COO2',
#  'halide_fr_C_O',
#  'halide_fr_C_O_noCOO',
#  'halide_fr_HOCCN',
#  'halide_fr_Imine',
#  'halide_fr_NH0',
#  'halide_fr_NH1',
#  'halide_fr_NH2',
#  'halide_fr_N_O',
#  'halide_fr_Ndealkylation1',
#  'halide_fr_Ndealkylation2',
#  'halide_fr_Nhpyrrole',
#  'halide_fr_aldehyde',
#  'halide_fr_alkyl_carbamate',
#  'halide_fr_alkyl_halide',
#  'halide_fr_amide',
#  'halide_fr_amidine',
#  'halide_fr_aniline',
#  'halide_fr_aryl_methyl',
#  'halide_fr_benzene',
#  'halide_fr_bicyclic',
#  'halide_fr_ester',
#  'halide_fr_ether',
#  'halide_fr_furan',
#  'halide_fr_halogen',
#  'halide_fr_imidazole',
#  'halide_fr_ketone',
#  'halide_fr_ketone_Topliss',
#  'halide_fr_lactone',
#  'halide_fr_methoxy',
#  'halide_fr_morpholine',
#  'halide_fr_nitrile',
#  'halide_fr_nitro',
#  'halide_fr_nitro_arom',
#  'halide_fr_para_hydroxylation',
#  'halide_fr_phenol',
#  'halide_fr_phenol_noOrthoHbond',
#  'halide_fr_piperdine',
#  'halide_fr_piperzine',
#  'halide_fr_priamide',
#  'halide_fr_pyridine',
#  'halide_fr_sulfonamd',
#  'halide_fr_sulfone',
#  'halide_fr_thiazole',
#  'halide_fr_thiophene',
#  'halide_molecular_weight',
#  'halide_molecular_volume',
#  'halide_surface_area',
#  'halide_ovality',
#  'halide_hardness',
#  'halide_dipole_moment',
#  'halide_electronegativity',
#  'halide_E_HOMO',
#  'halide_E_LOMO',
#  'halide_V0_frequency',
#  'halide_V0_intensity',
#  'halide_V1_frequency',
#  'halide_V1_intensity',
#  'halide_V2_frequency',
#  'halide_V2_intensity',
#  'halide_.C1_electrostatic_charge',
#  'halide_.C1_NMR_shift',
#  'halide_.C2_electrostatic_charge',
#  'halide_.C2_NMR_shift',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift']

# %%
len(feature_col)
# Out:
# 907

# %%
X = df_cat[feature_col]

# %%
# Lists to store the results
rmse_list = []
r2_list = []
pearson_corr_list = []
spearman_corr_list = []

for seed in range(30):
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    # Model initialization and training
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    # Predictions
    y_pred = model.predict(X_test)
    
    # Metrics calculation
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    pearson_corr, _ = pearsonr(y_test, y_pred)
    spearman_corr, _ = spearmanr(y_test, y_pred)
    
    # Store results
    rmse_list.append(rmse)
    r2_list.append(r2)
    pearson_corr_list.append(pearson_corr)
    spearman_corr_list.append(spearman_corr)
    
    print(f'Seed {seed} -> RMSE: {rmse:.4f}, R²: {r2:.4f}, Pearson: {pearson_corr:.4f}, Spearman: {spearman_corr:.4f}')

# Averages and standard deviations
average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)
average_pearson = np.mean(pearson_corr_list)
average_spearman = np.mean(spearman_corr_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)
std_pearson = np.std(pearson_corr_list)
std_spearman = np.std(spearman_corr_list)

# Final results
print(f'\nR²_mean: {average_r2:.4f}')
print(f'R²_sd: {std_r2:.4f}')
print(f'RMSE_mean: {average_rmse:.4f}')
print(f'RMSE_sd: {std_rmse:.4f}')
print(f'Pearson_corr_mean: {average_pearson:.4f}')
print(f'Pearson_corr_sd: {std_pearson:.4f}')
print(f'Spearman_corr_mean: {average_spearman:.4f}')
print(f'Spearman_corr_sd: {std_spearman:.4f}')
# Out:
# Seed 0 -> RMSE: 24.1364, R²: 0.3254, Pearson: 0.5894, Spearman: 0.5811
# Seed 1 -> RMSE: 23.7420, R²: 0.3074, Pearson: 0.5581, Spearman: 0.5527
# Seed 2 -> RMSE: 26.3217, R²: 0.2200, Pearson: 0.4864, Spearman: 0.4696
# Seed 3 -> RMSE: 23.3958, R²: 0.3355, Pearson: 0.5808, Spearman: 0.5664
# Seed 4 -> RMSE: 27.6426, R²: 0.2229, Pearson: 0.4851, Spearman: 0.4959
# Seed 5 -> RMSE: 24.3982, R²: 0.2738, Pearson: 0.5631, Spearman: 0.5541
# Seed 6 -> RMSE: 24.3596, R²: 0.2623, Pearson: 0.5248, Spearman: 0.5027
# Seed 7 -> RMSE: 24.1183, R²: 0.2736, Pearson: 0.5306, Spearman: 0.5311
# Seed 8 -> RMSE: 24.3173, R²: 0.2512, Pearson: 0.5153, Spearman: 0.5078
# Seed 9 -> RMSE: 24.2397, R²: 0.2511, Pearson: 0.5253, Spearman: 0.5181
# Seed 10 -> RMSE: 25.5533, R²: 0.2165, Pearson: 0.5025, Spearman: 0.4954
# Seed 11 -> RMSE: 26.7604, R²: 0.2208, Pearson: 0.4822, Spearman: 0.4680
# Seed 12 -> RMSE: 25.5443, R²: 0.2336, Pearson: 0.4923, Spearman: 0.4990
# Seed 13 -> RMSE: 25.9207, R²: 0.2718, Pearson: 0.5272, Spearman: 0.5433
# Seed 14 -> RMSE: 25.8249, R²: 0.2317, Pearson: 0.4940, Spearman: 0.4903
# Seed 15 -> RMSE: 25.7013, R²: 0.1985, Pearson: 0.4774, Spearman: 0.4847
# Seed 16 -> RMSE: 26.2290, R²: 0.2302, Pearson: 0.4893, Spearman: 0.4737
# Seed 17 -> RMSE: 27.3212, R²: 0.1673, Pearson: 0.4288, Spearman: 0.4403
# Seed 18 -> RMSE: 25.7630, R²: 0.2495, Pearson: 0.5149, Spearman: 0.5004
# Seed 19 -> RMSE: 23.1930, R²: 0.3469, Pearson: 0.5933, Spearman: 0.5870
# Seed 20 -> RMSE: 25.9692, R²: 0.3068, Pearson: 0.5580, Spearman: 0.5504
# Seed 21 -> RMSE: 25.2177, R²: 0.2146, Pearson: 0.4971, Spearman: 0.4845
# Seed 22 -> RMSE: 22.9085, R²: 0.3676, Pearson: 0.6064, Spearman: 0.6034
# Seed 23 -> RMSE: 24.1607, R²: 0.3273, Pearson: 0.5753, Spearman: 0.5800
# Seed 24 -> RMSE: 26.9351, R²: 0.1887, Pearson: 0.4483, Spearman: 0.4416
# Seed 25 -> RMSE: 26.1087, R²: 0.2830, Pearson: 0.5340, Spearman: 0.5350
# Seed 26 -> RMSE: 25.1514, R²: 0.2792, Pearson: 0.5377, Spearman: 0.5427
# Seed 27 -> RMSE: 23.2837, R²: 0.3392, Pearson: 0.5828, Spearman: 0.5888
# Seed 28 -> RMSE: 25.4665, R²: 0.3162, Pearson: 0.5661, Spearman: 0.5567
# Seed 29 -> RMSE: 24.0591, R²: 0.3143, Pearson: 0.5638, Spearman: 0.5500
#
# R²_mean: 0.2676
# R²_sd: 0.0512
# RMSE_mean: 25.1248
# RMSE_sd: 1.2561
# Pearson_corr_mean: 0.5277
# Pearson_corr_sd: 0.0441
# Spearman_corr_mean: 0.5232
# Spearman_corr_sd: 0.0439

# %% [markdown]
# # AP3_256

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
    if 'ReactSeq_all' in i:
        continue
#     if 'AP3_256' in i:
#         continue
    if 'Drfp' in i:
        continue
    if 'rxnfp_pretrained' in i:
        continue
    if 'rxnfp_ft_10k' in i:
        continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift',
#  'AP3_256_0',
#  'AP3_256_1',
#  'AP3_256_2',
#  'AP3_256_3',
#  'AP3_256_4',
#  'AP3_256_5',
#  'AP3_256_6',
#  'AP3_256_7',
#  'AP3_256_8',
#  'AP3_256_9',
#  'AP3_256_10',
#  'AP3_256_11',
#  'AP3_256_12',
#  'AP3_256_13',
#  'AP3_256_14',
#  'AP3_256_15',
#  'AP3_256_16',
#  'AP3_256_17',
#  'AP3_256_18',
#  'AP3_256_19',
#  'AP3_256_20',
#  'AP3_256_21',
#  'AP3_256_22',
#  'AP3_256_23',
#  'AP3_256_24',
#  'AP3_256_25',
#  'AP3_256_26',
#  'AP3_256_27',
#  'AP3_256_28',
#  'AP3_256_29',
#  'AP3_256_30',
#  'AP3_256_31',
#  'AP3_256_32',
#  'AP3_256_33',
#  'AP3_256_34',
#  'AP3_256_35',
#  'AP3_256_36',
#  'AP3_256_37',
#  'AP3_256_38',
#  'AP3_256_39',
#  'AP3_256_40',
#  'AP3_256_41',
#  'AP3_256_42',
#  'AP3_256_43',
#  'AP3_256_44',
#  'AP3_256_45',
#  'AP3_256_46',
#  'AP3_256_47',
#  'AP3_256_48',
#  'AP3_256_49',
#  'AP3_256_50',
#  'AP3_256_51',
#  'AP3_256_52',
#  'AP3_256_53',
#  'AP3_256_54',
#  'AP3_256_55',
#  'AP3_256_56',
#  'AP3_256_57',
#  'AP3_256_58',
#  'AP3_256_59',
#  'AP3_256_60',
#  'AP3_256_61',
#  'AP3_256_62',
#  'AP3_256_63',
#  'AP3_256_64',
#  'AP3_256_65',
#  'AP3_256_66',
#  'AP3_256_67',
#  'AP3_256_68',
#  'AP3_256_69',
#  'AP3_256_70',
#  'AP3_256_71',
#  'AP3_256_72',
#  'AP3_256_73',
#  'AP3_256_74',
#  'AP3_256_75',
#  'AP3_256_76',
#  'AP3_256_77',
#  'AP3_256_78',
#  'AP3_256_79',
#  'AP3_256_80',
#  'AP3_256_81',
#  'AP3_256_82',
#  'AP3_256_83',
#  'AP3_256_84',
#  'AP3_256_85',
#  'AP3_256_86',
#  'AP3_256_87',
#  'AP3_256_88',
#  'AP3_256_89',
#  'AP3_256_90',
#  'AP3_256_91',
#  'AP3_256_92',
#  'AP3_256_93',
#  'AP3_256_94',
#  'AP3_256_95',
#  'AP3_256_96',
#  'AP3_256_97',
#  'AP3_256_98',
#  'AP3_256_99',
#  'AP3_256_100',
#  'AP3_256_101',
#  'AP3_256_102',
#  'AP3_256_103',
#  'AP3_256_104',
#  'AP3_256_105',
#  'AP3_256_106',
#  'AP3_256_107',
#  'AP3_256_108',
#  'AP3_256_109',
#  'AP3_256_110',
#  'AP3_256_111',
#  'AP3_256_112',
#  'AP3_256_113',
#  'AP3_256_114',
#  'AP3_256_115',
#  'AP3_256_116',
#  'AP3_256_117',
#  'AP3_256_118',
#  'AP3_256_119',
#  'AP3_256_120',
#  'AP3_256_121',
#  'AP3_256_122',
#  'AP3_256_123',
#  'AP3_256_124',
#  'AP3_256_125',
#  'AP3_256_126',
#  'AP3_256_127',
#  'AP3_256_128',
#  'AP3_256_129',
#  'AP3_256_130',
#  'AP3_256_131',
#  'AP3_256_132',
#  'AP3_256_133',
#  'AP3_256_134',
#  'AP3_256_135',
#  'AP3_256_136',
#  'AP3_256_137',
#  'AP3_256_138',
#  'AP3_256_139',
#  'AP3_256_140',
#  'AP3_256_141',
#  'AP3_256_142',
#  'AP3_256_143',
#  'AP3_256_144',
#  'AP3_256_145',
#  'AP3_256_146',
#  'AP3_256_147',
#  'AP3_256_148',
#  'AP3_256_149',
#  'AP3_256_150',
#  'AP3_256_151',
#  'AP3_256_152',
#  'AP3_256_153',
#  'AP3_256_154',
#  'AP3_256_155',
#  'AP3_256_156',
#  'AP3_256_157',
#  'AP3_256_158',
#  'AP3_256_159',
#  'AP3_256_160',
#  'AP3_256_161',
#  'AP3_256_162',
#  'AP3_256_163',
#  'AP3_256_164',
#  'AP3_256_165',
#  'AP3_256_166',
#  'AP3_256_167',
#  'AP3_256_168',
#  'AP3_256_169',
#  'AP3_256_170',
#  'AP3_256_171',
#  'AP3_256_172',
#  'AP3_256_173',
#  'AP3_256_174',
#  'AP3_256_175',
#  'AP3_256_176',
#  'AP3_256_177',
#  'AP3_256_178',
#  'AP3_256_179',
#  'AP3_256_180',
#  'AP3_256_181',
#  'AP3_256_182',
#  'AP3_256_183',
#  'AP3_256_184',
#  'AP3_256_185',
#  'AP3_256_186',
#  'AP3_256_187',
#  'AP3_256_188',
#  'AP3_256_189',
#  'AP3_256_190',
#  'AP3_256_191',
#  'AP3_256_192',
#  'AP3_256_193',
#  'AP3_256_194',
#  'AP3_256_195',
#  'AP3_256_196',
#  'AP3_256_197',
#  'AP3_256_198',
#  'AP3_256_199',
#  'AP3_256_200',
#  'AP3_256_201',
#  'AP3_256_202',
#  'AP3_256_203',
#  'AP3_256_204',
#  'AP3_256_205',
#  'AP3_256_206',
#  'AP3_256_207',
#  'AP3_256_208',
#  'AP3_256_209',
#  'AP3_256_210',
#  'AP3_256_211',
#  'AP3_256_212',
#  'AP3_256_213',
#  'AP3_256_214',
#  'AP3_256_215',
#  'AP3_256_216',
#  'AP3_256_217',
#  'AP3_256_218',
#  'AP3_256_219',
#  'AP3_256_220',
#  'AP3_256_221',
#  'AP3_256_222',
#  'AP3_256_223',
#  'AP3_256_224',
#  'AP3_256_225',
#  'AP3_256_226',
#  'AP3_256_227',
#  'AP3_256_228',
#  'AP3_256_229',
#  'AP3_256_230',
#  'AP3_256_231',
#  'AP3_256_232',
#  'AP3_256_233',
#  'AP3_256_234',
#  'AP3_256_235',
#  'AP3_256_236',
#  'AP3_256_237',
#  'AP3_256_238',
#  'AP3_256_239',
#  'AP3_256_240',
#  'AP3_256_241',
#  'AP3_256_242',
#  'AP3_256_243',
#  'AP3_256_244',
#  'AP3_256_245',
#  'AP3_256_246',
#  'AP3_256_247',
#  'AP3_256_248',
#  'AP3_256_249',
#  'AP3_256_250',
#  'AP3_256_251',
#  'AP3_256_252',
#  'AP3_256_253',
#  'AP3_256_254',
#  'AP3_256_255']

# %%
len(feature_col)
# Out:
# 617

# %%
X = df_cat[feature_col]

# %%
# Lists to store the results
rmse_list = []
r2_list = []
pearson_corr_list = []
spearman_corr_list = []

for seed in range(30):
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    # Model initialization and training
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    # Predictions
    y_pred = model.predict(X_test)
    
    # Metrics calculation
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    pearson_corr, _ = pearsonr(y_test, y_pred)
    spearman_corr, _ = spearmanr(y_test, y_pred)
    
    # Store results
    rmse_list.append(rmse)
    r2_list.append(r2)
    pearson_corr_list.append(pearson_corr)
    spearman_corr_list.append(spearman_corr)
    
    print(f'Seed {seed} -> RMSE: {rmse:.4f}, R²: {r2:.4f}, Pearson: {pearson_corr:.4f}, Spearman: {spearman_corr:.4f}')

# Averages and standard deviations
average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)
average_pearson = np.mean(pearson_corr_list)
average_spearman = np.mean(spearman_corr_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)
std_pearson = np.std(pearson_corr_list)
std_spearman = np.std(spearman_corr_list)

# Final results
print(f'\nR²_mean: {average_r2:.4f}')
print(f'R²_sd: {std_r2:.4f}')
print(f'RMSE_mean: {average_rmse:.4f}')
print(f'RMSE_sd: {std_rmse:.4f}')
print(f'Pearson_corr_mean: {average_pearson:.4f}')
print(f'Pearson_corr_sd: {std_pearson:.4f}')
print(f'Spearman_corr_mean: {average_spearman:.4f}')
print(f'Spearman_corr_sd: {std_spearman:.4f}')
# Out:
# Seed 0 -> RMSE: 23.3204, R²: 0.3702, Pearson: 0.6226, Spearman: 0.6278
# Seed 1 -> RMSE: 23.6275, R²: 0.3140, Pearson: 0.5618, Spearman: 0.5585
# Seed 2 -> RMSE: 26.1536, R²: 0.2299, Pearson: 0.4973, Spearman: 0.4786
# Seed 3 -> RMSE: 23.3840, R²: 0.3362, Pearson: 0.5807, Spearman: 0.5621
# Seed 4 -> RMSE: 27.0832, R²: 0.2540, Pearson: 0.5136, Spearman: 0.5342
# Seed 5 -> RMSE: 24.5837, R²: 0.2627, Pearson: 0.5458, Spearman: 0.5369
# Seed 6 -> RMSE: 24.3004, R²: 0.2658, Pearson: 0.5206, Spearman: 0.5055
# Seed 7 -> RMSE: 23.4425, R²: 0.3137, Pearson: 0.5621, Spearman: 0.5634
# Seed 8 -> RMSE: 23.8898, R²: 0.2773, Pearson: 0.5361, Spearman: 0.5236
# Seed 9 -> RMSE: 24.1403, R²: 0.2572, Pearson: 0.5317, Spearman: 0.5442
# Seed 10 -> RMSE: 26.5453, R²: 0.1544, Pearson: 0.4523, Spearman: 0.4349
# Seed 11 -> RMSE: 26.9638, R²: 0.2090, Pearson: 0.4743, Spearman: 0.4620
# Seed 12 -> RMSE: 25.8385, R²: 0.2159, Pearson: 0.4769, Spearman: 0.4849
# Seed 13 -> RMSE: 25.3819, R²: 0.3018, Pearson: 0.5553, Spearman: 0.5777
# Seed 14 -> RMSE: 25.6038, R²: 0.2448, Pearson: 0.5055, Spearman: 0.5135
# Seed 15 -> RMSE: 25.4651, R²: 0.2131, Pearson: 0.4912, Spearman: 0.5015
# Seed 16 -> RMSE: 26.2253, R²: 0.2304, Pearson: 0.4912, Spearman: 0.4780
# Seed 17 -> RMSE: 26.8116, R²: 0.1981, Pearson: 0.4579, Spearman: 0.4575
# Seed 18 -> RMSE: 25.8477, R²: 0.2446, Pearson: 0.5102, Spearman: 0.4928
# Seed 19 -> RMSE: 23.1643, R²: 0.3485, Pearson: 0.5962, Spearman: 0.5888
# Seed 20 -> RMSE: 25.4489, R²: 0.3343, Pearson: 0.5836, Spearman: 0.5728
# Seed 21 -> RMSE: 25.1254, R²: 0.2204, Pearson: 0.4951, Spearman: 0.4882
# Seed 22 -> RMSE: 23.5086, R²: 0.3341, Pearson: 0.5799, Spearman: 0.5838
# Seed 23 -> RMSE: 23.5025, R²: 0.3634, Pearson: 0.6098, Spearman: 0.6258
# Seed 24 -> RMSE: 26.0193, R²: 0.2430, Pearson: 0.4953, Spearman: 0.4913
# Seed 25 -> RMSE: 26.2890, R²: 0.2731, Pearson: 0.5235, Spearman: 0.5247
# Seed 26 -> RMSE: 25.1783, R²: 0.2776, Pearson: 0.5346, Spearman: 0.5269
# Seed 27 -> RMSE: 23.5115, R²: 0.3262, Pearson: 0.5713, Spearman: 0.5775
# Seed 28 -> RMSE: 24.8375, R²: 0.3495, Pearson: 0.5956, Spearman: 0.5842
# Seed 29 -> RMSE: 23.4423, R²: 0.3490, Pearson: 0.5908, Spearman: 0.5809
#
# R²_mean: 0.2771
# R²_sd: 0.0558
# RMSE_mean: 24.9545
# RMSE_sd: 1.2465
# Pearson_corr_mean: 0.5354
# Pearson_corr_sd: 0.0462
# Spearman_corr_mean: 0.5327
# Spearman_corr_sd: 0.0492

# %% [markdown]
# # DRFP

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
    if 'ReactSeq_all' in i:
        continue
    if 'AP3_256' in i:
        continue
#     if 'Drfp' in i:
#         continue
    if 'rxnfp_pretrained' in i:
        continue
    if 'rxnfp_ft_10k' in i:
        continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift',
#  'Drfp_0',
#  'Drfp_1',
#  'Drfp_2',
#  'Drfp_3',
#  'Drfp_4',
#  'Drfp_5',
#  'Drfp_6',
#  'Drfp_7',
#  'Drfp_8',
#  'Drfp_9',
#  'Drfp_10',
#  'Drfp_11',
#  'Drfp_12',
#  'Drfp_13',
#  'Drfp_14',
#  'Drfp_15',
#  'Drfp_16',
#  'Drfp_17',
#  'Drfp_18',
#  'Drfp_19',
#  'Drfp_20',
#  'Drfp_21',
#  'Drfp_22',
#  'Drfp_23',
#  'Drfp_24',
#  'Drfp_25',
#  'Drfp_26',
#  'Drfp_27',
#  'Drfp_28',
#  'Drfp_29',
#  'Drfp_30',
#  'Drfp_31',
#  'Drfp_32',
#  'Drfp_33',
#  'Drfp_34',
#  'Drfp_35',
#  'Drfp_36',
#  'Drfp_37',
#  'Drfp_38',
#  'Drfp_39',
#  'Drfp_40',
#  'Drfp_41',
#  'Drfp_42',
#  'Drfp_43',
#  'Drfp_44',
#  'Drfp_45',
#  'Drfp_46',
#  'Drfp_47',
#  'Drfp_48',
#  'Drfp_49',
#  'Drfp_50',
#  'Drfp_51',
#  'Drfp_52',
#  'Drfp_53',
#  'Drfp_54',
#  'Drfp_55',
#  'Drfp_56',
#  'Drfp_57',
#  'Drfp_58',
#  'Drfp_59',
#  'Drfp_60',
#  'Drfp_61',
#  'Drfp_62',
#  'Drfp_63',
#  'Drfp_64',
#  'Drfp_65',
#  'Drfp_66',
#  'Drfp_67',
#  'Drfp_68',
#  'Drfp_69',
#  'Drfp_70',
#  'Drfp_71',
#  'Drfp_72',
#  'Drfp_73',
#  'Drfp_74',
#  'Drfp_75',
#  'Drfp_76',
#  'Drfp_77',
#  'Drfp_78',
#  'Drfp_79',
#  'Drfp_80',
#  'Drfp_81',
#  'Drfp_82',
#  'Drfp_83',
#  'Drfp_84',
#  'Drfp_85',
#  'Drfp_86',
#  'Drfp_87',
#  'Drfp_88',
#  'Drfp_89',
#  'Drfp_90',
#  'Drfp_91',
#  'Drfp_92',
#  'Drfp_93',
#  'Drfp_94',
#  'Drfp_95',
#  'Drfp_96',
#  'Drfp_97',
#  'Drfp_98',
#  'Drfp_99',
#  'Drfp_100',
#  'Drfp_101',
#  'Drfp_102',
#  'Drfp_103',
#  'Drfp_104',
#  'Drfp_105',
#  'Drfp_106',
#  'Drfp_107',
#  'Drfp_108',
#  'Drfp_109',
#  'Drfp_110',
#  'Drfp_111',
#  'Drfp_112',
#  'Drfp_113',
#  'Drfp_114',
#  'Drfp_115',
#  'Drfp_116',
#  'Drfp_117',
#  'Drfp_118',
#  'Drfp_119',
#  'Drfp_120',
#  'Drfp_121',
#  'Drfp_122',
#  'Drfp_123',
#  'Drfp_124',
#  'Drfp_125',
#  'Drfp_126',
#  'Drfp_127',
#  'Drfp_128',
#  'Drfp_129',
#  'Drfp_130',
#  'Drfp_131',
#  'Drfp_132',
#  'Drfp_133',
#  'Drfp_134',
#  'Drfp_135',
#  'Drfp_136',
#  'Drfp_137',
#  'Drfp_138',
#  'Drfp_139',
#  'Drfp_140',
#  'Drfp_141',
#  'Drfp_142',
#  'Drfp_143',
#  'Drfp_144',
#  'Drfp_145',
#  'Drfp_146',
#  'Drfp_147',
#  'Drfp_148',
#  'Drfp_149',
#  'Drfp_150',
#  'Drfp_151',
#  'Drfp_152',
#  'Drfp_153',
#  'Drfp_154',
#  'Drfp_155',
#  'Drfp_156',
#  'Drfp_157',
#  'Drfp_158',
#  'Drfp_159',
#  'Drfp_160',
#  'Drfp_161',
#  'Drfp_162',
#  'Drfp_163',
#  'Drfp_164',
#  'Drfp_165',
#  'Drfp_166',
#  'Drfp_167',
#  'Drfp_168',
#  'Drfp_169',
#  'Drfp_170',
#  'Drfp_171',
#  'Drfp_172',
#  'Drfp_173',
#  'Drfp_174',
#  'Drfp_175',
#  'Drfp_176',
#  'Drfp_177',
#  'Drfp_178',
#  'Drfp_179',
#  'Drfp_180',
#  'Drfp_181',
#  'Drfp_182',
#  'Drfp_183',
#  'Drfp_184',
#  'Drfp_185',
#  'Drfp_186',
#  'Drfp_187',
#  'Drfp_188',
#  'Drfp_189',
#  'Drfp_190',
#  'Drfp_191',
#  'Drfp_192',
#  'Drfp_193',
#  'Drfp_194',
#  'Drfp_195',
#  'Drfp_196',
#  'Drfp_197',
#  'Drfp_198',
#  'Drfp_199',
#  'Drfp_200',
#  'Drfp_201',
#  'Drfp_202',
#  'Drfp_203',
#  'Drfp_204',
#  'Drfp_205',
#  'Drfp_206',
#  'Drfp_207',
#  'Drfp_208',
#  'Drfp_209',
#  'Drfp_210',
#  'Drfp_211',
#  'Drfp_212',
#  'Drfp_213',
#  'Drfp_214',
#  'Drfp_215',
#  'Drfp_216',
#  'Drfp_217',
#  'Drfp_218',
#  'Drfp_219',
#  'Drfp_220',
#  'Drfp_221',
#  'Drfp_222',
#  'Drfp_223',
#  'Drfp_224',
#  'Drfp_225',
#  'Drfp_226',
#  'Drfp_227',
#  'Drfp_228',
#  'Drfp_229',
#  'Drfp_230',
#  'Drfp_231',
#  'Drfp_232',
#  'Drfp_233',
#  'Drfp_234',
#  'Drfp_235',
#  'Drfp_236',
#  'Drfp_237',
#  'Drfp_238',
#  'Drfp_239',
#  'Drfp_240',
#  'Drfp_241',
#  'Drfp_242',
#  'Drfp_243',
#  'Drfp_244',
#  'Drfp_245',
#  'Drfp_246',
#  'Drfp_247',
#  'Drfp_248',
#  'Drfp_249',
#  'Drfp_250',
#  'Drfp_251',
#  'Drfp_252',
#  'Drfp_253',
#  'Drfp_254',
#  'Drfp_255',
#  'Drfp_256',
#  'Drfp_257',
#  'Drfp_258',
#  'Drfp_259',
#  'Drfp_260',
#  'Drfp_261',
#  'Drfp_262',
#  'Drfp_263',
#  'Drfp_264',
#  'Drfp_265',
#  'Drfp_266',
#  'Drfp_267',
#  'Drfp_268',
#  'Drfp_269',
#  'Drfp_270',
#  'Drfp_271',
#  'Drfp_272',
#  'Drfp_273',
#  'Drfp_274',
#  'Drfp_275',
#  'Drfp_276',
#  'Drfp_277',
#  'Drfp_278',
#  'Drfp_279',
#  'Drfp_280',
#  'Drfp_281',
#  'Drfp_282',
#  'Drfp_283',
#  'Drfp_284',
#  'Drfp_285',
#  'Drfp_286',
#  'Drfp_287',
#  'Drfp_288',
#  'Drfp_289',
#  'Drfp_290',
#  'Drfp_291',
#  'Drfp_292',
#  'Drfp_293',
#  'Drfp_294',
#  'Drfp_295',
#  'Drfp_296',
#  'Drfp_297',
#  'Drfp_298',
#  'Drfp_299',
#  'Drfp_300',
#  'Drfp_301',
#  'Drfp_302',
#  'Drfp_303',
#  'Drfp_304',
#  'Drfp_305',
#  'Drfp_306',
#  'Drfp_307',
#  'Drfp_308',
#  'Drfp_309',
#  'Drfp_310',
#  'Drfp_311',
#  'Drfp_312',
#  'Drfp_313',
#  'Drfp_314',
#  'Drfp_315',
#  'Drfp_316',
#  'Drfp_317',
#  'Drfp_318',
#  'Drfp_319',
#  'Drfp_320',
#  'Drfp_321',
#  'Drfp_322',
#  'Drfp_323',
#  'Drfp_324',
#  'Drfp_325',
#  'Drfp_326',
#  'Drfp_327',
#  'Drfp_328',
#  'Drfp_329',
#  'Drfp_330',
#  'Drfp_331',
#  'Drfp_332',
#  'Drfp_333',
#  'Drfp_334',
#  'Drfp_335',
#  'Drfp_336',
#  'Drfp_337',
#  'Drfp_338',
#  'Drfp_339',
#  'Drfp_340',
#  'Drfp_341',
#  'Drfp_342',
#  'Drfp_343',
#  'Drfp_344',
#  'Drfp_345',
#  'Drfp_346',
#  'Drfp_347',
#  'Drfp_348',
#  'Drfp_349',
#  'Drfp_350',
#  'Drfp_351',
#  'Drfp_352',
#  'Drfp_353',
#  'Drfp_354',
#  'Drfp_355',
#  'Drfp_356',
#  'Drfp_357',
#  'Drfp_358',
#  'Drfp_359',
#  'Drfp_360',
#  'Drfp_361',
#  'Drfp_362',
#  'Drfp_363',
#  'Drfp_364',
#  'Drfp_365',
#  'Drfp_366',
#  'Drfp_367',
#  'Drfp_368',
#  'Drfp_369',
#  'Drfp_370',
#  'Drfp_371',
#  'Drfp_372',
#  'Drfp_373',
#  'Drfp_374',
#  'Drfp_375',
#  'Drfp_376',
#  'Drfp_377',
#  'Drfp_378',
#  'Drfp_379',
#  'Drfp_380',
#  'Drfp_381',
#  'Drfp_382',
#  'Drfp_383',
#  'Drfp_384',
#  'Drfp_385',
#  'Drfp_386',
#  'Drfp_387',
#  'Drfp_388',
#  'Drfp_389',
#  'Drfp_390',
#  'Drfp_391',
#  'Drfp_392',
#  'Drfp_393',
#  'Drfp_394',
#  'Drfp_395',
#  'Drfp_396',
#  'Drfp_397',
#  'Drfp_398',
#  'Drfp_399',
#  'Drfp_400',
#  'Drfp_401',
#  'Drfp_402',
#  'Drfp_403',
#  'Drfp_404',
#  'Drfp_405',
#  'Drfp_406',
#  'Drfp_407',
#  'Drfp_408',
#  'Drfp_409',
#  'Drfp_410',
#  'Drfp_411',
#  'Drfp_412',
#  'Drfp_413',
#  'Drfp_414',
#  'Drfp_415',
#  'Drfp_416',
#  'Drfp_417',
#  'Drfp_418',
#  'Drfp_419',
#  'Drfp_420',
#  'Drfp_421',
#  'Drfp_422',
#  'Drfp_423',
#  'Drfp_424',
#  'Drfp_425',
#  'Drfp_426',
#  'Drfp_427',
#  'Drfp_428',
#  'Drfp_429',
#  'Drfp_430',
#  'Drfp_431',
#  'Drfp_432',
#  'Drfp_433',
#  'Drfp_434',
#  'Drfp_435',
#  'Drfp_436',
#  'Drfp_437',
#  'Drfp_438',
#  'Drfp_439',
#  'Drfp_440',
#  'Drfp_441',
#  'Drfp_442',
#  'Drfp_443',
#  'Drfp_444',
#  'Drfp_445',
#  'Drfp_446',
#  'Drfp_447',
#  'Drfp_448',
#  'Drfp_449',
#  'Drfp_450',
#  'Drfp_451',
#  'Drfp_452',
#  'Drfp_453',
#  'Drfp_454',
#  'Drfp_455',
#  'Drfp_456',
#  'Drfp_457',
#  'Drfp_458',
#  'Drfp_459',
#  'Drfp_460',
#  'Drfp_461',
#  'Drfp_462',
#  'Drfp_463',
#  'Drfp_464',
#  'Drfp_465',
#  'Drfp_466',
#  'Drfp_467',
#  'Drfp_468',
#  'Drfp_469',
#  'Drfp_470',
#  'Drfp_471',
#  'Drfp_472',
#  'Drfp_473',
#  'Drfp_474',
#  'Drfp_475',
#  'Drfp_476',
#  'Drfp_477',
#  'Drfp_478',
#  'Drfp_479',
#  'Drfp_480',
#  'Drfp_481',
#  'Drfp_482',
#  'Drfp_483',
#  'Drfp_484',
#  'Drfp_485',
#  'Drfp_486',
#  'Drfp_487',
#  'Drfp_488',
#  'Drfp_489',
#  'Drfp_490',
#  'Drfp_491',
#  'Drfp_492',
#  'Drfp_493',
#  'Drfp_494',
#  'Drfp_495',
#  'Drfp_496',
#  'Drfp_497',
#  'Drfp_498',
#  'Drfp_499',
#  'Drfp_500',
#  'Drfp_501',
#  'Drfp_502',
#  'Drfp_503',
#  'Drfp_504',
#  'Drfp_505',
#  'Drfp_506',
#  'Drfp_507',
#  'Drfp_508',
#  'Drfp_509',
#  'Drfp_510',
#  'Drfp_511',
#  'Drfp_512',
#  'Drfp_513',
#  'Drfp_514',
#  'Drfp_515',
#  'Drfp_516',
#  'Drfp_517',
#  'Drfp_518',
#  'Drfp_519',
#  'Drfp_520',
#  'Drfp_521',
#  'Drfp_522',
#  'Drfp_523',
#  'Drfp_524',
#  'Drfp_525',
#  'Drfp_526',
#  'Drfp_527',
#  'Drfp_528',
#  'Drfp_529',
#  'Drfp_530',
#  'Drfp_531',
#  'Drfp_532',
#  'Drfp_533',
#  'Drfp_534',
#  'Drfp_535',
#  'Drfp_536',
#  'Drfp_537',
#  'Drfp_538',
#  'Drfp_539',
#  'Drfp_540',
#  'Drfp_541',
#  'Drfp_542',
#  'Drfp_543',
#  'Drfp_544',
#  'Drfp_545',
#  'Drfp_546',
#  'Drfp_547',
#  'Drfp_548',
#  'Drfp_549',
#  'Drfp_550',
#  'Drfp_551',
#  'Drfp_552',
#  'Drfp_553',
#  'Drfp_554',
#  'Drfp_555',
#  'Drfp_556',
#  'Drfp_557',
#  'Drfp_558',
#  'Drfp_559',
#  'Drfp_560',
#  'Drfp_561',
#  'Drfp_562',
#  'Drfp_563',
#  'Drfp_564',
#  'Drfp_565',
#  'Drfp_566',
#  'Drfp_567',
#  'Drfp_568',
#  'Drfp_569',
#  'Drfp_570',
#  'Drfp_571',
#  'Drfp_572',
#  'Drfp_573',
#  'Drfp_574',
#  'Drfp_575',
#  'Drfp_576',
#  'Drfp_577',
#  'Drfp_578',
#  'Drfp_579',
#  'Drfp_580',
#  'Drfp_581',
#  'Drfp_582',
#  'Drfp_583',
#  'Drfp_584',
#  'Drfp_585',
#  'Drfp_586',
#  'Drfp_587',
#  'Drfp_588',
#  'Drfp_589',
#  'Drfp_590',
#  'Drfp_591',
#  'Drfp_592',
#  'Drfp_593',
#  'Drfp_594',
#  'Drfp_595',
#  'Drfp_596',
#  'Drfp_597',
#  'Drfp_598',
#  'Drfp_599',
#  'Drfp_600',
#  'Drfp_601',
#  'Drfp_602',
#  'Drfp_603',
#  'Drfp_604',
#  'Drfp_605',
#  'Drfp_606',
#  'Drfp_607',
#  'Drfp_608',
#  'Drfp_609',
#  'Drfp_610',
#  'Drfp_611',
#  'Drfp_612',
#  'Drfp_613',
#  'Drfp_614',
#  'Drfp_615',
#  'Drfp_616',
#  'Drfp_617',
#  'Drfp_618',
#  'Drfp_619',
#  'Drfp_620',
#  'Drfp_621',
#  'Drfp_622',
#  'Drfp_623',
#  'Drfp_624',
#  'Drfp_625',
#  'Drfp_626',
#  'Drfp_627',
#  'Drfp_628',
#  'Drfp_629',
#  'Drfp_630',
#  'Drfp_631',
#  'Drfp_632',
#  'Drfp_633',
#  'Drfp_634',
#  'Drfp_635',
#  'Drfp_636',
#  'Drfp_637',
#  'Drfp_638',
#  ...]

# %%
len(feature_col)
# Out:
# 2409

# %%
X = df_cat[feature_col]

# %%
# Lists to store the results
rmse_list = []
r2_list = []
pearson_corr_list = []
spearman_corr_list = []

for seed in range(30):
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    # Model initialization and training
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    # Predictions
    y_pred = model.predict(X_test)
    
    # Metrics calculation
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    pearson_corr, _ = pearsonr(y_test, y_pred)
    spearman_corr, _ = spearmanr(y_test, y_pred)
    
    # Store results
    rmse_list.append(rmse)
    r2_list.append(r2)
    pearson_corr_list.append(pearson_corr)
    spearman_corr_list.append(spearman_corr)
    
    print(f'Seed {seed} -> RMSE: {rmse:.4f}, R²: {r2:.4f}, Pearson: {pearson_corr:.4f}, Spearman: {spearman_corr:.4f}')

# Averages and standard deviations
average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)
average_pearson = np.mean(pearson_corr_list)
average_spearman = np.mean(spearman_corr_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)
std_pearson = np.std(pearson_corr_list)
std_spearman = np.std(spearman_corr_list)

# Final results
print(f'\nR²_mean: {average_r2:.4f}')
print(f'R²_sd: {std_r2:.4f}')
print(f'RMSE_mean: {average_rmse:.4f}')
print(f'RMSE_sd: {std_rmse:.4f}')
print(f'Pearson_corr_mean: {average_pearson:.4f}')
print(f'Pearson_corr_sd: {std_pearson:.4f}')
print(f'Spearman_corr_mean: {average_spearman:.4f}')
print(f'Spearman_corr_sd: {std_spearman:.4f}')
# Out:
# Seed 0 -> RMSE: 24.0543, R²: 0.3300, Pearson: 0.5988, Spearman: 0.6084
# Seed 1 -> RMSE: 24.8349, R²: 0.2422, Pearson: 0.5050, Spearman: 0.5098
# Seed 2 -> RMSE: 26.5574, R²: 0.2060, Pearson: 0.4788, Spearman: 0.4736
# Seed 3 -> RMSE: 23.2614, R²: 0.3431, Pearson: 0.5880, Spearman: 0.5741
# Seed 4 -> RMSE: 27.4178, R²: 0.2355, Pearson: 0.4957, Spearman: 0.5141
# Seed 5 -> RMSE: 25.6164, R²: 0.1994, Pearson: 0.5011, Spearman: 0.4914
# Seed 6 -> RMSE: 25.3297, R²: 0.2023, Pearson: 0.4747, Spearman: 0.4515
# Seed 7 -> RMSE: 24.4075, R²: 0.2561, Pearson: 0.5140, Spearman: 0.5143
# Seed 8 -> RMSE: 23.8250, R²: 0.2812, Pearson: 0.5403, Spearman: 0.5372
# Seed 9 -> RMSE: 25.3503, R²: 0.1809, Pearson: 0.4812, Spearman: 0.4830
# Seed 10 -> RMSE: 26.9463, R²: 0.1287, Pearson: 0.4440, Spearman: 0.4346
# Seed 11 -> RMSE: 27.7088, R²: 0.1646, Pearson: 0.4349, Spearman: 0.4346
# Seed 12 -> RMSE: 26.0220, R²: 0.2047, Pearson: 0.4702, Spearman: 0.4793
# Seed 13 -> RMSE: 26.7759, R²: 0.2230, Pearson: 0.4931, Spearman: 0.5140
# Seed 14 -> RMSE: 26.3572, R²: 0.1997, Pearson: 0.4717, Spearman: 0.4846
# Seed 15 -> RMSE: 26.2045, R²: 0.1668, Pearson: 0.4586, Spearman: 0.4744
# Seed 16 -> RMSE: 27.4466, R²: 0.1571, Pearson: 0.4258, Spearman: 0.4250
# Seed 17 -> RMSE: 27.9973, R²: 0.1256, Pearson: 0.4037, Spearman: 0.4188
# Seed 18 -> RMSE: 26.4353, R²: 0.2099, Pearson: 0.4930, Spearman: 0.4797
# Seed 19 -> RMSE: 23.6665, R²: 0.3200, Pearson: 0.5744, Spearman: 0.5784
# Seed 20 -> RMSE: 26.4032, R²: 0.2834, Pearson: 0.5362, Spearman: 0.5379
# Seed 21 -> RMSE: 25.4560, R²: 0.1997, Pearson: 0.4857, Spearman: 0.4855
# Seed 22 -> RMSE: 24.1924, R²: 0.2948, Pearson: 0.5505, Spearman: 0.5566
# Seed 23 -> RMSE: 24.7995, R²: 0.2912, Pearson: 0.5507, Spearman: 0.5466
# Seed 24 -> RMSE: 26.9822, R²: 0.1859, Pearson: 0.4430, Spearman: 0.4551
# Seed 25 -> RMSE: 26.7023, R²: 0.2500, Pearson: 0.5008, Spearman: 0.4942
# Seed 26 -> RMSE: 25.7222, R²: 0.2461, Pearson: 0.5059, Spearman: 0.5233
# Seed 27 -> RMSE: 24.4732, R²: 0.2700, Pearson: 0.5267, Spearman: 0.5280
# Seed 28 -> RMSE: 25.0084, R²: 0.3405, Pearson: 0.5885, Spearman: 0.5898
# Seed 29 -> RMSE: 24.0293, R²: 0.3160, Pearson: 0.5636, Spearman: 0.5584
#
# R²_mean: 0.2351
# R²_sd: 0.0607
# RMSE_mean: 25.6661
# RMSE_sd: 1.2924
# Pearson_corr_mean: 0.5033
# Pearson_corr_sd: 0.0497
# Spearman_corr_mean: 0.5052
# Spearman_corr_sd: 0.0491

# %% [markdown]
# # rxnfp_pretrained

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
    if 'ReactSeq_all' in i:
        continue
    if 'AP3_256' in i:
        continue
    if 'Drfp' in i:
        continue
#     if 'rxnfp_pretrained' in i:
#         continue
    if 'rxnfp_ft_10k' in i:
        continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift',
#  'rxnfp_pretrained_0',
#  'rxnfp_pretrained_1',
#  'rxnfp_pretrained_2',
#  'rxnfp_pretrained_3',
#  'rxnfp_pretrained_4',
#  'rxnfp_pretrained_5',
#  'rxnfp_pretrained_6',
#  'rxnfp_pretrained_7',
#  'rxnfp_pretrained_8',
#  'rxnfp_pretrained_9',
#  'rxnfp_pretrained_10',
#  'rxnfp_pretrained_11',
#  'rxnfp_pretrained_12',
#  'rxnfp_pretrained_13',
#  'rxnfp_pretrained_14',
#  'rxnfp_pretrained_15',
#  'rxnfp_pretrained_16',
#  'rxnfp_pretrained_17',
#  'rxnfp_pretrained_18',
#  'rxnfp_pretrained_19',
#  'rxnfp_pretrained_20',
#  'rxnfp_pretrained_21',
#  'rxnfp_pretrained_22',
#  'rxnfp_pretrained_23',
#  'rxnfp_pretrained_24',
#  'rxnfp_pretrained_25',
#  'rxnfp_pretrained_26',
#  'rxnfp_pretrained_27',
#  'rxnfp_pretrained_28',
#  'rxnfp_pretrained_29',
#  'rxnfp_pretrained_30',
#  'rxnfp_pretrained_31',
#  'rxnfp_pretrained_32',
#  'rxnfp_pretrained_33',
#  'rxnfp_pretrained_34',
#  'rxnfp_pretrained_35',
#  'rxnfp_pretrained_36',
#  'rxnfp_pretrained_37',
#  'rxnfp_pretrained_38',
#  'rxnfp_pretrained_39',
#  'rxnfp_pretrained_40',
#  'rxnfp_pretrained_41',
#  'rxnfp_pretrained_42',
#  'rxnfp_pretrained_43',
#  'rxnfp_pretrained_44',
#  'rxnfp_pretrained_45',
#  'rxnfp_pretrained_46',
#  'rxnfp_pretrained_47',
#  'rxnfp_pretrained_48',
#  'rxnfp_pretrained_49',
#  'rxnfp_pretrained_50',
#  'rxnfp_pretrained_51',
#  'rxnfp_pretrained_52',
#  'rxnfp_pretrained_53',
#  'rxnfp_pretrained_54',
#  'rxnfp_pretrained_55',
#  'rxnfp_pretrained_56',
#  'rxnfp_pretrained_57',
#  'rxnfp_pretrained_58',
#  'rxnfp_pretrained_59',
#  'rxnfp_pretrained_60',
#  'rxnfp_pretrained_61',
#  'rxnfp_pretrained_62',
#  'rxnfp_pretrained_63',
#  'rxnfp_pretrained_64',
#  'rxnfp_pretrained_65',
#  'rxnfp_pretrained_66',
#  'rxnfp_pretrained_67',
#  'rxnfp_pretrained_68',
#  'rxnfp_pretrained_69',
#  'rxnfp_pretrained_70',
#  'rxnfp_pretrained_71',
#  'rxnfp_pretrained_72',
#  'rxnfp_pretrained_73',
#  'rxnfp_pretrained_74',
#  'rxnfp_pretrained_75',
#  'rxnfp_pretrained_76',
#  'rxnfp_pretrained_77',
#  'rxnfp_pretrained_78',
#  'rxnfp_pretrained_79',
#  'rxnfp_pretrained_80',
#  'rxnfp_pretrained_81',
#  'rxnfp_pretrained_82',
#  'rxnfp_pretrained_83',
#  'rxnfp_pretrained_84',
#  'rxnfp_pretrained_85',
#  'rxnfp_pretrained_86',
#  'rxnfp_pretrained_87',
#  'rxnfp_pretrained_88',
#  'rxnfp_pretrained_89',
#  'rxnfp_pretrained_90',
#  'rxnfp_pretrained_91',
#  'rxnfp_pretrained_92',
#  'rxnfp_pretrained_93',
#  'rxnfp_pretrained_94',
#  'rxnfp_pretrained_95',
#  'rxnfp_pretrained_96',
#  'rxnfp_pretrained_97',
#  'rxnfp_pretrained_98',
#  'rxnfp_pretrained_99',
#  'rxnfp_pretrained_100',
#  'rxnfp_pretrained_101',
#  'rxnfp_pretrained_102',
#  'rxnfp_pretrained_103',
#  'rxnfp_pretrained_104',
#  'rxnfp_pretrained_105',
#  'rxnfp_pretrained_106',
#  'rxnfp_pretrained_107',
#  'rxnfp_pretrained_108',
#  'rxnfp_pretrained_109',
#  'rxnfp_pretrained_110',
#  'rxnfp_pretrained_111',
#  'rxnfp_pretrained_112',
#  'rxnfp_pretrained_113',
#  'rxnfp_pretrained_114',
#  'rxnfp_pretrained_115',
#  'rxnfp_pretrained_116',
#  'rxnfp_pretrained_117',
#  'rxnfp_pretrained_118',
#  'rxnfp_pretrained_119',
#  'rxnfp_pretrained_120',
#  'rxnfp_pretrained_121',
#  'rxnfp_pretrained_122',
#  'rxnfp_pretrained_123',
#  'rxnfp_pretrained_124',
#  'rxnfp_pretrained_125',
#  'rxnfp_pretrained_126',
#  'rxnfp_pretrained_127',
#  'rxnfp_pretrained_128',
#  'rxnfp_pretrained_129',
#  'rxnfp_pretrained_130',
#  'rxnfp_pretrained_131',
#  'rxnfp_pretrained_132',
#  'rxnfp_pretrained_133',
#  'rxnfp_pretrained_134',
#  'rxnfp_pretrained_135',
#  'rxnfp_pretrained_136',
#  'rxnfp_pretrained_137',
#  'rxnfp_pretrained_138',
#  'rxnfp_pretrained_139',
#  'rxnfp_pretrained_140',
#  'rxnfp_pretrained_141',
#  'rxnfp_pretrained_142',
#  'rxnfp_pretrained_143',
#  'rxnfp_pretrained_144',
#  'rxnfp_pretrained_145',
#  'rxnfp_pretrained_146',
#  'rxnfp_pretrained_147',
#  'rxnfp_pretrained_148',
#  'rxnfp_pretrained_149',
#  'rxnfp_pretrained_150',
#  'rxnfp_pretrained_151',
#  'rxnfp_pretrained_152',
#  'rxnfp_pretrained_153',
#  'rxnfp_pretrained_154',
#  'rxnfp_pretrained_155',
#  'rxnfp_pretrained_156',
#  'rxnfp_pretrained_157',
#  'rxnfp_pretrained_158',
#  'rxnfp_pretrained_159',
#  'rxnfp_pretrained_160',
#  'rxnfp_pretrained_161',
#  'rxnfp_pretrained_162',
#  'rxnfp_pretrained_163',
#  'rxnfp_pretrained_164',
#  'rxnfp_pretrained_165',
#  'rxnfp_pretrained_166',
#  'rxnfp_pretrained_167',
#  'rxnfp_pretrained_168',
#  'rxnfp_pretrained_169',
#  'rxnfp_pretrained_170',
#  'rxnfp_pretrained_171',
#  'rxnfp_pretrained_172',
#  'rxnfp_pretrained_173',
#  'rxnfp_pretrained_174',
#  'rxnfp_pretrained_175',
#  'rxnfp_pretrained_176',
#  'rxnfp_pretrained_177',
#  'rxnfp_pretrained_178',
#  'rxnfp_pretrained_179',
#  'rxnfp_pretrained_180',
#  'rxnfp_pretrained_181',
#  'rxnfp_pretrained_182',
#  'rxnfp_pretrained_183',
#  'rxnfp_pretrained_184',
#  'rxnfp_pretrained_185',
#  'rxnfp_pretrained_186',
#  'rxnfp_pretrained_187',
#  'rxnfp_pretrained_188',
#  'rxnfp_pretrained_189',
#  'rxnfp_pretrained_190',
#  'rxnfp_pretrained_191',
#  'rxnfp_pretrained_192',
#  'rxnfp_pretrained_193',
#  'rxnfp_pretrained_194',
#  'rxnfp_pretrained_195',
#  'rxnfp_pretrained_196',
#  'rxnfp_pretrained_197',
#  'rxnfp_pretrained_198',
#  'rxnfp_pretrained_199',
#  'rxnfp_pretrained_200',
#  'rxnfp_pretrained_201',
#  'rxnfp_pretrained_202',
#  'rxnfp_pretrained_203',
#  'rxnfp_pretrained_204',
#  'rxnfp_pretrained_205',
#  'rxnfp_pretrained_206',
#  'rxnfp_pretrained_207',
#  'rxnfp_pretrained_208',
#  'rxnfp_pretrained_209',
#  'rxnfp_pretrained_210',
#  'rxnfp_pretrained_211',
#  'rxnfp_pretrained_212',
#  'rxnfp_pretrained_213',
#  'rxnfp_pretrained_214',
#  'rxnfp_pretrained_215',
#  'rxnfp_pretrained_216',
#  'rxnfp_pretrained_217',
#  'rxnfp_pretrained_218',
#  'rxnfp_pretrained_219',
#  'rxnfp_pretrained_220',
#  'rxnfp_pretrained_221',
#  'rxnfp_pretrained_222',
#  'rxnfp_pretrained_223',
#  'rxnfp_pretrained_224',
#  'rxnfp_pretrained_225',
#  'rxnfp_pretrained_226',
#  'rxnfp_pretrained_227',
#  'rxnfp_pretrained_228',
#  'rxnfp_pretrained_229',
#  'rxnfp_pretrained_230',
#  'rxnfp_pretrained_231',
#  'rxnfp_pretrained_232',
#  'rxnfp_pretrained_233',
#  'rxnfp_pretrained_234',
#  'rxnfp_pretrained_235',
#  'rxnfp_pretrained_236',
#  'rxnfp_pretrained_237',
#  'rxnfp_pretrained_238',
#  'rxnfp_pretrained_239',
#  'rxnfp_pretrained_240',
#  'rxnfp_pretrained_241',
#  'rxnfp_pretrained_242',
#  'rxnfp_pretrained_243',
#  'rxnfp_pretrained_244',
#  'rxnfp_pretrained_245',
#  'rxnfp_pretrained_246',
#  'rxnfp_pretrained_247',
#  'rxnfp_pretrained_248',
#  'rxnfp_pretrained_249',
#  'rxnfp_pretrained_250',
#  'rxnfp_pretrained_251',
#  'rxnfp_pretrained_252',
#  'rxnfp_pretrained_253',
#  'rxnfp_pretrained_254',
#  'rxnfp_pretrained_255']

# %%
len(feature_col)
# Out:
# 617

# %%
X = df_cat[feature_col]

# %%
# Lists to store the results
rmse_list = []
r2_list = []
pearson_corr_list = []
spearman_corr_list = []

for seed in range(30):
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    # Model initialization and training
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    # Predictions
    y_pred = model.predict(X_test)
    
    # Metrics calculation
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    pearson_corr, _ = pearsonr(y_test, y_pred)
    spearman_corr, _ = spearmanr(y_test, y_pred)
    
    # Store results
    rmse_list.append(rmse)
    r2_list.append(r2)
    pearson_corr_list.append(pearson_corr)
    spearman_corr_list.append(spearman_corr)
    
    print(f'Seed {seed} -> RMSE: {rmse:.4f}, R²: {r2:.4f}, Pearson: {pearson_corr:.4f}, Spearman: {spearman_corr:.4f}')

# Averages and standard deviations
average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)
average_pearson = np.mean(pearson_corr_list)
average_spearman = np.mean(spearman_corr_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)
std_pearson = np.std(pearson_corr_list)
std_spearman = np.std(spearman_corr_list)

# Final results
print(f'\nR²_mean: {average_r2:.4f}')
print(f'R²_sd: {std_r2:.4f}')
print(f'RMSE_mean: {average_rmse:.4f}')
print(f'RMSE_sd: {std_rmse:.4f}')
print(f'Pearson_corr_mean: {average_pearson:.4f}')
print(f'Pearson_corr_sd: {std_pearson:.4f}')
print(f'Spearman_corr_mean: {average_spearman:.4f}')
print(f'Spearman_corr_sd: {std_spearman:.4f}')
# Out:
# Seed 0 -> RMSE: 23.9158, R²: 0.3377, Pearson: 0.5981, Spearman: 0.5843
# Seed 1 -> RMSE: 23.4927, R²: 0.3219, Pearson: 0.5681, Spearman: 0.5513
# Seed 2 -> RMSE: 25.5808, R²: 0.2633, Pearson: 0.5202, Spearman: 0.4996
# Seed 3 -> RMSE: 23.3289, R²: 0.3393, Pearson: 0.5832, Spearman: 0.5576
# Seed 4 -> RMSE: 28.0328, R²: 0.2008, Pearson: 0.4621, Spearman: 0.4704
# Seed 5 -> RMSE: 24.4389, R²: 0.2713, Pearson: 0.5509, Spearman: 0.5419
# Seed 6 -> RMSE: 23.6454, R²: 0.3049, Pearson: 0.5563, Spearman: 0.5450
# Seed 7 -> RMSE: 23.3630, R²: 0.3184, Pearson: 0.5690, Spearman: 0.5698
# Seed 8 -> RMSE: 24.3661, R²: 0.2482, Pearson: 0.5107, Spearman: 0.5028
# Seed 9 -> RMSE: 23.9292, R²: 0.2701, Pearson: 0.5373, Spearman: 0.5423
# Seed 10 -> RMSE: 25.5891, R²: 0.2143, Pearson: 0.5079, Spearman: 0.5017
# Seed 11 -> RMSE: 27.0702, R²: 0.2027, Pearson: 0.4625, Spearman: 0.4640
# Seed 12 -> RMSE: 24.8625, R²: 0.2740, Pearson: 0.5249, Spearman: 0.5408
# Seed 13 -> RMSE: 25.3369, R²: 0.3042, Pearson: 0.5542, Spearman: 0.5655
# Seed 14 -> RMSE: 25.1580, R²: 0.2709, Pearson: 0.5260, Spearman: 0.5311
# Seed 15 -> RMSE: 25.3479, R²: 0.2204, Pearson: 0.4962, Spearman: 0.4958
# Seed 16 -> RMSE: 25.3081, R²: 0.2833, Pearson: 0.5350, Spearman: 0.5227
# Seed 17 -> RMSE: 26.4913, R²: 0.2172, Pearson: 0.4715, Spearman: 0.4792
# Seed 18 -> RMSE: 25.2143, R²: 0.2812, Pearson: 0.5385, Spearman: 0.5275
# Seed 19 -> RMSE: 22.8800, R²: 0.3644, Pearson: 0.6080, Spearman: 0.6139
# Seed 20 -> RMSE: 25.6044, R²: 0.3261, Pearson: 0.5750, Spearman: 0.5836
# Seed 21 -> RMSE: 25.9654, R²: 0.1674, Pearson: 0.4616, Spearman: 0.4593
# Seed 22 -> RMSE: 23.7210, R²: 0.3220, Pearson: 0.5684, Spearman: 0.5499
# Seed 23 -> RMSE: 24.5163, R²: 0.3073, Pearson: 0.5574, Spearman: 0.5648
# Seed 24 -> RMSE: 27.1366, R²: 0.1766, Pearson: 0.4325, Spearman: 0.4042
# Seed 25 -> RMSE: 26.4251, R²: 0.2655, Pearson: 0.5161, Spearman: 0.5363
# Seed 26 -> RMSE: 25.4345, R²: 0.2629, Pearson: 0.5184, Spearman: 0.5262
# Seed 27 -> RMSE: 23.3309, R²: 0.3365, Pearson: 0.5808, Spearman: 0.5863
# Seed 28 -> RMSE: 25.3793, R²: 0.3208, Pearson: 0.5716, Spearman: 0.5528
# Seed 29 -> RMSE: 23.4101, R²: 0.3508, Pearson: 0.5927, Spearman: 0.5788
#
# R²_mean: 0.2781
# R²_sd: 0.0524
# RMSE_mean: 24.9425
# RMSE_sd: 1.2811
# Pearson_corr_mean: 0.5352
# Pearson_corr_sd: 0.0445
# Spearman_corr_mean: 0.5316
# Spearman_corr_sd: 0.0448

# %% [markdown]
# # rxnfp_finetuned

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
    if 'ReactSeq_all' in i:
        continue
    if 'AP3_256' in i:
        continue
    if 'Drfp' in i:
        continue
    if 'rxnfp_pretrained' in i:
        continue
#     if 'rxnfp_ft_10k' in i:
#         continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift',
#  'rxnfp_ft_10k_0',
#  'rxnfp_ft_10k_1',
#  'rxnfp_ft_10k_2',
#  'rxnfp_ft_10k_3',
#  'rxnfp_ft_10k_4',
#  'rxnfp_ft_10k_5',
#  'rxnfp_ft_10k_6',
#  'rxnfp_ft_10k_7',
#  'rxnfp_ft_10k_8',
#  'rxnfp_ft_10k_9',
#  'rxnfp_ft_10k_10',
#  'rxnfp_ft_10k_11',
#  'rxnfp_ft_10k_12',
#  'rxnfp_ft_10k_13',
#  'rxnfp_ft_10k_14',
#  'rxnfp_ft_10k_15',
#  'rxnfp_ft_10k_16',
#  'rxnfp_ft_10k_17',
#  'rxnfp_ft_10k_18',
#  'rxnfp_ft_10k_19',
#  'rxnfp_ft_10k_20',
#  'rxnfp_ft_10k_21',
#  'rxnfp_ft_10k_22',
#  'rxnfp_ft_10k_23',
#  'rxnfp_ft_10k_24',
#  'rxnfp_ft_10k_25',
#  'rxnfp_ft_10k_26',
#  'rxnfp_ft_10k_27',
#  'rxnfp_ft_10k_28',
#  'rxnfp_ft_10k_29',
#  'rxnfp_ft_10k_30',
#  'rxnfp_ft_10k_31',
#  'rxnfp_ft_10k_32',
#  'rxnfp_ft_10k_33',
#  'rxnfp_ft_10k_34',
#  'rxnfp_ft_10k_35',
#  'rxnfp_ft_10k_36',
#  'rxnfp_ft_10k_37',
#  'rxnfp_ft_10k_38',
#  'rxnfp_ft_10k_39',
#  'rxnfp_ft_10k_40',
#  'rxnfp_ft_10k_41',
#  'rxnfp_ft_10k_42',
#  'rxnfp_ft_10k_43',
#  'rxnfp_ft_10k_44',
#  'rxnfp_ft_10k_45',
#  'rxnfp_ft_10k_46',
#  'rxnfp_ft_10k_47',
#  'rxnfp_ft_10k_48',
#  'rxnfp_ft_10k_49',
#  'rxnfp_ft_10k_50',
#  'rxnfp_ft_10k_51',
#  'rxnfp_ft_10k_52',
#  'rxnfp_ft_10k_53',
#  'rxnfp_ft_10k_54',
#  'rxnfp_ft_10k_55',
#  'rxnfp_ft_10k_56',
#  'rxnfp_ft_10k_57',
#  'rxnfp_ft_10k_58',
#  'rxnfp_ft_10k_59',
#  'rxnfp_ft_10k_60',
#  'rxnfp_ft_10k_61',
#  'rxnfp_ft_10k_62',
#  'rxnfp_ft_10k_63',
#  'rxnfp_ft_10k_64',
#  'rxnfp_ft_10k_65',
#  'rxnfp_ft_10k_66',
#  'rxnfp_ft_10k_67',
#  'rxnfp_ft_10k_68',
#  'rxnfp_ft_10k_69',
#  'rxnfp_ft_10k_70',
#  'rxnfp_ft_10k_71',
#  'rxnfp_ft_10k_72',
#  'rxnfp_ft_10k_73',
#  'rxnfp_ft_10k_74',
#  'rxnfp_ft_10k_75',
#  'rxnfp_ft_10k_76',
#  'rxnfp_ft_10k_77',
#  'rxnfp_ft_10k_78',
#  'rxnfp_ft_10k_79',
#  'rxnfp_ft_10k_80',
#  'rxnfp_ft_10k_81',
#  'rxnfp_ft_10k_82',
#  'rxnfp_ft_10k_83',
#  'rxnfp_ft_10k_84',
#  'rxnfp_ft_10k_85',
#  'rxnfp_ft_10k_86',
#  'rxnfp_ft_10k_87',
#  'rxnfp_ft_10k_88',
#  'rxnfp_ft_10k_89',
#  'rxnfp_ft_10k_90',
#  'rxnfp_ft_10k_91',
#  'rxnfp_ft_10k_92',
#  'rxnfp_ft_10k_93',
#  'rxnfp_ft_10k_94',
#  'rxnfp_ft_10k_95',
#  'rxnfp_ft_10k_96',
#  'rxnfp_ft_10k_97',
#  'rxnfp_ft_10k_98',
#  'rxnfp_ft_10k_99',
#  'rxnfp_ft_10k_100',
#  'rxnfp_ft_10k_101',
#  'rxnfp_ft_10k_102',
#  'rxnfp_ft_10k_103',
#  'rxnfp_ft_10k_104',
#  'rxnfp_ft_10k_105',
#  'rxnfp_ft_10k_106',
#  'rxnfp_ft_10k_107',
#  'rxnfp_ft_10k_108',
#  'rxnfp_ft_10k_109',
#  'rxnfp_ft_10k_110',
#  'rxnfp_ft_10k_111',
#  'rxnfp_ft_10k_112',
#  'rxnfp_ft_10k_113',
#  'rxnfp_ft_10k_114',
#  'rxnfp_ft_10k_115',
#  'rxnfp_ft_10k_116',
#  'rxnfp_ft_10k_117',
#  'rxnfp_ft_10k_118',
#  'rxnfp_ft_10k_119',
#  'rxnfp_ft_10k_120',
#  'rxnfp_ft_10k_121',
#  'rxnfp_ft_10k_122',
#  'rxnfp_ft_10k_123',
#  'rxnfp_ft_10k_124',
#  'rxnfp_ft_10k_125',
#  'rxnfp_ft_10k_126',
#  'rxnfp_ft_10k_127',
#  'rxnfp_ft_10k_128',
#  'rxnfp_ft_10k_129',
#  'rxnfp_ft_10k_130',
#  'rxnfp_ft_10k_131',
#  'rxnfp_ft_10k_132',
#  'rxnfp_ft_10k_133',
#  'rxnfp_ft_10k_134',
#  'rxnfp_ft_10k_135',
#  'rxnfp_ft_10k_136',
#  'rxnfp_ft_10k_137',
#  'rxnfp_ft_10k_138',
#  'rxnfp_ft_10k_139',
#  'rxnfp_ft_10k_140',
#  'rxnfp_ft_10k_141',
#  'rxnfp_ft_10k_142',
#  'rxnfp_ft_10k_143',
#  'rxnfp_ft_10k_144',
#  'rxnfp_ft_10k_145',
#  'rxnfp_ft_10k_146',
#  'rxnfp_ft_10k_147',
#  'rxnfp_ft_10k_148',
#  'rxnfp_ft_10k_149',
#  'rxnfp_ft_10k_150',
#  'rxnfp_ft_10k_151',
#  'rxnfp_ft_10k_152',
#  'rxnfp_ft_10k_153',
#  'rxnfp_ft_10k_154',
#  'rxnfp_ft_10k_155',
#  'rxnfp_ft_10k_156',
#  'rxnfp_ft_10k_157',
#  'rxnfp_ft_10k_158',
#  'rxnfp_ft_10k_159',
#  'rxnfp_ft_10k_160',
#  'rxnfp_ft_10k_161',
#  'rxnfp_ft_10k_162',
#  'rxnfp_ft_10k_163',
#  'rxnfp_ft_10k_164',
#  'rxnfp_ft_10k_165',
#  'rxnfp_ft_10k_166',
#  'rxnfp_ft_10k_167',
#  'rxnfp_ft_10k_168',
#  'rxnfp_ft_10k_169',
#  'rxnfp_ft_10k_170',
#  'rxnfp_ft_10k_171',
#  'rxnfp_ft_10k_172',
#  'rxnfp_ft_10k_173',
#  'rxnfp_ft_10k_174',
#  'rxnfp_ft_10k_175',
#  'rxnfp_ft_10k_176',
#  'rxnfp_ft_10k_177',
#  'rxnfp_ft_10k_178',
#  'rxnfp_ft_10k_179',
#  'rxnfp_ft_10k_180',
#  'rxnfp_ft_10k_181',
#  'rxnfp_ft_10k_182',
#  'rxnfp_ft_10k_183',
#  'rxnfp_ft_10k_184',
#  'rxnfp_ft_10k_185',
#  'rxnfp_ft_10k_186',
#  'rxnfp_ft_10k_187',
#  'rxnfp_ft_10k_188',
#  'rxnfp_ft_10k_189',
#  'rxnfp_ft_10k_190',
#  'rxnfp_ft_10k_191',
#  'rxnfp_ft_10k_192',
#  'rxnfp_ft_10k_193',
#  'rxnfp_ft_10k_194',
#  'rxnfp_ft_10k_195',
#  'rxnfp_ft_10k_196',
#  'rxnfp_ft_10k_197',
#  'rxnfp_ft_10k_198',
#  'rxnfp_ft_10k_199',
#  'rxnfp_ft_10k_200',
#  'rxnfp_ft_10k_201',
#  'rxnfp_ft_10k_202',
#  'rxnfp_ft_10k_203',
#  'rxnfp_ft_10k_204',
#  'rxnfp_ft_10k_205',
#  'rxnfp_ft_10k_206',
#  'rxnfp_ft_10k_207',
#  'rxnfp_ft_10k_208',
#  'rxnfp_ft_10k_209',
#  'rxnfp_ft_10k_210',
#  'rxnfp_ft_10k_211',
#  'rxnfp_ft_10k_212',
#  'rxnfp_ft_10k_213',
#  'rxnfp_ft_10k_214',
#  'rxnfp_ft_10k_215',
#  'rxnfp_ft_10k_216',
#  'rxnfp_ft_10k_217',
#  'rxnfp_ft_10k_218',
#  'rxnfp_ft_10k_219',
#  'rxnfp_ft_10k_220',
#  'rxnfp_ft_10k_221',
#  'rxnfp_ft_10k_222',
#  'rxnfp_ft_10k_223',
#  'rxnfp_ft_10k_224',
#  'rxnfp_ft_10k_225',
#  'rxnfp_ft_10k_226',
#  'rxnfp_ft_10k_227',
#  'rxnfp_ft_10k_228',
#  'rxnfp_ft_10k_229',
#  'rxnfp_ft_10k_230',
#  'rxnfp_ft_10k_231',
#  'rxnfp_ft_10k_232',
#  'rxnfp_ft_10k_233',
#  'rxnfp_ft_10k_234',
#  'rxnfp_ft_10k_235',
#  'rxnfp_ft_10k_236',
#  'rxnfp_ft_10k_237',
#  'rxnfp_ft_10k_238',
#  'rxnfp_ft_10k_239',
#  'rxnfp_ft_10k_240',
#  'rxnfp_ft_10k_241',
#  'rxnfp_ft_10k_242',
#  'rxnfp_ft_10k_243',
#  'rxnfp_ft_10k_244',
#  'rxnfp_ft_10k_245',
#  'rxnfp_ft_10k_246',
#  'rxnfp_ft_10k_247',
#  'rxnfp_ft_10k_248',
#  'rxnfp_ft_10k_249',
#  'rxnfp_ft_10k_250',
#  'rxnfp_ft_10k_251',
#  'rxnfp_ft_10k_252',
#  'rxnfp_ft_10k_253',
#  'rxnfp_ft_10k_254',
#  'rxnfp_ft_10k_255']

# %%
len(feature_col)
# Out:
# 617

# %%
X = df_cat[feature_col]

# %%
# Lists to store the results
rmse_list = []
r2_list = []
pearson_corr_list = []
spearman_corr_list = []

for seed in range(30):
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    # Model initialization and training
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    # Predictions
    y_pred = model.predict(X_test)
    
    # Metrics calculation
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    pearson_corr, _ = pearsonr(y_test, y_pred)
    spearman_corr, _ = spearmanr(y_test, y_pred)
    
    # Store results
    rmse_list.append(rmse)
    r2_list.append(r2)
    pearson_corr_list.append(pearson_corr)
    spearman_corr_list.append(spearman_corr)
    
    print(f'Seed {seed} -> RMSE: {rmse:.4f}, R²: {r2:.4f}, Pearson: {pearson_corr:.4f}, Spearman: {spearman_corr:.4f}')

# Averages and standard deviations
average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)
average_pearson = np.mean(pearson_corr_list)
average_spearman = np.mean(spearman_corr_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)
std_pearson = np.std(pearson_corr_list)
std_spearman = np.std(spearman_corr_list)

# Final results
print(f'\nR²_mean: {average_r2:.4f}')
print(f'R²_sd: {std_r2:.4f}')
print(f'RMSE_mean: {average_rmse:.4f}')
print(f'RMSE_sd: {std_rmse:.4f}')
print(f'Pearson_corr_mean: {average_pearson:.4f}')
print(f'Pearson_corr_sd: {std_pearson:.4f}')
print(f'Spearman_corr_mean: {average_spearman:.4f}')
print(f'Spearman_corr_sd: {std_spearman:.4f}')
# Out:
# Seed 0 -> RMSE: 23.8877, R²: 0.3392, Pearson: 0.5995, Spearman: 0.5969
# Seed 1 -> RMSE: 24.3814, R²: 0.2696, Pearson: 0.5231, Spearman: 0.5097
# Seed 2 -> RMSE: 27.2679, R²: 0.1629, Pearson: 0.4343, Spearman: 0.4093
# Seed 3 -> RMSE: 23.5630, R²: 0.3259, Pearson: 0.5724, Spearman: 0.5498
# Seed 4 -> RMSE: 27.6522, R²: 0.2223, Pearson: 0.4773, Spearman: 0.4918
# Seed 5 -> RMSE: 24.5448, R²: 0.2650, Pearson: 0.5496, Spearman: 0.5433
# Seed 6 -> RMSE: 24.2286, R²: 0.2702, Pearson: 0.5280, Spearman: 0.5141
# Seed 7 -> RMSE: 23.9719, R²: 0.2824, Pearson: 0.5390, Spearman: 0.5324
# Seed 8 -> RMSE: 24.0512, R²: 0.2675, Pearson: 0.5237, Spearman: 0.5273
# Seed 9 -> RMSE: 24.4851, R²: 0.2358, Pearson: 0.5116, Spearman: 0.5122
# Seed 10 -> RMSE: 26.0086, R²: 0.1883, Pearson: 0.4712, Spearman: 0.4500
# Seed 11 -> RMSE: 26.8782, R²: 0.2140, Pearson: 0.4698, Spearman: 0.4697
# Seed 12 -> RMSE: 25.9942, R²: 0.2064, Pearson: 0.4609, Spearman: 0.4662
# Seed 13 -> RMSE: 26.1060, R²: 0.2614, Pearson: 0.5166, Spearman: 0.5266
# Seed 14 -> RMSE: 26.1664, R²: 0.2112, Pearson: 0.4763, Spearman: 0.4892
# Seed 15 -> RMSE: 26.2435, R²: 0.1643, Pearson: 0.4443, Spearman: 0.4608
# Seed 16 -> RMSE: 26.1739, R²: 0.2334, Pearson: 0.4871, Spearman: 0.4645
# Seed 17 -> RMSE: 27.7264, R²: 0.1425, Pearson: 0.4065, Spearman: 0.4080
# Seed 18 -> RMSE: 25.7298, R²: 0.2515, Pearson: 0.5126, Spearman: 0.4925
# Seed 19 -> RMSE: 23.2288, R²: 0.3449, Pearson: 0.5929, Spearman: 0.5905
# Seed 20 -> RMSE: 26.6790, R²: 0.2683, Pearson: 0.5189, Spearman: 0.5174
# Seed 21 -> RMSE: 25.8806, R²: 0.1728, Pearson: 0.4629, Spearman: 0.4505
# Seed 22 -> RMSE: 23.8450, R²: 0.3149, Pearson: 0.5636, Spearman: 0.5538
# Seed 23 -> RMSE: 24.1241, R²: 0.3293, Pearson: 0.5768, Spearman: 0.5762
# Seed 24 -> RMSE: 27.2536, R²: 0.1694, Pearson: 0.4269, Spearman: 0.4272
# Seed 25 -> RMSE: 26.3969, R²: 0.2671, Pearson: 0.5185, Spearman: 0.5249
# Seed 26 -> RMSE: 25.6544, R²: 0.2501, Pearson: 0.5099, Spearman: 0.5089
# Seed 27 -> RMSE: 23.5488, R²: 0.3241, Pearson: 0.5698, Spearman: 0.5699
# Seed 28 -> RMSE: 25.8470, R²: 0.2956, Pearson: 0.5520, Spearman: 0.5430
# Seed 29 -> RMSE: 24.0303, R²: 0.3159, Pearson: 0.5632, Spearman: 0.5566
#
# R²_mean: 0.2522
# R²_sd: 0.0568
# RMSE_mean: 25.3850
# RMSE_sd: 1.3355
# Pearson_corr_mean: 0.5120
# Pearson_corr_sd: 0.0502
# Spearman_corr_mean: 0.5078
# Spearman_corr_sd: 0.0499

# %% [markdown]
# # ReactSeq_all

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
#     if 'ReactSeq_all' in i:
#         continue
    if 'AP3_256' in i:
        continue
    if 'Drfp' in i:
        continue
    if 'rxnfp_pretrained' in i:
        continue
    if 'rxnfp_ft_10k' in i:
        continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift',
#  'ReactSeq_all_0',
#  'ReactSeq_all_1',
#  'ReactSeq_all_2',
#  'ReactSeq_all_3',
#  'ReactSeq_all_4',
#  'ReactSeq_all_5',
#  'ReactSeq_all_6',
#  'ReactSeq_all_7',
#  'ReactSeq_all_8',
#  'ReactSeq_all_9',
#  'ReactSeq_all_10',
#  'ReactSeq_all_11',
#  'ReactSeq_all_12',
#  'ReactSeq_all_13',
#  'ReactSeq_all_14',
#  'ReactSeq_all_15',
#  'ReactSeq_all_16',
#  'ReactSeq_all_17',
#  'ReactSeq_all_18',
#  'ReactSeq_all_19',
#  'ReactSeq_all_20',
#  'ReactSeq_all_21',
#  'ReactSeq_all_22',
#  'ReactSeq_all_23',
#  'ReactSeq_all_24',
#  'ReactSeq_all_25',
#  'ReactSeq_all_26',
#  'ReactSeq_all_27',
#  'ReactSeq_all_28',
#  'ReactSeq_all_29',
#  'ReactSeq_all_30',
#  'ReactSeq_all_31',
#  'ReactSeq_all_32',
#  'ReactSeq_all_33',
#  'ReactSeq_all_34',
#  'ReactSeq_all_35',
#  'ReactSeq_all_36',
#  'ReactSeq_all_37',
#  'ReactSeq_all_38',
#  'ReactSeq_all_39',
#  'ReactSeq_all_40',
#  'ReactSeq_all_41',
#  'ReactSeq_all_42',
#  'ReactSeq_all_43',
#  'ReactSeq_all_44',
#  'ReactSeq_all_45',
#  'ReactSeq_all_46',
#  'ReactSeq_all_47',
#  'ReactSeq_all_48',
#  'ReactSeq_all_49',
#  'ReactSeq_all_50',
#  'ReactSeq_all_51',
#  'ReactSeq_all_52',
#  'ReactSeq_all_53',
#  'ReactSeq_all_54',
#  'ReactSeq_all_55',
#  'ReactSeq_all_56',
#  'ReactSeq_all_57',
#  'ReactSeq_all_58',
#  'ReactSeq_all_59',
#  'ReactSeq_all_60',
#  'ReactSeq_all_61',
#  'ReactSeq_all_62',
#  'ReactSeq_all_63',
#  'ReactSeq_all_64',
#  'ReactSeq_all_65',
#  'ReactSeq_all_66',
#  'ReactSeq_all_67',
#  'ReactSeq_all_68',
#  'ReactSeq_all_69',
#  'ReactSeq_all_70',
#  'ReactSeq_all_71',
#  'ReactSeq_all_72',
#  'ReactSeq_all_73',
#  'ReactSeq_all_74',
#  'ReactSeq_all_75',
#  'ReactSeq_all_76',
#  'ReactSeq_all_77',
#  'ReactSeq_all_78',
#  'ReactSeq_all_79',
#  'ReactSeq_all_80',
#  'ReactSeq_all_81',
#  'ReactSeq_all_82',
#  'ReactSeq_all_83',
#  'ReactSeq_all_84',
#  'ReactSeq_all_85',
#  'ReactSeq_all_86',
#  'ReactSeq_all_87',
#  'ReactSeq_all_88',
#  'ReactSeq_all_89',
#  'ReactSeq_all_90',
#  'ReactSeq_all_91',
#  'ReactSeq_all_92',
#  'ReactSeq_all_93',
#  'ReactSeq_all_94',
#  'ReactSeq_all_95',
#  'ReactSeq_all_96',
#  'ReactSeq_all_97',
#  'ReactSeq_all_98',
#  'ReactSeq_all_99',
#  'ReactSeq_all_100',
#  'ReactSeq_all_101',
#  'ReactSeq_all_102',
#  'ReactSeq_all_103',
#  'ReactSeq_all_104',
#  'ReactSeq_all_105',
#  'ReactSeq_all_106',
#  'ReactSeq_all_107',
#  'ReactSeq_all_108',
#  'ReactSeq_all_109',
#  'ReactSeq_all_110',
#  'ReactSeq_all_111',
#  'ReactSeq_all_112',
#  'ReactSeq_all_113',
#  'ReactSeq_all_114',
#  'ReactSeq_all_115',
#  'ReactSeq_all_116',
#  'ReactSeq_all_117',
#  'ReactSeq_all_118',
#  'ReactSeq_all_119',
#  'ReactSeq_all_120',
#  'ReactSeq_all_121',
#  'ReactSeq_all_122',
#  'ReactSeq_all_123',
#  'ReactSeq_all_124',
#  'ReactSeq_all_125',
#  'ReactSeq_all_126',
#  'ReactSeq_all_127',
#  'ReactSeq_all_128',
#  'ReactSeq_all_129',
#  'ReactSeq_all_130',
#  'ReactSeq_all_131',
#  'ReactSeq_all_132',
#  'ReactSeq_all_133',
#  'ReactSeq_all_134',
#  'ReactSeq_all_135',
#  'ReactSeq_all_136',
#  'ReactSeq_all_137',
#  'ReactSeq_all_138',
#  'ReactSeq_all_139',
#  'ReactSeq_all_140',
#  'ReactSeq_all_141',
#  'ReactSeq_all_142',
#  'ReactSeq_all_143',
#  'ReactSeq_all_144',
#  'ReactSeq_all_145',
#  'ReactSeq_all_146',
#  'ReactSeq_all_147',
#  'ReactSeq_all_148',
#  'ReactSeq_all_149',
#  'ReactSeq_all_150',
#  'ReactSeq_all_151',
#  'ReactSeq_all_152',
#  'ReactSeq_all_153',
#  'ReactSeq_all_154',
#  'ReactSeq_all_155',
#  'ReactSeq_all_156',
#  'ReactSeq_all_157',
#  'ReactSeq_all_158',
#  'ReactSeq_all_159',
#  'ReactSeq_all_160',
#  'ReactSeq_all_161',
#  'ReactSeq_all_162',
#  'ReactSeq_all_163',
#  'ReactSeq_all_164',
#  'ReactSeq_all_165',
#  'ReactSeq_all_166',
#  'ReactSeq_all_167',
#  'ReactSeq_all_168',
#  'ReactSeq_all_169',
#  'ReactSeq_all_170',
#  'ReactSeq_all_171',
#  'ReactSeq_all_172',
#  'ReactSeq_all_173',
#  'ReactSeq_all_174',
#  'ReactSeq_all_175',
#  'ReactSeq_all_176',
#  'ReactSeq_all_177',
#  'ReactSeq_all_178',
#  'ReactSeq_all_179',
#  'ReactSeq_all_180',
#  'ReactSeq_all_181',
#  'ReactSeq_all_182',
#  'ReactSeq_all_183',
#  'ReactSeq_all_184',
#  'ReactSeq_all_185',
#  'ReactSeq_all_186',
#  'ReactSeq_all_187',
#  'ReactSeq_all_188',
#  'ReactSeq_all_189',
#  'ReactSeq_all_190',
#  'ReactSeq_all_191',
#  'ReactSeq_all_192',
#  'ReactSeq_all_193',
#  'ReactSeq_all_194',
#  'ReactSeq_all_195',
#  'ReactSeq_all_196',
#  'ReactSeq_all_197',
#  'ReactSeq_all_198',
#  'ReactSeq_all_199',
#  'ReactSeq_all_200',
#  'ReactSeq_all_201',
#  'ReactSeq_all_202',
#  'ReactSeq_all_203',
#  'ReactSeq_all_204',
#  'ReactSeq_all_205',
#  'ReactSeq_all_206',
#  'ReactSeq_all_207',
#  'ReactSeq_all_208',
#  'ReactSeq_all_209',
#  'ReactSeq_all_210',
#  'ReactSeq_all_211',
#  'ReactSeq_all_212',
#  'ReactSeq_all_213',
#  'ReactSeq_all_214',
#  'ReactSeq_all_215',
#  'ReactSeq_all_216',
#  'ReactSeq_all_217',
#  'ReactSeq_all_218',
#  'ReactSeq_all_219',
#  'ReactSeq_all_220',
#  'ReactSeq_all_221',
#  'ReactSeq_all_222',
#  'ReactSeq_all_223',
#  'ReactSeq_all_224',
#  'ReactSeq_all_225',
#  'ReactSeq_all_226',
#  'ReactSeq_all_227',
#  'ReactSeq_all_228',
#  'ReactSeq_all_229',
#  'ReactSeq_all_230',
#  'ReactSeq_all_231',
#  'ReactSeq_all_232',
#  'ReactSeq_all_233',
#  'ReactSeq_all_234',
#  'ReactSeq_all_235',
#  'ReactSeq_all_236',
#  'ReactSeq_all_237',
#  'ReactSeq_all_238',
#  'ReactSeq_all_239',
#  'ReactSeq_all_240',
#  'ReactSeq_all_241',
#  'ReactSeq_all_242',
#  'ReactSeq_all_243',
#  'ReactSeq_all_244',
#  'ReactSeq_all_245',
#  'ReactSeq_all_246',
#  'ReactSeq_all_247',
#  'ReactSeq_all_248',
#  'ReactSeq_all_249',
#  'ReactSeq_all_250',
#  'ReactSeq_all_251',
#  'ReactSeq_all_252',
#  'ReactSeq_all_253',
#  'ReactSeq_all_254',
#  'ReactSeq_all_255']

# %%
len(feature_col)
# Out:
# 617

# %%
X = df_cat[feature_col]

# %%
# Lists to store the results
rmse_list = []
r2_list = []
pearson_corr_list = []
spearman_corr_list = []

for seed in range(30):
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    # Model initialization and training
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    # Predictions
    y_pred = model.predict(X_test)
    
    # Metrics calculation
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    pearson_corr, _ = pearsonr(y_test, y_pred)
    spearman_corr, _ = spearmanr(y_test, y_pred)
    
    # Store results
    rmse_list.append(rmse)
    r2_list.append(r2)
    pearson_corr_list.append(pearson_corr)
    spearman_corr_list.append(spearman_corr)
    
    print(f'Seed {seed} -> RMSE: {rmse:.4f}, R²: {r2:.4f}, Pearson: {pearson_corr:.4f}, Spearman: {spearman_corr:.4f}')

# Averages and standard deviations
average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)
average_pearson = np.mean(pearson_corr_list)
average_spearman = np.mean(spearman_corr_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)
std_pearson = np.std(pearson_corr_list)
std_spearman = np.std(spearman_corr_list)

# Final results
print(f'\nR²_mean: {average_r2:.4f}')
print(f'R²_sd: {std_r2:.4f}')
print(f'RMSE_mean: {average_rmse:.4f}')
print(f'RMSE_sd: {std_rmse:.4f}')
print(f'Pearson_corr_mean: {average_pearson:.4f}')
print(f'Pearson_corr_sd: {std_pearson:.4f}')
print(f'Spearman_corr_mean: {average_spearman:.4f}')
print(f'Spearman_corr_sd: {std_spearman:.4f}')
# Out:
# Seed 0 -> RMSE: 24.1145, R²: 0.3266, Pearson: 0.5824, Spearman: 0.5789
# Seed 1 -> RMSE: 24.3551, R²: 0.2712, Pearson: 0.5211, Spearman: 0.5160
# Seed 2 -> RMSE: 25.8552, R²: 0.2474, Pearson: 0.5077, Spearman: 0.4909
# Seed 3 -> RMSE: 23.9499, R²: 0.3036, Pearson: 0.5513, Spearman: 0.5359
# Seed 4 -> RMSE: 27.5557, R²: 0.2277, Pearson: 0.4854, Spearman: 0.4910
# Seed 5 -> RMSE: 24.1581, R²: 0.2880, Pearson: 0.5583, Spearman: 0.5503
# Seed 6 -> RMSE: 23.0559, R²: 0.3391, Pearson: 0.5827, Spearman: 0.5795
# Seed 7 -> RMSE: 23.6540, R²: 0.3013, Pearson: 0.5571, Spearman: 0.5649
# Seed 8 -> RMSE: 23.9453, R²: 0.2739, Pearson: 0.5325, Spearman: 0.5307
# Seed 9 -> RMSE: 23.7537, R²: 0.2808, Pearson: 0.5375, Spearman: 0.5404
# Seed 10 -> RMSE: 25.6942, R²: 0.2078, Pearson: 0.4788, Spearman: 0.4539
# Seed 11 -> RMSE: 26.4857, R²: 0.2368, Pearson: 0.4919, Spearman: 0.4874
# Seed 12 -> RMSE: 24.5893, R²: 0.2899, Pearson: 0.5420, Spearman: 0.5429
# Seed 13 -> RMSE: 25.8505, R²: 0.2758, Pearson: 0.5302, Spearman: 0.5248
# Seed 14 -> RMSE: 25.4110, R²: 0.2561, Pearson: 0.5153, Spearman: 0.5155
# Seed 15 -> RMSE: 25.0446, R²: 0.2389, Pearson: 0.5023, Spearman: 0.5107
# Seed 16 -> RMSE: 25.4861, R²: 0.2732, Pearson: 0.5248, Spearman: 0.5081
# Seed 17 -> RMSE: 26.9887, R²: 0.1875, Pearson: 0.4372, Spearman: 0.4467
# Seed 18 -> RMSE: 24.9220, R²: 0.2977, Pearson: 0.5567, Spearman: 0.5431
# Seed 19 -> RMSE: 23.1374, R²: 0.3501, Pearson: 0.5987, Spearman: 0.5944
# Seed 20 -> RMSE: 25.5427, R²: 0.3293, Pearson: 0.5873, Spearman: 0.5817
# Seed 21 -> RMSE: 24.6595, R²: 0.2490, Pearson: 0.5080, Spearman: 0.4957
# Seed 22 -> RMSE: 22.8660, R²: 0.3700, Pearson: 0.6098, Spearman: 0.6125
# Seed 23 -> RMSE: 24.0557, R²: 0.3331, Pearson: 0.5823, Spearman: 0.5907
# Seed 24 -> RMSE: 26.2726, R²: 0.2282, Pearson: 0.4780, Spearman: 0.4490
# Seed 25 -> RMSE: 25.8441, R²: 0.2975, Pearson: 0.5522, Spearman: 0.5601
# Seed 26 -> RMSE: 25.0603, R²: 0.2844, Pearson: 0.5393, Spearman: 0.5414
# Seed 27 -> RMSE: 23.5800, R²: 0.3223, Pearson: 0.5684, Spearman: 0.5652
# Seed 28 -> RMSE: 25.3676, R²: 0.3215, Pearson: 0.5745, Spearman: 0.5713
# Seed 29 -> RMSE: 23.7596, R²: 0.3313, Pearson: 0.5757, Spearman: 0.5544
#
# R²_mean: 0.2847
# R²_sd: 0.0435
# RMSE_mean: 24.8338
# RMSE_sd: 1.1691
# Pearson_corr_mean: 0.5390
# Pearson_corr_sd: 0.0403
# Spearman_corr_mean: 0.5343
# Spearman_corr_sd: 0.0428

# %% [markdown]
# # ReactSeq_MEO

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
#     if 'ReactSeq_MEO' in i:
#         continue
    if 'ReactSeq_all' in i:
        continue
    if 'AP3_256' in i:
        continue
    if 'Drfp' in i:
        continue
    if 'rxnfp_pretrained' in i:
        continue
    if 'rxnfp_ft_10k' in i:
        continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift',
#  'ReactSeq_MEO_0',
#  'ReactSeq_MEO_1',
#  'ReactSeq_MEO_2',
#  'ReactSeq_MEO_3',
#  'ReactSeq_MEO_4',
#  'ReactSeq_MEO_5',
#  'ReactSeq_MEO_6',
#  'ReactSeq_MEO_7',
#  'ReactSeq_MEO_8',
#  'ReactSeq_MEO_9',
#  'ReactSeq_MEO_10',
#  'ReactSeq_MEO_11',
#  'ReactSeq_MEO_12',
#  'ReactSeq_MEO_13',
#  'ReactSeq_MEO_14',
#  'ReactSeq_MEO_15',
#  'ReactSeq_MEO_16',
#  'ReactSeq_MEO_17',
#  'ReactSeq_MEO_18',
#  'ReactSeq_MEO_19',
#  'ReactSeq_MEO_20',
#  'ReactSeq_MEO_21',
#  'ReactSeq_MEO_22',
#  'ReactSeq_MEO_23',
#  'ReactSeq_MEO_24',
#  'ReactSeq_MEO_25',
#  'ReactSeq_MEO_26',
#  'ReactSeq_MEO_27',
#  'ReactSeq_MEO_28',
#  'ReactSeq_MEO_29',
#  'ReactSeq_MEO_30',
#  'ReactSeq_MEO_31',
#  'ReactSeq_MEO_32',
#  'ReactSeq_MEO_33',
#  'ReactSeq_MEO_34',
#  'ReactSeq_MEO_35',
#  'ReactSeq_MEO_36',
#  'ReactSeq_MEO_37',
#  'ReactSeq_MEO_38',
#  'ReactSeq_MEO_39',
#  'ReactSeq_MEO_40',
#  'ReactSeq_MEO_41',
#  'ReactSeq_MEO_42',
#  'ReactSeq_MEO_43',
#  'ReactSeq_MEO_44',
#  'ReactSeq_MEO_45',
#  'ReactSeq_MEO_46',
#  'ReactSeq_MEO_47',
#  'ReactSeq_MEO_48',
#  'ReactSeq_MEO_49',
#  'ReactSeq_MEO_50',
#  'ReactSeq_MEO_51',
#  'ReactSeq_MEO_52',
#  'ReactSeq_MEO_53',
#  'ReactSeq_MEO_54',
#  'ReactSeq_MEO_55',
#  'ReactSeq_MEO_56',
#  'ReactSeq_MEO_57',
#  'ReactSeq_MEO_58',
#  'ReactSeq_MEO_59',
#  'ReactSeq_MEO_60',
#  'ReactSeq_MEO_61',
#  'ReactSeq_MEO_62',
#  'ReactSeq_MEO_63',
#  'ReactSeq_MEO_64',
#  'ReactSeq_MEO_65',
#  'ReactSeq_MEO_66',
#  'ReactSeq_MEO_67',
#  'ReactSeq_MEO_68',
#  'ReactSeq_MEO_69',
#  'ReactSeq_MEO_70',
#  'ReactSeq_MEO_71',
#  'ReactSeq_MEO_72',
#  'ReactSeq_MEO_73',
#  'ReactSeq_MEO_74',
#  'ReactSeq_MEO_75',
#  'ReactSeq_MEO_76',
#  'ReactSeq_MEO_77',
#  'ReactSeq_MEO_78',
#  'ReactSeq_MEO_79',
#  'ReactSeq_MEO_80',
#  'ReactSeq_MEO_81',
#  'ReactSeq_MEO_82',
#  'ReactSeq_MEO_83',
#  'ReactSeq_MEO_84',
#  'ReactSeq_MEO_85',
#  'ReactSeq_MEO_86',
#  'ReactSeq_MEO_87',
#  'ReactSeq_MEO_88',
#  'ReactSeq_MEO_89',
#  'ReactSeq_MEO_90',
#  'ReactSeq_MEO_91',
#  'ReactSeq_MEO_92',
#  'ReactSeq_MEO_93',
#  'ReactSeq_MEO_94',
#  'ReactSeq_MEO_95',
#  'ReactSeq_MEO_96',
#  'ReactSeq_MEO_97',
#  'ReactSeq_MEO_98',
#  'ReactSeq_MEO_99',
#  'ReactSeq_MEO_100',
#  'ReactSeq_MEO_101',
#  'ReactSeq_MEO_102',
#  'ReactSeq_MEO_103',
#  'ReactSeq_MEO_104',
#  'ReactSeq_MEO_105',
#  'ReactSeq_MEO_106',
#  'ReactSeq_MEO_107',
#  'ReactSeq_MEO_108',
#  'ReactSeq_MEO_109',
#  'ReactSeq_MEO_110',
#  'ReactSeq_MEO_111',
#  'ReactSeq_MEO_112',
#  'ReactSeq_MEO_113',
#  'ReactSeq_MEO_114',
#  'ReactSeq_MEO_115',
#  'ReactSeq_MEO_116',
#  'ReactSeq_MEO_117',
#  'ReactSeq_MEO_118',
#  'ReactSeq_MEO_119',
#  'ReactSeq_MEO_120',
#  'ReactSeq_MEO_121',
#  'ReactSeq_MEO_122',
#  'ReactSeq_MEO_123',
#  'ReactSeq_MEO_124',
#  'ReactSeq_MEO_125',
#  'ReactSeq_MEO_126',
#  'ReactSeq_MEO_127',
#  'ReactSeq_MEO_128',
#  'ReactSeq_MEO_129',
#  'ReactSeq_MEO_130',
#  'ReactSeq_MEO_131',
#  'ReactSeq_MEO_132',
#  'ReactSeq_MEO_133',
#  'ReactSeq_MEO_134',
#  'ReactSeq_MEO_135',
#  'ReactSeq_MEO_136',
#  'ReactSeq_MEO_137',
#  'ReactSeq_MEO_138',
#  'ReactSeq_MEO_139',
#  'ReactSeq_MEO_140',
#  'ReactSeq_MEO_141',
#  'ReactSeq_MEO_142',
#  'ReactSeq_MEO_143',
#  'ReactSeq_MEO_144',
#  'ReactSeq_MEO_145',
#  'ReactSeq_MEO_146',
#  'ReactSeq_MEO_147',
#  'ReactSeq_MEO_148',
#  'ReactSeq_MEO_149',
#  'ReactSeq_MEO_150',
#  'ReactSeq_MEO_151',
#  'ReactSeq_MEO_152',
#  'ReactSeq_MEO_153',
#  'ReactSeq_MEO_154',
#  'ReactSeq_MEO_155',
#  'ReactSeq_MEO_156',
#  'ReactSeq_MEO_157',
#  'ReactSeq_MEO_158',
#  'ReactSeq_MEO_159',
#  'ReactSeq_MEO_160',
#  'ReactSeq_MEO_161',
#  'ReactSeq_MEO_162',
#  'ReactSeq_MEO_163',
#  'ReactSeq_MEO_164',
#  'ReactSeq_MEO_165',
#  'ReactSeq_MEO_166',
#  'ReactSeq_MEO_167',
#  'ReactSeq_MEO_168',
#  'ReactSeq_MEO_169',
#  'ReactSeq_MEO_170',
#  'ReactSeq_MEO_171',
#  'ReactSeq_MEO_172',
#  'ReactSeq_MEO_173',
#  'ReactSeq_MEO_174',
#  'ReactSeq_MEO_175',
#  'ReactSeq_MEO_176',
#  'ReactSeq_MEO_177',
#  'ReactSeq_MEO_178',
#  'ReactSeq_MEO_179',
#  'ReactSeq_MEO_180',
#  'ReactSeq_MEO_181',
#  'ReactSeq_MEO_182',
#  'ReactSeq_MEO_183',
#  'ReactSeq_MEO_184',
#  'ReactSeq_MEO_185',
#  'ReactSeq_MEO_186',
#  'ReactSeq_MEO_187',
#  'ReactSeq_MEO_188',
#  'ReactSeq_MEO_189',
#  'ReactSeq_MEO_190',
#  'ReactSeq_MEO_191',
#  'ReactSeq_MEO_192',
#  'ReactSeq_MEO_193',
#  'ReactSeq_MEO_194',
#  'ReactSeq_MEO_195',
#  'ReactSeq_MEO_196',
#  'ReactSeq_MEO_197',
#  'ReactSeq_MEO_198',
#  'ReactSeq_MEO_199',
#  'ReactSeq_MEO_200',
#  'ReactSeq_MEO_201',
#  'ReactSeq_MEO_202',
#  'ReactSeq_MEO_203',
#  'ReactSeq_MEO_204',
#  'ReactSeq_MEO_205',
#  'ReactSeq_MEO_206',
#  'ReactSeq_MEO_207',
#  'ReactSeq_MEO_208',
#  'ReactSeq_MEO_209',
#  'ReactSeq_MEO_210',
#  'ReactSeq_MEO_211',
#  'ReactSeq_MEO_212',
#  'ReactSeq_MEO_213',
#  'ReactSeq_MEO_214',
#  'ReactSeq_MEO_215',
#  'ReactSeq_MEO_216',
#  'ReactSeq_MEO_217',
#  'ReactSeq_MEO_218',
#  'ReactSeq_MEO_219',
#  'ReactSeq_MEO_220',
#  'ReactSeq_MEO_221',
#  'ReactSeq_MEO_222',
#  'ReactSeq_MEO_223',
#  'ReactSeq_MEO_224',
#  'ReactSeq_MEO_225',
#  'ReactSeq_MEO_226',
#  'ReactSeq_MEO_227',
#  'ReactSeq_MEO_228',
#  'ReactSeq_MEO_229',
#  'ReactSeq_MEO_230',
#  'ReactSeq_MEO_231',
#  'ReactSeq_MEO_232',
#  'ReactSeq_MEO_233',
#  'ReactSeq_MEO_234',
#  'ReactSeq_MEO_235',
#  'ReactSeq_MEO_236',
#  'ReactSeq_MEO_237',
#  'ReactSeq_MEO_238',
#  'ReactSeq_MEO_239',
#  'ReactSeq_MEO_240',
#  'ReactSeq_MEO_241',
#  'ReactSeq_MEO_242',
#  'ReactSeq_MEO_243',
#  'ReactSeq_MEO_244',
#  'ReactSeq_MEO_245',
#  'ReactSeq_MEO_246',
#  'ReactSeq_MEO_247',
#  'ReactSeq_MEO_248',
#  'ReactSeq_MEO_249',
#  'ReactSeq_MEO_250',
#  'ReactSeq_MEO_251',
#  'ReactSeq_MEO_252',
#  'ReactSeq_MEO_253',
#  'ReactSeq_MEO_254',
#  'ReactSeq_MEO_255']

# %%
len(feature_col)
# Out:
# 617

# %%
X = df_cat[feature_col]

# %%
# Lists to store the results
rmse_list = []
r2_list = []
pearson_corr_list = []
spearman_corr_list = []

for seed in range(30):
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    # Model initialization and training
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    # Predictions
    y_pred = model.predict(X_test)
    
    # Metrics calculation
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    pearson_corr, _ = pearsonr(y_test, y_pred)
    spearman_corr, _ = spearmanr(y_test, y_pred)
    
    # Store results
    rmse_list.append(rmse)
    r2_list.append(r2)
    pearson_corr_list.append(pearson_corr)
    spearman_corr_list.append(spearman_corr)
    
    print(f'Seed {seed} -> RMSE: {rmse:.4f}, R²: {r2:.4f}, Pearson: {pearson_corr:.4f}, Spearman: {spearman_corr:.4f}')

# Averages and standard deviations
average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)
average_pearson = np.mean(pearson_corr_list)
average_spearman = np.mean(spearman_corr_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)
std_pearson = np.std(pearson_corr_list)
std_spearman = np.std(spearman_corr_list)

# Final results
print(f'\nR²_mean: {average_r2:.4f}')
print(f'R²_sd: {std_r2:.4f}')
print(f'RMSE_mean: {average_rmse:.4f}')
print(f'RMSE_sd: {std_rmse:.4f}')
print(f'Pearson_corr_mean: {average_pearson:.4f}')
print(f'Pearson_corr_sd: {std_pearson:.4f}')
print(f'Spearman_corr_mean: {average_spearman:.4f}')
print(f'Spearman_corr_sd: {std_spearman:.4f}')
# Out:
# Seed 0 -> RMSE: 23.8202, R²: 0.3430, Pearson: 0.6048, Spearman: 0.6062
# Seed 1 -> RMSE: 24.4841, R²: 0.2634, Pearson: 0.5146, Spearman: 0.5060
# Seed 2 -> RMSE: 25.8846, R²: 0.2457, Pearson: 0.5045, Spearman: 0.4874
# Seed 3 -> RMSE: 23.4466, R²: 0.3326, Pearson: 0.5768, Spearman: 0.5659
# Seed 4 -> RMSE: 26.7642, R²: 0.2715, Pearson: 0.5243, Spearman: 0.5348
# Seed 5 -> RMSE: 24.0665, R²: 0.2934, Pearson: 0.5672, Spearman: 0.5648
# Seed 6 -> RMSE: 23.9127, R²: 0.2891, Pearson: 0.5380, Spearman: 0.5280
# Seed 7 -> RMSE: 23.4473, R²: 0.3135, Pearson: 0.5697, Spearman: 0.5696
# Seed 8 -> RMSE: 23.4127, R²: 0.3059, Pearson: 0.5635, Spearman: 0.5600
# Seed 9 -> RMSE: 23.8259, R²: 0.2764, Pearson: 0.5369, Spearman: 0.5414
# Seed 10 -> RMSE: 25.3947, R²: 0.2261, Pearson: 0.5035, Spearman: 0.4918
# Seed 11 -> RMSE: 26.3647, R²: 0.2437, Pearson: 0.4979, Spearman: 0.4913
# Seed 12 -> RMSE: 24.8167, R²: 0.2767, Pearson: 0.5294, Spearman: 0.5344
# Seed 13 -> RMSE: 26.1394, R²: 0.2595, Pearson: 0.5143, Spearman: 0.5120
# Seed 14 -> RMSE: 25.7453, R²: 0.2364, Pearson: 0.4923, Spearman: 0.4897
# Seed 15 -> RMSE: 25.3777, R²: 0.2185, Pearson: 0.4843, Spearman: 0.4923
# Seed 16 -> RMSE: 25.4182, R²: 0.2771, Pearson: 0.5308, Spearman: 0.5133
# Seed 17 -> RMSE: 26.8824, R²: 0.1939, Pearson: 0.4470, Spearman: 0.4517
# Seed 18 -> RMSE: 25.0936, R²: 0.2880, Pearson: 0.5461, Spearman: 0.5316
# Seed 19 -> RMSE: 22.8013, R²: 0.3688, Pearson: 0.6188, Spearman: 0.6120
# Seed 20 -> RMSE: 25.3784, R²: 0.3379, Pearson: 0.5943, Spearman: 0.5959
# Seed 21 -> RMSE: 24.3710, R²: 0.2665, Pearson: 0.5222, Spearman: 0.5063
# Seed 22 -> RMSE: 23.1749, R²: 0.3528, Pearson: 0.5946, Spearman: 0.5903
# Seed 23 -> RMSE: 23.8298, R²: 0.3456, Pearson: 0.5925, Spearman: 0.6237
# Seed 24 -> RMSE: 25.7618, R²: 0.2579, Pearson: 0.5082, Spearman: 0.4878
# Seed 25 -> RMSE: 26.0690, R²: 0.2852, Pearson: 0.5398, Spearman: 0.5478
# Seed 26 -> RMSE: 24.6903, R²: 0.3054, Pearson: 0.5638, Spearman: 0.5753
# Seed 27 -> RMSE: 23.3358, R²: 0.3362, Pearson: 0.5822, Spearman: 0.5844
# Seed 28 -> RMSE: 25.4243, R²: 0.3184, Pearson: 0.5733, Spearman: 0.5633
# Seed 29 -> RMSE: 24.0279, R²: 0.3161, Pearson: 0.5628, Spearman: 0.5386
#
# R²_mean: 0.2882
# R²_sd: 0.0425
# RMSE_mean: 24.7721
# RMSE_sd: 1.1304
# Pearson_corr_mean: 0.5433
# Pearson_corr_sd: 0.0399
# Spearman_corr_mean: 0.5399
# Spearman_corr_sd: 0.0430

# %% [markdown]
# # ReactSeq_all_no_condition

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'ReactSeq_all' in i:
        feature_col.append(i)
feature_col
# Out:
# ['ReactSeq_all_0',
#  'ReactSeq_all_1',
#  'ReactSeq_all_2',
#  'ReactSeq_all_3',
#  'ReactSeq_all_4',
#  'ReactSeq_all_5',
#  'ReactSeq_all_6',
#  'ReactSeq_all_7',
#  'ReactSeq_all_8',
#  'ReactSeq_all_9',
#  'ReactSeq_all_10',
#  'ReactSeq_all_11',
#  'ReactSeq_all_12',
#  'ReactSeq_all_13',
#  'ReactSeq_all_14',
#  'ReactSeq_all_15',
#  'ReactSeq_all_16',
#  'ReactSeq_all_17',
#  'ReactSeq_all_18',
#  'ReactSeq_all_19',
#  'ReactSeq_all_20',
#  'ReactSeq_all_21',
#  'ReactSeq_all_22',
#  'ReactSeq_all_23',
#  'ReactSeq_all_24',
#  'ReactSeq_all_25',
#  'ReactSeq_all_26',
#  'ReactSeq_all_27',
#  'ReactSeq_all_28',
#  'ReactSeq_all_29',
#  'ReactSeq_all_30',
#  'ReactSeq_all_31',
#  'ReactSeq_all_32',
#  'ReactSeq_all_33',
#  'ReactSeq_all_34',
#  'ReactSeq_all_35',
#  'ReactSeq_all_36',
#  'ReactSeq_all_37',
#  'ReactSeq_all_38',
#  'ReactSeq_all_39',
#  'ReactSeq_all_40',
#  'ReactSeq_all_41',
#  'ReactSeq_all_42',
#  'ReactSeq_all_43',
#  'ReactSeq_all_44',
#  'ReactSeq_all_45',
#  'ReactSeq_all_46',
#  'ReactSeq_all_47',
#  'ReactSeq_all_48',
#  'ReactSeq_all_49',
#  'ReactSeq_all_50',
#  'ReactSeq_all_51',
#  'ReactSeq_all_52',
#  'ReactSeq_all_53',
#  'ReactSeq_all_54',
#  'ReactSeq_all_55',
#  'ReactSeq_all_56',
#  'ReactSeq_all_57',
#  'ReactSeq_all_58',
#  'ReactSeq_all_59',
#  'ReactSeq_all_60',
#  'ReactSeq_all_61',
#  'ReactSeq_all_62',
#  'ReactSeq_all_63',
#  'ReactSeq_all_64',
#  'ReactSeq_all_65',
#  'ReactSeq_all_66',
#  'ReactSeq_all_67',
#  'ReactSeq_all_68',
#  'ReactSeq_all_69',
#  'ReactSeq_all_70',
#  'ReactSeq_all_71',
#  'ReactSeq_all_72',
#  'ReactSeq_all_73',
#  'ReactSeq_all_74',
#  'ReactSeq_all_75',
#  'ReactSeq_all_76',
#  'ReactSeq_all_77',
#  'ReactSeq_all_78',
#  'ReactSeq_all_79',
#  'ReactSeq_all_80',
#  'ReactSeq_all_81',
#  'ReactSeq_all_82',
#  'ReactSeq_all_83',
#  'ReactSeq_all_84',
#  'ReactSeq_all_85',
#  'ReactSeq_all_86',
#  'ReactSeq_all_87',
#  'ReactSeq_all_88',
#  'ReactSeq_all_89',
#  'ReactSeq_all_90',
#  'ReactSeq_all_91',
#  'ReactSeq_all_92',
#  'ReactSeq_all_93',
#  'ReactSeq_all_94',
#  'ReactSeq_all_95',
#  'ReactSeq_all_96',
#  'ReactSeq_all_97',
#  'ReactSeq_all_98',
#  'ReactSeq_all_99',
#  'ReactSeq_all_100',
#  'ReactSeq_all_101',
#  'ReactSeq_all_102',
#  'ReactSeq_all_103',
#  'ReactSeq_all_104',
#  'ReactSeq_all_105',
#  'ReactSeq_all_106',
#  'ReactSeq_all_107',
#  'ReactSeq_all_108',
#  'ReactSeq_all_109',
#  'ReactSeq_all_110',
#  'ReactSeq_all_111',
#  'ReactSeq_all_112',
#  'ReactSeq_all_113',
#  'ReactSeq_all_114',
#  'ReactSeq_all_115',
#  'ReactSeq_all_116',
#  'ReactSeq_all_117',
#  'ReactSeq_all_118',
#  'ReactSeq_all_119',
#  'ReactSeq_all_120',
#  'ReactSeq_all_121',
#  'ReactSeq_all_122',
#  'ReactSeq_all_123',
#  'ReactSeq_all_124',
#  'ReactSeq_all_125',
#  'ReactSeq_all_126',
#  'ReactSeq_all_127',
#  'ReactSeq_all_128',
#  'ReactSeq_all_129',
#  'ReactSeq_all_130',
#  'ReactSeq_all_131',
#  'ReactSeq_all_132',
#  'ReactSeq_all_133',
#  'ReactSeq_all_134',
#  'ReactSeq_all_135',
#  'ReactSeq_all_136',
#  'ReactSeq_all_137',
#  'ReactSeq_all_138',
#  'ReactSeq_all_139',
#  'ReactSeq_all_140',
#  'ReactSeq_all_141',
#  'ReactSeq_all_142',
#  'ReactSeq_all_143',
#  'ReactSeq_all_144',
#  'ReactSeq_all_145',
#  'ReactSeq_all_146',
#  'ReactSeq_all_147',
#  'ReactSeq_all_148',
#  'ReactSeq_all_149',
#  'ReactSeq_all_150',
#  'ReactSeq_all_151',
#  'ReactSeq_all_152',
#  'ReactSeq_all_153',
#  'ReactSeq_all_154',
#  'ReactSeq_all_155',
#  'ReactSeq_all_156',
#  'ReactSeq_all_157',
#  'ReactSeq_all_158',
#  'ReactSeq_all_159',
#  'ReactSeq_all_160',
#  'ReactSeq_all_161',
#  'ReactSeq_all_162',
#  'ReactSeq_all_163',
#  'ReactSeq_all_164',
#  'ReactSeq_all_165',
#  'ReactSeq_all_166',
#  'ReactSeq_all_167',
#  'ReactSeq_all_168',
#  'ReactSeq_all_169',
#  'ReactSeq_all_170',
#  'ReactSeq_all_171',
#  'ReactSeq_all_172',
#  'ReactSeq_all_173',
#  'ReactSeq_all_174',
#  'ReactSeq_all_175',
#  'ReactSeq_all_176',
#  'ReactSeq_all_177',
#  'ReactSeq_all_178',
#  'ReactSeq_all_179',
#  'ReactSeq_all_180',
#  'ReactSeq_all_181',
#  'ReactSeq_all_182',
#  'ReactSeq_all_183',
#  'ReactSeq_all_184',
#  'ReactSeq_all_185',
#  'ReactSeq_all_186',
#  'ReactSeq_all_187',
#  'ReactSeq_all_188',
#  'ReactSeq_all_189',
#  'ReactSeq_all_190',
#  'ReactSeq_all_191',
#  'ReactSeq_all_192',
#  'ReactSeq_all_193',
#  'ReactSeq_all_194',
#  'ReactSeq_all_195',
#  'ReactSeq_all_196',
#  'ReactSeq_all_197',
#  'ReactSeq_all_198',
#  'ReactSeq_all_199',
#  'ReactSeq_all_200',
#  'ReactSeq_all_201',
#  'ReactSeq_all_202',
#  'ReactSeq_all_203',
#  'ReactSeq_all_204',
#  'ReactSeq_all_205',
#  'ReactSeq_all_206',
#  'ReactSeq_all_207',
#  'ReactSeq_all_208',
#  'ReactSeq_all_209',
#  'ReactSeq_all_210',
#  'ReactSeq_all_211',
#  'ReactSeq_all_212',
#  'ReactSeq_all_213',
#  'ReactSeq_all_214',
#  'ReactSeq_all_215',
#  'ReactSeq_all_216',
#  'ReactSeq_all_217',
#  'ReactSeq_all_218',
#  'ReactSeq_all_219',
#  'ReactSeq_all_220',
#  'ReactSeq_all_221',
#  'ReactSeq_all_222',
#  'ReactSeq_all_223',
#  'ReactSeq_all_224',
#  'ReactSeq_all_225',
#  'ReactSeq_all_226',
#  'ReactSeq_all_227',
#  'ReactSeq_all_228',
#  'ReactSeq_all_229',
#  'ReactSeq_all_230',
#  'ReactSeq_all_231',
#  'ReactSeq_all_232',
#  'ReactSeq_all_233',
#  'ReactSeq_all_234',
#  'ReactSeq_all_235',
#  'ReactSeq_all_236',
#  'ReactSeq_all_237',
#  'ReactSeq_all_238',
#  'ReactSeq_all_239',
#  'ReactSeq_all_240',
#  'ReactSeq_all_241',
#  'ReactSeq_all_242',
#  'ReactSeq_all_243',
#  'ReactSeq_all_244',
#  'ReactSeq_all_245',
#  'ReactSeq_all_246',
#  'ReactSeq_all_247',
#  'ReactSeq_all_248',
#  'ReactSeq_all_249',
#  'ReactSeq_all_250',
#  'ReactSeq_all_251',
#  'ReactSeq_all_252',
#  'ReactSeq_all_253',
#  'ReactSeq_all_254',
#  'ReactSeq_all_255']

# %%
len(feature_col)
# Out:
# 256

# %%
X = df_cat[feature_col]

# %%
# Lists to store the results
rmse_list = []
r2_list = []
pearson_corr_list = []
spearman_corr_list = []

for seed in range(30):
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    # Model initialization and training
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    # Predictions
    y_pred = model.predict(X_test)
    
    # Metrics calculation
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    pearson_corr, _ = pearsonr(y_test, y_pred)
    spearman_corr, _ = spearmanr(y_test, y_pred)
    
    # Store results
    rmse_list.append(rmse)
    r2_list.append(r2)
    pearson_corr_list.append(pearson_corr)
    spearman_corr_list.append(spearman_corr)
    
    print(f'Seed {seed} -> RMSE: {rmse:.4f}, R²: {r2:.4f}, Pearson: {pearson_corr:.4f}, Spearman: {spearman_corr:.4f}')

# Averages and standard deviations
average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)
average_pearson = np.mean(pearson_corr_list)
average_spearman = np.mean(spearman_corr_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)
std_pearson = np.std(pearson_corr_list)
std_spearman = np.std(spearman_corr_list)

# Final results
print(f'\nR²_mean: {average_r2:.4f}')
print(f'R²_sd: {std_r2:.4f}')
print(f'RMSE_mean: {average_rmse:.4f}')
print(f'RMSE_sd: {std_rmse:.4f}')
print(f'Pearson_corr_mean: {average_pearson:.4f}')
print(f'Pearson_corr_sd: {std_pearson:.4f}')
print(f'Spearman_corr_mean: {average_spearman:.4f}')
print(f'Spearman_corr_sd: {std_spearman:.4f}')
# Out:
# Seed 0 -> RMSE: 25.6554, R²: 0.2378, Pearson: 0.4943, Spearman: 0.4994
# Seed 1 -> RMSE: 23.8926, R²: 0.2986, Pearson: 0.5494, Spearman: 0.5451
# Seed 2 -> RMSE: 25.2240, R²: 0.2837, Pearson: 0.5380, Spearman: 0.5464
# Seed 3 -> RMSE: 25.2083, R²: 0.2285, Pearson: 0.4820, Spearman: 0.4777
# Seed 4 -> RMSE: 28.6408, R²: 0.1657, Pearson: 0.4256, Spearman: 0.4392
# Seed 5 -> RMSE: 25.8547, R²: 0.1845, Pearson: 0.4569, Spearman: 0.4499
# Seed 6 -> RMSE: 23.9666, R²: 0.2859, Pearson: 0.5349, Spearman: 0.5407
# Seed 7 -> RMSE: 25.0514, R²: 0.2163, Pearson: 0.4853, Spearman: 0.4936
# Seed 8 -> RMSE: 24.5106, R²: 0.2392, Pearson: 0.5006, Spearman: 0.5123
# Seed 9 -> RMSE: 24.2069, R²: 0.2531, Pearson: 0.5173, Spearman: 0.5175
# Seed 10 -> RMSE: 25.7013, R²: 0.2074, Pearson: 0.4708, Spearman: 0.4626
# Seed 11 -> RMSE: 27.0373, R²: 0.2046, Pearson: 0.4533, Spearman: 0.4683
# Seed 12 -> RMSE: 26.2337, R²: 0.1917, Pearson: 0.4477, Spearman: 0.4414
# Seed 13 -> RMSE: 26.7526, R²: 0.2243, Pearson: 0.4782, Spearman: 0.4659
# Seed 14 -> RMSE: 26.2960, R²: 0.2034, Pearson: 0.4557, Spearman: 0.4387
# Seed 15 -> RMSE: 24.5542, R²: 0.2684, Pearson: 0.5233, Spearman: 0.5303
# Seed 16 -> RMSE: 26.1154, R²: 0.2369, Pearson: 0.4932, Spearman: 0.5019
# Seed 17 -> RMSE: 26.3901, R²: 0.2231, Pearson: 0.4731, Spearman: 0.4897
# Seed 18 -> RMSE: 25.7254, R²: 0.2517, Pearson: 0.5224, Spearman: 0.5275
# Seed 19 -> RMSE: 25.0160, R²: 0.2402, Pearson: 0.4950, Spearman: 0.4923
# Seed 20 -> RMSE: 27.9380, R²: 0.1977, Pearson: 0.4496, Spearman: 0.4588
# Seed 21 -> RMSE: 25.5214, R²: 0.1956, Pearson: 0.4516, Spearman: 0.4656
# Seed 22 -> RMSE: 23.9308, R²: 0.3099, Pearson: 0.5594, Spearman: 0.5625
# Seed 23 -> RMSE: 25.8800, R²: 0.2281, Pearson: 0.4792, Spearman: 0.5052
# Seed 24 -> RMSE: 27.5148, R²: 0.1535, Pearson: 0.4050, Spearman: 0.3986
# Seed 25 -> RMSE: 26.8127, R²: 0.2438, Pearson: 0.4992, Spearman: 0.5263
# Seed 26 -> RMSE: 26.4805, R²: 0.2010, Pearson: 0.4580, Spearman: 0.4704
# Seed 27 -> RMSE: 24.6025, R²: 0.2622, Pearson: 0.5130, Spearman: 0.5012
# Seed 28 -> RMSE: 27.0497, R²: 0.2285, Pearson: 0.4815, Spearman: 0.4916
# Seed 29 -> RMSE: 25.4868, R²: 0.2305, Pearson: 0.4843, Spearman: 0.4610
#
# R²_mean: 0.2299
# R²_sd: 0.0364
# RMSE_mean: 25.7750
# RMSE_sd: 1.1789
# Pearson_corr_mean: 0.4859
# Pearson_corr_sd: 0.0355
# Spearman_corr_mean: 0.4894
# Spearman_corr_sd: 0.0376

# %% [markdown]
# # ReactSeq_MEO_no_condition

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'ReactSeq_MEO' in i:
        feature_col.append(i)
feature_col
# Out:
# ['ReactSeq_MEO_0',
#  'ReactSeq_MEO_1',
#  'ReactSeq_MEO_2',
#  'ReactSeq_MEO_3',
#  'ReactSeq_MEO_4',
#  'ReactSeq_MEO_5',
#  'ReactSeq_MEO_6',
#  'ReactSeq_MEO_7',
#  'ReactSeq_MEO_8',
#  'ReactSeq_MEO_9',
#  'ReactSeq_MEO_10',
#  'ReactSeq_MEO_11',
#  'ReactSeq_MEO_12',
#  'ReactSeq_MEO_13',
#  'ReactSeq_MEO_14',
#  'ReactSeq_MEO_15',
#  'ReactSeq_MEO_16',
#  'ReactSeq_MEO_17',
#  'ReactSeq_MEO_18',
#  'ReactSeq_MEO_19',
#  'ReactSeq_MEO_20',
#  'ReactSeq_MEO_21',
#  'ReactSeq_MEO_22',
#  'ReactSeq_MEO_23',
#  'ReactSeq_MEO_24',
#  'ReactSeq_MEO_25',
#  'ReactSeq_MEO_26',
#  'ReactSeq_MEO_27',
#  'ReactSeq_MEO_28',
#  'ReactSeq_MEO_29',
#  'ReactSeq_MEO_30',
#  'ReactSeq_MEO_31',
#  'ReactSeq_MEO_32',
#  'ReactSeq_MEO_33',
#  'ReactSeq_MEO_34',
#  'ReactSeq_MEO_35',
#  'ReactSeq_MEO_36',
#  'ReactSeq_MEO_37',
#  'ReactSeq_MEO_38',
#  'ReactSeq_MEO_39',
#  'ReactSeq_MEO_40',
#  'ReactSeq_MEO_41',
#  'ReactSeq_MEO_42',
#  'ReactSeq_MEO_43',
#  'ReactSeq_MEO_44',
#  'ReactSeq_MEO_45',
#  'ReactSeq_MEO_46',
#  'ReactSeq_MEO_47',
#  'ReactSeq_MEO_48',
#  'ReactSeq_MEO_49',
#  'ReactSeq_MEO_50',
#  'ReactSeq_MEO_51',
#  'ReactSeq_MEO_52',
#  'ReactSeq_MEO_53',
#  'ReactSeq_MEO_54',
#  'ReactSeq_MEO_55',
#  'ReactSeq_MEO_56',
#  'ReactSeq_MEO_57',
#  'ReactSeq_MEO_58',
#  'ReactSeq_MEO_59',
#  'ReactSeq_MEO_60',
#  'ReactSeq_MEO_61',
#  'ReactSeq_MEO_62',
#  'ReactSeq_MEO_63',
#  'ReactSeq_MEO_64',
#  'ReactSeq_MEO_65',
#  'ReactSeq_MEO_66',
#  'ReactSeq_MEO_67',
#  'ReactSeq_MEO_68',
#  'ReactSeq_MEO_69',
#  'ReactSeq_MEO_70',
#  'ReactSeq_MEO_71',
#  'ReactSeq_MEO_72',
#  'ReactSeq_MEO_73',
#  'ReactSeq_MEO_74',
#  'ReactSeq_MEO_75',
#  'ReactSeq_MEO_76',
#  'ReactSeq_MEO_77',
#  'ReactSeq_MEO_78',
#  'ReactSeq_MEO_79',
#  'ReactSeq_MEO_80',
#  'ReactSeq_MEO_81',
#  'ReactSeq_MEO_82',
#  'ReactSeq_MEO_83',
#  'ReactSeq_MEO_84',
#  'ReactSeq_MEO_85',
#  'ReactSeq_MEO_86',
#  'ReactSeq_MEO_87',
#  'ReactSeq_MEO_88',
#  'ReactSeq_MEO_89',
#  'ReactSeq_MEO_90',
#  'ReactSeq_MEO_91',
#  'ReactSeq_MEO_92',
#  'ReactSeq_MEO_93',
#  'ReactSeq_MEO_94',
#  'ReactSeq_MEO_95',
#  'ReactSeq_MEO_96',
#  'ReactSeq_MEO_97',
#  'ReactSeq_MEO_98',
#  'ReactSeq_MEO_99',
#  'ReactSeq_MEO_100',
#  'ReactSeq_MEO_101',
#  'ReactSeq_MEO_102',
#  'ReactSeq_MEO_103',
#  'ReactSeq_MEO_104',
#  'ReactSeq_MEO_105',
#  'ReactSeq_MEO_106',
#  'ReactSeq_MEO_107',
#  'ReactSeq_MEO_108',
#  'ReactSeq_MEO_109',
#  'ReactSeq_MEO_110',
#  'ReactSeq_MEO_111',
#  'ReactSeq_MEO_112',
#  'ReactSeq_MEO_113',
#  'ReactSeq_MEO_114',
#  'ReactSeq_MEO_115',
#  'ReactSeq_MEO_116',
#  'ReactSeq_MEO_117',
#  'ReactSeq_MEO_118',
#  'ReactSeq_MEO_119',
#  'ReactSeq_MEO_120',
#  'ReactSeq_MEO_121',
#  'ReactSeq_MEO_122',
#  'ReactSeq_MEO_123',
#  'ReactSeq_MEO_124',
#  'ReactSeq_MEO_125',
#  'ReactSeq_MEO_126',
#  'ReactSeq_MEO_127',
#  'ReactSeq_MEO_128',
#  'ReactSeq_MEO_129',
#  'ReactSeq_MEO_130',
#  'ReactSeq_MEO_131',
#  'ReactSeq_MEO_132',
#  'ReactSeq_MEO_133',
#  'ReactSeq_MEO_134',
#  'ReactSeq_MEO_135',
#  'ReactSeq_MEO_136',
#  'ReactSeq_MEO_137',
#  'ReactSeq_MEO_138',
#  'ReactSeq_MEO_139',
#  'ReactSeq_MEO_140',
#  'ReactSeq_MEO_141',
#  'ReactSeq_MEO_142',
#  'ReactSeq_MEO_143',
#  'ReactSeq_MEO_144',
#  'ReactSeq_MEO_145',
#  'ReactSeq_MEO_146',
#  'ReactSeq_MEO_147',
#  'ReactSeq_MEO_148',
#  'ReactSeq_MEO_149',
#  'ReactSeq_MEO_150',
#  'ReactSeq_MEO_151',
#  'ReactSeq_MEO_152',
#  'ReactSeq_MEO_153',
#  'ReactSeq_MEO_154',
#  'ReactSeq_MEO_155',
#  'ReactSeq_MEO_156',
#  'ReactSeq_MEO_157',
#  'ReactSeq_MEO_158',
#  'ReactSeq_MEO_159',
#  'ReactSeq_MEO_160',
#  'ReactSeq_MEO_161',
#  'ReactSeq_MEO_162',
#  'ReactSeq_MEO_163',
#  'ReactSeq_MEO_164',
#  'ReactSeq_MEO_165',
#  'ReactSeq_MEO_166',
#  'ReactSeq_MEO_167',
#  'ReactSeq_MEO_168',
#  'ReactSeq_MEO_169',
#  'ReactSeq_MEO_170',
#  'ReactSeq_MEO_171',
#  'ReactSeq_MEO_172',
#  'ReactSeq_MEO_173',
#  'ReactSeq_MEO_174',
#  'ReactSeq_MEO_175',
#  'ReactSeq_MEO_176',
#  'ReactSeq_MEO_177',
#  'ReactSeq_MEO_178',
#  'ReactSeq_MEO_179',
#  'ReactSeq_MEO_180',
#  'ReactSeq_MEO_181',
#  'ReactSeq_MEO_182',
#  'ReactSeq_MEO_183',
#  'ReactSeq_MEO_184',
#  'ReactSeq_MEO_185',
#  'ReactSeq_MEO_186',
#  'ReactSeq_MEO_187',
#  'ReactSeq_MEO_188',
#  'ReactSeq_MEO_189',
#  'ReactSeq_MEO_190',
#  'ReactSeq_MEO_191',
#  'ReactSeq_MEO_192',
#  'ReactSeq_MEO_193',
#  'ReactSeq_MEO_194',
#  'ReactSeq_MEO_195',
#  'ReactSeq_MEO_196',
#  'ReactSeq_MEO_197',
#  'ReactSeq_MEO_198',
#  'ReactSeq_MEO_199',
#  'ReactSeq_MEO_200',
#  'ReactSeq_MEO_201',
#  'ReactSeq_MEO_202',
#  'ReactSeq_MEO_203',
#  'ReactSeq_MEO_204',
#  'ReactSeq_MEO_205',
#  'ReactSeq_MEO_206',
#  'ReactSeq_MEO_207',
#  'ReactSeq_MEO_208',
#  'ReactSeq_MEO_209',
#  'ReactSeq_MEO_210',
#  'ReactSeq_MEO_211',
#  'ReactSeq_MEO_212',
#  'ReactSeq_MEO_213',
#  'ReactSeq_MEO_214',
#  'ReactSeq_MEO_215',
#  'ReactSeq_MEO_216',
#  'ReactSeq_MEO_217',
#  'ReactSeq_MEO_218',
#  'ReactSeq_MEO_219',
#  'ReactSeq_MEO_220',
#  'ReactSeq_MEO_221',
#  'ReactSeq_MEO_222',
#  'ReactSeq_MEO_223',
#  'ReactSeq_MEO_224',
#  'ReactSeq_MEO_225',
#  'ReactSeq_MEO_226',
#  'ReactSeq_MEO_227',
#  'ReactSeq_MEO_228',
#  'ReactSeq_MEO_229',
#  'ReactSeq_MEO_230',
#  'ReactSeq_MEO_231',
#  'ReactSeq_MEO_232',
#  'ReactSeq_MEO_233',
#  'ReactSeq_MEO_234',
#  'ReactSeq_MEO_235',
#  'ReactSeq_MEO_236',
#  'ReactSeq_MEO_237',
#  'ReactSeq_MEO_238',
#  'ReactSeq_MEO_239',
#  'ReactSeq_MEO_240',
#  'ReactSeq_MEO_241',
#  'ReactSeq_MEO_242',
#  'ReactSeq_MEO_243',
#  'ReactSeq_MEO_244',
#  'ReactSeq_MEO_245',
#  'ReactSeq_MEO_246',
#  'ReactSeq_MEO_247',
#  'ReactSeq_MEO_248',
#  'ReactSeq_MEO_249',
#  'ReactSeq_MEO_250',
#  'ReactSeq_MEO_251',
#  'ReactSeq_MEO_252',
#  'ReactSeq_MEO_253',
#  'ReactSeq_MEO_254',
#  'ReactSeq_MEO_255']

# %%
len(feature_col)
# Out:
# 256

# %%
X = df_cat[feature_col]

# %%
# Lists to store the results
rmse_list = []
r2_list = []
pearson_corr_list = []
spearman_corr_list = []

for seed in range(30):
    # Splitting the dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    # Model initialization and training
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    # Predictions
    y_pred = model.predict(X_test)
    
    # Metrics calculation
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    pearson_corr, _ = pearsonr(y_test, y_pred)
    spearman_corr, _ = spearmanr(y_test, y_pred)
    
    # Store results
    rmse_list.append(rmse)
    r2_list.append(r2)
    pearson_corr_list.append(pearson_corr)
    spearman_corr_list.append(spearman_corr)
    
    print(f'Seed {seed} -> RMSE: {rmse:.4f}, R²: {r2:.4f}, Pearson: {pearson_corr:.4f}, Spearman: {spearman_corr:.4f}')

# Averages and standard deviations
average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)
average_pearson = np.mean(pearson_corr_list)
average_spearman = np.mean(spearman_corr_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)
std_pearson = np.std(pearson_corr_list)
std_spearman = np.std(spearman_corr_list)

# Final results
print(f'\nR²_mean: {average_r2:.4f}')
print(f'R²_sd: {std_r2:.4f}')
print(f'RMSE_mean: {average_rmse:.4f}')
print(f'RMSE_sd: {std_rmse:.4f}')
print(f'Pearson_corr_mean: {average_pearson:.4f}')
print(f'Pearson_corr_sd: {std_pearson:.4f}')
print(f'Spearman_corr_mean: {average_spearman:.4f}')
print(f'Spearman_corr_sd: {std_spearman:.4f}')
# Out:
# Seed 0 -> RMSE: 25.3210, R²: 0.2576, Pearson: 0.5159, Spearman: 0.5252
# Seed 1 -> RMSE: 23.3457, R²: 0.3303, Pearson: 0.5799, Spearman: 0.5834
# Seed 2 -> RMSE: 25.5529, R²: 0.2649, Pearson: 0.5170, Spearman: 0.5172
# Seed 3 -> RMSE: 25.7054, R²: 0.1978, Pearson: 0.4542, Spearman: 0.4504
# Seed 4 -> RMSE: 27.9617, R²: 0.2048, Pearson: 0.4579, Spearman: 0.4554
# Seed 5 -> RMSE: 25.5339, R²: 0.2046, Pearson: 0.4828, Spearman: 0.4845
# Seed 6 -> RMSE: 23.5990, R²: 0.3076, Pearson: 0.5549, Spearman: 0.5468
# Seed 7 -> RMSE: 24.8489, R²: 0.2289, Pearson: 0.4935, Spearman: 0.4844
# Seed 8 -> RMSE: 24.8353, R²: 0.2189, Pearson: 0.4798, Spearman: 0.4865
# Seed 9 -> RMSE: 24.7526, R²: 0.2191, Pearson: 0.4870, Spearman: 0.4983
# Seed 10 -> RMSE: 25.6535, R²: 0.2103, Pearson: 0.4796, Spearman: 0.4602
# Seed 11 -> RMSE: 27.4522, R²: 0.1800, Pearson: 0.4253, Spearman: 0.4258
# Seed 12 -> RMSE: 25.6472, R²: 0.2275, Pearson: 0.4793, Spearman: 0.4815
# Seed 13 -> RMSE: 27.2704, R²: 0.1940, Pearson: 0.4480, Spearman: 0.4261
# Seed 14 -> RMSE: 27.0510, R²: 0.1570, Pearson: 0.4131, Spearman: 0.3961
# Seed 15 -> RMSE: 24.8518, R²: 0.2506, Pearson: 0.5067, Spearman: 0.5148
# Seed 16 -> RMSE: 25.1498, R²: 0.2922, Pearson: 0.5580, Spearman: 0.5547
# Seed 17 -> RMSE: 26.4049, R²: 0.2223, Pearson: 0.4724, Spearman: 0.4738
# Seed 18 -> RMSE: 25.5785, R²: 0.2602, Pearson: 0.5252, Spearman: 0.5312
# Seed 19 -> RMSE: 24.4713, R²: 0.2730, Pearson: 0.5264, Spearman: 0.5181
# Seed 20 -> RMSE: 27.1651, R²: 0.2414, Pearson: 0.4954, Spearman: 0.4930
# Seed 21 -> RMSE: 25.1764, R²: 0.2172, Pearson: 0.4704, Spearman: 0.4778
# Seed 22 -> RMSE: 24.3923, R²: 0.2831, Pearson: 0.5335, Spearman: 0.5263
# Seed 23 -> RMSE: 25.9517, R²: 0.2238, Pearson: 0.4762, Spearman: 0.5089
# Seed 24 -> RMSE: 27.2454, R²: 0.1699, Pearson: 0.4171, Spearman: 0.3806
# Seed 25 -> RMSE: 26.4129, R²: 0.2662, Pearson: 0.5207, Spearman: 0.5442
# Seed 26 -> RMSE: 26.2445, R²: 0.2152, Pearson: 0.4717, Spearman: 0.4779
# Seed 27 -> RMSE: 24.5195, R²: 0.2672, Pearson: 0.5182, Spearman: 0.5188
# Seed 28 -> RMSE: 26.5802, R²: 0.2550, Pearson: 0.5085, Spearman: 0.4993
# Seed 29 -> RMSE: 24.7834, R²: 0.2724, Pearson: 0.5223, Spearman: 0.5002
#
# R²_mean: 0.2371
# R²_sd: 0.0399
# RMSE_mean: 25.6486
# RMSE_sd: 1.1308
# Pearson_corr_mean: 0.4930
# Pearson_corr_sd: 0.0396
# Spearman_corr_mean: 0.4914
# Spearman_corr_sd: 0.0448
