# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
df_cat = pd.read_csv('./ELN_reaction_representation.csv')
# Out:
# /tmp/ipykernel_3816447/614745552.py:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cat = pd.read_csv('./ELN_reaction_representation.csv')

# %%
y = df_cat['yield']
y
# Out:
# 0      65.39
# 1      57.47
# 2      65.43
# 3      75.07
# 4      46.32
#        ...
# 744    42.82
# 745    42.75
# 746    46.13
# 747    24.34
# 748    29.00
# Name: yield, Length: 749, dtype: float64

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
    if 'ReactSeq_all' in i:
        continue
    if 'AP3_256' in i:
        continue
    if 'Drfp' in i:
        continue
    if 'rxnfp_pretrained' in i:
        continue
    if 'rxnfp_ft_10k' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'halide_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'amine_MaxEStateIndex',
#  'amine_MinEStateIndex',
#  'amine_MaxAbsEStateIndex',
#  'amine_MinAbsEStateIndex',
#  'amine_qed',
#  'amine_MolWt',
#  'amine_HeavyAtomMolWt',
#  'amine_ExactMolWt',
#  'amine_NumValenceElectrons',
#  'amine_MaxPartialCharge',
#  'amine_MinPartialCharge',
#  'amine_MaxAbsPartialCharge',
#  'amine_MinAbsPartialCharge',
#  'amine_FpDensityMorgan1',
#  'amine_FpDensityMorgan2',
#  'amine_FpDensityMorgan3',
#  'amine_BCUT2D_MWHI',
#  'amine_BCUT2D_MWLOW',
#  'amine_BCUT2D_CHGHI',
#  'amine_BCUT2D_CHGLO',
#  'amine_BCUT2D_LOGPHI',
#  'amine_BCUT2D_LOGPLOW',
#  'amine_BCUT2D_MRHI',
#  'amine_BCUT2D_MRLOW',
#  'amine_BalabanJ',
#  'amine_BertzCT',
#  'amine_Chi0',
#  'amine_Chi0n',
#  'amine_Chi0v',
#  'amine_Chi1',
#  'amine_Chi1n',
#  'amine_Chi1v',
#  'amine_Chi2n',
#  'amine_Chi2v',
#  'amine_Chi3n',
#  'amine_Chi3v',
#  'amine_Chi4n',
#  'amine_Chi4v',
#  'amine_HallKierAlpha',
#  'amine_Ipc',
#  'amine_Kappa1',
#  'amine_Kappa2',
#  'amine_Kappa3',
#  'amine_LabuteASA',
#  'amine_PEOE_VSA1',
#  'amine_PEOE_VSA10',
#  'amine_PEOE_VSA11',
#  'amine_PEOE_VSA12',
#  'amine_PEOE_VSA13',
#  'amine_PEOE_VSA14',
#  'amine_PEOE_VSA2',
#  'amine_PEOE_VSA3',
#  'amine_PEOE_VSA4',
#  'amine_PEOE_VSA5',
#  'amine_PEOE_VSA6',
#  'amine_PEOE_VSA7',
#  'amine_PEOE_VSA8',
#  'amine_PEOE_VSA9',
#  'amine_SMR_VSA1',
#  'amine_SMR_VSA10',
#  'amine_SMR_VSA2',
#  'amine_SMR_VSA3',
#  'amine_SMR_VSA4',
#  'amine_SMR_VSA5',
#  'amine_SMR_VSA6',
#  'amine_SMR_VSA7',
#  'amine_SMR_VSA9',
#  'amine_SlogP_VSA1',
#  'amine_SlogP_VSA10',
#  'amine_SlogP_VSA11',
#  'amine_SlogP_VSA12',
#  'amine_SlogP_VSA2',
#  'amine_SlogP_VSA3',
#  'amine_SlogP_VSA4',
#  'amine_SlogP_VSA5',
#  'amine_SlogP_VSA6',
#  'amine_SlogP_VSA7',
#  'amine_SlogP_VSA8',
#  'amine_TPSA',
#  'amine_EState_VSA1',
#  'amine_EState_VSA10',
#  'amine_EState_VSA11',
#  'amine_EState_VSA2',
#  'amine_EState_VSA3',
#  'amine_EState_VSA4',
#  'amine_EState_VSA5',
#  'amine_EState_VSA6',
#  'amine_EState_VSA8',
#  'amine_EState_VSA9',
#  'amine_VSA_EState1',
#  'amine_VSA_EState10',
#  'amine_VSA_EState2',
#  'amine_VSA_EState3',
#  'amine_VSA_EState4',
#  'amine_VSA_EState5',
#  'amine_VSA_EState6',
#  'amine_VSA_EState7',
#  'amine_VSA_EState8',
#  'amine_VSA_EState9',
#  'amine_FractionCSP3',
#  'amine_HeavyAtomCount',
#  'amine_NHOHCount',
#  'amine_NOCount',
#  'amine_NumAliphaticCarbocycles',
#  'amine_NumAliphaticHeterocycles',
#  'amine_NumAliphaticRings',
#  'amine_NumAromaticCarbocycles',
#  'amine_NumAromaticHeterocycles',
#  'amine_NumAromaticRings',
#  'amine_NumHAcceptors',
#  'amine_NumHDonors',
#  'amine_NumHeteroatoms',
#  'amine_NumRotatableBonds',
#  'amine_NumSaturatedCarbocycles',
#  'amine_NumSaturatedHeterocycles',
#  'amine_NumSaturatedRings',
#  'amine_RingCount',
#  'amine_MolLogP',
#  'amine_MolMR',
#  'amine_fr_Al_OH',
#  'amine_fr_ArN',
#  'amine_fr_Ar_N',
#  'amine_fr_Ar_NH',
#  'amine_fr_C_O',
#  'amine_fr_C_O_noCOO',
#  'amine_fr_HOCCN',
#  'amine_fr_Imine',
#  'amine_fr_NH0',
#  'amine_fr_NH1',
#  'amine_fr_NH2',
#  'amine_fr_N_O',
#  'amine_fr_Ndealkylation1',
#  'amine_fr_Ndealkylation2',
#  'amine_fr_Nhpyrrole',
#  'amine_fr_aldehyde',
#  'amine_fr_alkyl_carbamate',
#  'amine_fr_alkyl_halide',
#  'amine_fr_allylic_oxid',
#  'amine_fr_amide',
#  'amine_fr_aniline',
#  'amine_fr_aryl_methyl',
#  'amine_fr_benzene',
#  'amine_fr_bicyclic',
#  'amine_fr_ester',
#  'amine_fr_ether',
#  'amine_fr_halogen',
#  'amine_fr_imidazole',
#  'amine_fr_ketone',
#  'amine_fr_ketone_Topliss',
#  'amine_fr_lactone',
#  'amine_fr_methoxy',
#  'amine_fr_morpholine',
#  'amine_fr_nitrile',
#  'amine_fr_nitro',
#  'amine_fr_nitro_arom',
#  'amine_fr_oxazole',
#  'amine_fr_para_hydroxylation',
#  'amine_fr_piperdine',
#  'amine_fr_piperzine',
#  'amine_fr_priamide',
#  'amine_fr_pyridine',
#  'amine_fr_sulfonamd',
#  'amine_fr_sulfone',
#  'amine_fr_thiazole',
#  'amine_fr_urea',
#  'amine_molecular_weight',
#  'amine_molecular_volume',
#  'amine_surface_area',
#  'amine_ovality',
#  'amine_hardness',
#  'amine_dipole_moment',
#  'amine_electronegativity',
#  'amine_E_HOMO',
#  'amine_E_LOMO',
#  'amine_.N1_electrostatic_charge',
#  'amine_.N1_NMR_shift',
#  'amine_.C1_electrostatic_charge',
#  'amine_.C1_NMR_shift',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'product_MaxEStateIndex',
#  'product_MinEStateIndex',
#  'product_MaxAbsEStateIndex',
#  'product_MinAbsEStateIndex',
#  'product_qed',
#  'product_MolWt',
#  'product_HeavyAtomMolWt',
#  'product_ExactMolWt',
#  'product_NumValenceElectrons',
#  'product_MaxPartialCharge',
#  'product_MinPartialCharge',
#  'product_MaxAbsPartialCharge',
#  'product_MinAbsPartialCharge',
#  'product_FpDensityMorgan1',
#  'product_FpDensityMorgan2',
#  'product_FpDensityMorgan3',
#  'product_BCUT2D_MWHI',
#  'product_BCUT2D_MWLOW',
#  'product_BCUT2D_CHGHI',
#  'product_BCUT2D_CHGLO',
#  'product_BCUT2D_LOGPHI',
#  'product_BCUT2D_LOGPLOW',
#  'product_BCUT2D_MRHI',
#  'product_BCUT2D_MRLOW',
#  'product_BalabanJ',
#  'product_BertzCT',
#  'product_Chi0',
#  'product_Chi0n',
#  'product_Chi0v',
#  'product_Chi1',
#  'product_Chi1n',
#  'product_Chi1v',
#  'product_Chi2n',
#  'product_Chi2v',
#  'product_Chi3n',
#  'product_Chi3v',
#  'product_Chi4n',
#  'product_Chi4v',
#  'product_HallKierAlpha',
#  'product_Ipc',
#  'product_Kappa1',
#  'product_Kappa2',
#  'product_Kappa3',
#  'product_LabuteASA',
#  'product_PEOE_VSA1',
#  'product_PEOE_VSA10',
#  'product_PEOE_VSA11',
#  'product_PEOE_VSA12',
#  'product_PEOE_VSA13',
#  'product_PEOE_VSA14',
#  'product_PEOE_VSA2',
#  'product_PEOE_VSA3',
#  'product_PEOE_VSA4',
#  'product_PEOE_VSA5',
#  'product_PEOE_VSA6',
#  'product_PEOE_VSA7',
#  'product_PEOE_VSA8',
#  'product_PEOE_VSA9',
#  'product_SMR_VSA1',
#  'product_SMR_VSA10',
#  'product_SMR_VSA2',
#  'product_SMR_VSA3',
#  'product_SMR_VSA4',
#  'product_SMR_VSA5',
#  'product_SMR_VSA6',
#  'product_SMR_VSA7',
#  'product_SMR_VSA9',
#  'product_SlogP_VSA1',
#  'product_SlogP_VSA10',
#  'product_SlogP_VSA11',
#  'product_SlogP_VSA12',
#  'product_SlogP_VSA2',
#  'product_SlogP_VSA3',
#  'product_SlogP_VSA4',
#  'product_SlogP_VSA5',
#  'product_SlogP_VSA6',
#  'product_SlogP_VSA7',
#  'product_SlogP_VSA8',
#  'product_TPSA',
#  'product_EState_VSA1',
#  'product_EState_VSA10',
#  'product_EState_VSA11',
#  'product_EState_VSA2',
#  'product_EState_VSA3',
#  'product_EState_VSA4',
#  'product_EState_VSA5',
#  'product_EState_VSA6',
#  'product_EState_VSA8',
#  'product_EState_VSA9',
#  'product_VSA_EState1',
#  'product_VSA_EState10',
#  'product_VSA_EState2',
#  'product_VSA_EState3',
#  'product_VSA_EState4',
#  'product_VSA_EState5',
#  'product_VSA_EState6',
#  'product_VSA_EState7',
#  'product_VSA_EState8',
#  'product_VSA_EState9',
#  'product_FractionCSP3',
#  'product_HeavyAtomCount',
#  'product_NHOHCount',
#  'product_NOCount',
#  'product_NumAliphaticCarbocycles',
#  'product_NumAliphaticHeterocycles',
#  'product_NumAliphaticRings',
#  'product_NumAromaticCarbocycles',
#  'product_NumAromaticHeterocycles',
#  'product_NumAromaticRings',
#  'product_NumHAcceptors',
#  'product_NumHDonors',
#  'product_NumHeteroatoms',
#  'product_NumRotatableBonds',
#  'product_NumSaturatedCarbocycles',
#  'product_NumSaturatedHeterocycles',
#  'product_NumSaturatedRings',
#  'product_RingCount',
#  'product_MolLogP',
#  'product_MolMR',
#  'product_fr_Al_COO',
#  'product_fr_Al_OH',
#  'product_fr_ArN',
#  'product_fr_Ar_COO',
#  'product_fr_Ar_N',
#  'product_fr_Ar_NH',
#  'product_fr_Ar_OH',
#  'product_fr_COO',
#  'product_fr_COO2',
#  'product_fr_C_O',
#  'product_fr_C_O_noCOO',
#  'product_fr_HOCCN',
#  'product_fr_Imine',
#  'product_fr_NH0',
#  'product_fr_NH1',
#  'product_fr_NH2',
#  'product_fr_N_O',
#  'product_fr_Ndealkylation1',
#  'product_fr_Ndealkylation2',
#  'product_fr_Nhpyrrole',
#  'product_fr_aldehyde',
#  'product_fr_alkyl_carbamate',
#  'product_fr_alkyl_halide',
#  'product_fr_allylic_oxid',
#  'product_fr_amide',
#  'product_fr_amidine',
#  'product_fr_aniline',
#  'product_fr_aryl_methyl',
#  'product_fr_benzene',
#  'product_fr_bicyclic',
#  'product_fr_ester',
#  'product_fr_ether',
#  'product_fr_furan',
#  'product_fr_halogen',
#  'product_fr_imidazole',
#  'product_fr_ketone',
#  'product_fr_ketone_Topliss',
#  'product_fr_lactone',
#  'product_fr_methoxy',
#  'product_fr_morpholine',
#  'product_fr_nitrile',
#  'product_fr_nitro',
#  'product_fr_nitro_arom',
#  'product_fr_oxazole',
#  'product_fr_para_hydroxylation',
#  'product_fr_phenol',
#  'product_fr_phenol_noOrthoHbond',
#  'product_fr_piperdine',
#  'product_fr_piperzine',
#  'product_fr_priamide',
#  'product_fr_pyridine',
#  'product_fr_sulfonamd',
#  'product_fr_sulfone',
#  'product_fr_thiazole',
#  'product_fr_thiophene',
#  'product_fr_urea',
#  'halide_MaxEStateIndex',
#  'halide_MinEStateIndex',
#  'halide_MaxAbsEStateIndex',
#  'halide_MinAbsEStateIndex',
#  'halide_qed',
#  'halide_MolWt',
#  'halide_HeavyAtomMolWt',
#  'halide_ExactMolWt',
#  'halide_NumValenceElectrons',
#  'halide_MaxPartialCharge',
#  'halide_MinPartialCharge',
#  'halide_MaxAbsPartialCharge',
#  'halide_MinAbsPartialCharge',
#  'halide_FpDensityMorgan1',
#  'halide_FpDensityMorgan2',
#  'halide_FpDensityMorgan3',
#  'halide_BCUT2D_MWHI',
#  'halide_BCUT2D_MWLOW',
#  'halide_BCUT2D_CHGHI',
#  'halide_BCUT2D_CHGLO',
#  'halide_BCUT2D_LOGPHI',
#  'halide_BCUT2D_LOGPLOW',
#  'halide_BCUT2D_MRHI',
#  'halide_BCUT2D_MRLOW',
#  'halide_BalabanJ',
#  'halide_BertzCT',
#  'halide_Chi0',
#  'halide_Chi0n',
#  'halide_Chi0v',
#  'halide_Chi1',
#  'halide_Chi1n',
#  'halide_Chi1v',
#  'halide_Chi2n',
#  'halide_Chi2v',
#  'halide_Chi3n',
#  'halide_Chi3v',
#  'halide_Chi4n',
#  'halide_Chi4v',
#  'halide_HallKierAlpha',
#  'halide_Ipc',
#  'halide_Kappa1',
#  'halide_Kappa2',
#  'halide_Kappa3',
#  'halide_LabuteASA',
#  'halide_PEOE_VSA1',
#  'halide_PEOE_VSA10',
#  'halide_PEOE_VSA11',
#  'halide_PEOE_VSA12',
#  'halide_PEOE_VSA13',
#  'halide_PEOE_VSA14',
#  'halide_PEOE_VSA2',
#  'halide_PEOE_VSA3',
#  'halide_PEOE_VSA4',
#  'halide_PEOE_VSA5',
#  'halide_PEOE_VSA6',
#  'halide_PEOE_VSA7',
#  'halide_PEOE_VSA8',
#  'halide_PEOE_VSA9',
#  'halide_SMR_VSA1',
#  'halide_SMR_VSA10',
#  'halide_SMR_VSA2',
#  'halide_SMR_VSA3',
#  'halide_SMR_VSA4',
#  'halide_SMR_VSA5',
#  'halide_SMR_VSA6',
#  'halide_SMR_VSA7',
#  'halide_SMR_VSA9',
#  'halide_SlogP_VSA1',
#  'halide_SlogP_VSA10',
#  'halide_SlogP_VSA11',
#  'halide_SlogP_VSA12',
#  'halide_SlogP_VSA2',
#  'halide_SlogP_VSA3',
#  'halide_SlogP_VSA4',
#  'halide_SlogP_VSA5',
#  'halide_SlogP_VSA6',
#  'halide_SlogP_VSA7',
#  'halide_SlogP_VSA8',
#  'halide_TPSA',
#  'halide_EState_VSA1',
#  'halide_EState_VSA10',
#  'halide_EState_VSA11',
#  'halide_EState_VSA2',
#  'halide_EState_VSA3',
#  'halide_EState_VSA4',
#  'halide_EState_VSA5',
#  'halide_EState_VSA6',
#  'halide_EState_VSA7',
#  'halide_EState_VSA8',
#  'halide_EState_VSA9',
#  'halide_VSA_EState1',
#  'halide_VSA_EState10',
#  'halide_VSA_EState2',
#  'halide_VSA_EState3',
#  'halide_VSA_EState4',
#  'halide_VSA_EState5',
#  'halide_VSA_EState6',
#  'halide_VSA_EState7',
#  'halide_VSA_EState8',
#  'halide_VSA_EState9',
#  'halide_FractionCSP3',
#  'halide_HeavyAtomCount',
#  'halide_NHOHCount',
#  'halide_NOCount',
#  'halide_NumAliphaticCarbocycles',
#  'halide_NumAliphaticHeterocycles',
#  'halide_NumAliphaticRings',
#  'halide_NumAromaticCarbocycles',
#  'halide_NumAromaticHeterocycles',
#  'halide_NumAromaticRings',
#  'halide_NumHAcceptors',
#  'halide_NumHDonors',
#  'halide_NumHeteroatoms',
#  'halide_NumRotatableBonds',
#  'halide_NumSaturatedCarbocycles',
#  'halide_NumSaturatedHeterocycles',
#  'halide_NumSaturatedRings',
#  'halide_RingCount',
#  'halide_MolLogP',
#  'halide_MolMR',
#  'halide_fr_Al_COO',
#  'halide_fr_Al_OH',
#  'halide_fr_ArN',
#  'halide_fr_Ar_COO',
#  'halide_fr_Ar_N',
#  'halide_fr_Ar_NH',
#  'halide_fr_Ar_OH',
#  'halide_fr_COO',
#  'halide_fr_COO2',
#  'halide_fr_C_O',
#  'halide_fr_C_O_noCOO',
#  'halide_fr_HOCCN',
#  'halide_fr_Imine',
#  'halide_fr_NH0',
#  'halide_fr_NH1',
#  'halide_fr_NH2',
#  'halide_fr_N_O',
#  'halide_fr_Ndealkylation1',
#  'halide_fr_Ndealkylation2',
#  'halide_fr_Nhpyrrole',
#  'halide_fr_aldehyde',
#  'halide_fr_alkyl_carbamate',
#  'halide_fr_alkyl_halide',
#  'halide_fr_amide',
#  'halide_fr_amidine',
#  'halide_fr_aniline',
#  'halide_fr_aryl_methyl',
#  'halide_fr_benzene',
#  'halide_fr_bicyclic',
#  'halide_fr_ester',
#  'halide_fr_ether',
#  'halide_fr_furan',
#  'halide_fr_halogen',
#  'halide_fr_imidazole',
#  'halide_fr_ketone',
#  'halide_fr_ketone_Topliss',
#  'halide_fr_lactone',
#  'halide_fr_methoxy',
#  'halide_fr_morpholine',
#  'halide_fr_nitrile',
#  'halide_fr_nitro',
#  'halide_fr_nitro_arom',
#  'halide_fr_para_hydroxylation',
#  'halide_fr_phenol',
#  'halide_fr_phenol_noOrthoHbond',
#  'halide_fr_piperdine',
#  'halide_fr_piperzine',
#  'halide_fr_priamide',
#  'halide_fr_pyridine',
#  'halide_fr_sulfonamd',
#  'halide_fr_sulfone',
#  'halide_fr_thiazole',
#  'halide_fr_thiophene',
#  'halide_molecular_weight',
#  'halide_molecular_volume',
#  'halide_surface_area',
#  'halide_ovality',
#  'halide_hardness',
#  'halide_dipole_moment',
#  'halide_electronegativity',
#  'halide_E_HOMO',
#  'halide_E_LOMO',
#  'halide_V0_frequency',
#  'halide_V0_intensity',
#  'halide_V1_frequency',
#  'halide_V1_intensity',
#  'halide_V2_frequency',
#  'halide_V2_intensity',
#  'halide_.C1_electrostatic_charge',
#  'halide_.C1_NMR_shift',
#  'halide_.C2_electrostatic_charge',
#  'halide_.C2_NMR_shift',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift']

# %%
len(feature_col)
# Out:
# 907

# %%
X = df_cat[feature_col]

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Lists to store the results
rmse_list = []
r2_list = []

for seed in range(30):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmse_list.append(rmse)
    r2_list.append(r2)
    
    print(f'Seed {seed} -> RMSE: {rmse}, R²: {r2}')

average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)


print(f'\nR²_mean: {average_r2}')
print(f'R²_sd: {std_r2}')

print(f'RMSE_mean: {average_rmse}')
print(f'RMSE_sd: {std_rmse}')
# Out:
# Seed 0 -> RMSE: 24.136390243513283, R²: 0.3254012459012757
# Seed 1 -> RMSE: 23.74195188293456, R²: 0.30738766896998915
# Seed 2 -> RMSE: 26.321683142435134, R²: 0.22001001870426906
# Seed 3 -> RMSE: 23.395817213945303, R²: 0.3354791680968532
# Seed 4 -> RMSE: 27.642637572580156, R²: 0.22286550512174919
# Seed 5 -> RMSE: 24.398163232912214, R²: 0.2737597104115169
# Seed 6 -> RMSE: 24.359557552781034, R²: 0.2622644394092478
# Seed 7 -> RMSE: 24.118329135654204, R²: 0.2736116821080472
# Seed 8 -> RMSE: 24.31734810187338, R²: 0.25117042371617826
# Seed 9 -> RMSE: 24.239664680857036, R²: 0.2510856972495896
# Seed 10 -> RMSE: 25.553281472230335, R²: 0.21645304742446725
# Seed 11 -> RMSE: 26.76044446196981, R²: 0.22083755719362175
# Seed 12 -> RMSE: 25.544319208595066, R²: 0.23363774080336042
# Seed 13 -> RMSE: 25.920669895285485, R²: 0.27181798085499487
# Seed 14 -> RMSE: 25.82491147068833, R²: 0.2316846095203846
# Seed 15 -> RMSE: 25.70129317361546, R²: 0.1984867373108412
# Seed 16 -> RMSE: 26.228964683851355, R²: 0.23020133064593484
# Seed 17 -> RMSE: 27.32115317082255, R²: 0.16734998083618569
# Seed 18 -> RMSE: 25.763020131555425, R²: 0.2495255008376035
# Seed 19 -> RMSE: 23.19297571510241, R²: 0.3469339894285274
# Seed 20 -> RMSE: 25.969195267036675, R²: 0.30676112576856973
# Seed 21 -> RMSE: 25.217688460511944, R²: 0.21463068342748848
# Seed 22 -> RMSE: 22.908508900272974, R²: 0.36762744886086773
# Seed 23 -> RMSE: 24.160704216852444, R²: 0.3272666716152023
# Seed 24 -> RMSE: 26.93507258753871, R²: 0.18874493465705633
# Seed 25 -> RMSE: 26.108673947378065, R²: 0.2829994287401696
# Seed 26 -> RMSE: 25.151412597914753, R²: 0.2791826309974369
# Seed 27 -> RMSE: 23.283687908597905, R²: 0.33919338588819736
# Seed 28 -> RMSE: 25.46647580969691, R²: 0.31615198850085535
# Seed 29 -> RMSE: 24.059067637970728, R²: 0.31430163320359006
#
# R²_mean: 0.26756079887346906
# R²_sd: 0.05122203219725366
# RMSE_mean: 25.124768782565788
# RMSE_sd: 1.2561448711178484

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
    if 'ReactSeq_all' in i:
        continue
    if 'AP3_256' in i:
        continue
    if 'Drfp' in i:
        continue
    if 'rxnfp_pretrained' in i:
        continue
    if 'rxnfp_ft_10k' in i:
        continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift']

# %%
len(feature_col)
# Out:
# 361

# %%
X = df_cat[feature_col]

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Lists to store the results
rmse_list = []
r2_list = []

for seed in range(30):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmse_list.append(rmse)
    r2_list.append(r2)
    
    print(f'Seed {seed} -> RMSE: {rmse}, R²: {r2}')

average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)


print(f'\nR²_mean: {average_r2}')
print(f'R²_sd: {std_r2}')

print(f'RMSE_mean: {average_rmse}')
print(f'RMSE_sd: {std_rmse}')
# Out:
# Seed 0 -> RMSE: 26.092658227977946, R²: 0.21161646036398363
# Seed 1 -> RMSE: 26.773331928356598, R²: 0.11923058961822974
# Seed 2 -> RMSE: 27.613057210920115, R²: 0.1415980488414933
# Seed 3 -> RMSE: 24.789390688382767, R²: 0.2539569910065046
# Seed 4 -> RMSE: 28.881490495065897, R²: 0.15164732879429854
# Seed 5 -> RMSE: 26.819422168778086, R²: 0.12246407131451631
# Seed 6 -> RMSE: 25.984772314744177, R²: 0.1605404816159962
# Seed 7 -> RMSE: 25.18167270395577, R²: 0.20814882440627835
# Seed 8 -> RMSE: 25.414160236839905, R²: 0.18209644952457904
# Seed 9 -> RMSE: 27.07456546841358, R²: 0.06566654477364853
# Seed 10 -> RMSE: 27.45532701380011, R²: 0.09546597073193763
# Seed 11 -> RMSE: 28.39150316648387, R²: 0.12296254890540648
# Seed 12 -> RMSE: 27.787982919618464, R²: 0.09309981540863754
# Seed 13 -> RMSE: 29.337180051549687, R²: 0.06720922855290434
# Seed 14 -> RMSE: 28.288006601610952, R²: 0.07813667109014943
# Seed 15 -> RMSE: 27.117004428264067, R²: 0.1077548706892576
# Seed 16 -> RMSE: 28.44762196226355, R²: 0.0944617588672424
# Seed 17 -> RMSE: 28.59847608477668, R²: 0.08767363084107704
# Seed 18 -> RMSE: 27.16822472459194, R²: 0.16542587520175978
# Seed 19 -> RMSE: 25.539044285352094, R²: 0.20813086254870306
# Seed 20 -> RMSE: 28.129315610856477, R²: 0.1866372925360883
# Seed 21 -> RMSE: 27.198381230169108, R²: 0.08641387890018015
# Seed 22 -> RMSE: 26.855571391360034, R²: 0.1309432033907908
# Seed 23 -> RMSE: 26.674863728153834, R²: 0.17997293666585412
# Seed 24 -> RMSE: 27.67926976860793, R²: 0.14329682229318697
# Seed 25 -> RMSE: 28.592226063388768, R²: 0.14010423481667622
# Seed 26 -> RMSE: 27.35156464053333, R²: 0.1475580187412323
# Seed 27 -> RMSE: 25.849461179186058, R²: 0.18553236326637812
# Seed 28 -> RMSE: 27.69737522934122, R²: 0.19109202049251384
# Seed 29 -> RMSE: 25.816716789244463, R²: 0.2104537958273136
#
# R²_mean: 0.14464305300089392
# R²_sd: 0.04895218198047264
# RMSE_mean: 27.15332127708625
# RMSE_sd: 1.1596958295126947

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
    if 'ReactSeq_all' in i:
        continue
#     if 'AP3_256' in i:
#         continue
    if 'Drfp' in i:
        continue
    if 'rxnfp_pretrained' in i:
        continue
    if 'rxnfp_ft_10k' in i:
        continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift',
#  'AP3_256_0',
#  'AP3_256_1',
#  'AP3_256_2',
#  'AP3_256_3',
#  'AP3_256_4',
#  'AP3_256_5',
#  'AP3_256_6',
#  'AP3_256_7',
#  'AP3_256_8',
#  'AP3_256_9',
#  'AP3_256_10',
#  'AP3_256_11',
#  'AP3_256_12',
#  'AP3_256_13',
#  'AP3_256_14',
#  'AP3_256_15',
#  'AP3_256_16',
#  'AP3_256_17',
#  'AP3_256_18',
#  'AP3_256_19',
#  'AP3_256_20',
#  'AP3_256_21',
#  'AP3_256_22',
#  'AP3_256_23',
#  'AP3_256_24',
#  'AP3_256_25',
#  'AP3_256_26',
#  'AP3_256_27',
#  'AP3_256_28',
#  'AP3_256_29',
#  'AP3_256_30',
#  'AP3_256_31',
#  'AP3_256_32',
#  'AP3_256_33',
#  'AP3_256_34',
#  'AP3_256_35',
#  'AP3_256_36',
#  'AP3_256_37',
#  'AP3_256_38',
#  'AP3_256_39',
#  'AP3_256_40',
#  'AP3_256_41',
#  'AP3_256_42',
#  'AP3_256_43',
#  'AP3_256_44',
#  'AP3_256_45',
#  'AP3_256_46',
#  'AP3_256_47',
#  'AP3_256_48',
#  'AP3_256_49',
#  'AP3_256_50',
#  'AP3_256_51',
#  'AP3_256_52',
#  'AP3_256_53',
#  'AP3_256_54',
#  'AP3_256_55',
#  'AP3_256_56',
#  'AP3_256_57',
#  'AP3_256_58',
#  'AP3_256_59',
#  'AP3_256_60',
#  'AP3_256_61',
#  'AP3_256_62',
#  'AP3_256_63',
#  'AP3_256_64',
#  'AP3_256_65',
#  'AP3_256_66',
#  'AP3_256_67',
#  'AP3_256_68',
#  'AP3_256_69',
#  'AP3_256_70',
#  'AP3_256_71',
#  'AP3_256_72',
#  'AP3_256_73',
#  'AP3_256_74',
#  'AP3_256_75',
#  'AP3_256_76',
#  'AP3_256_77',
#  'AP3_256_78',
#  'AP3_256_79',
#  'AP3_256_80',
#  'AP3_256_81',
#  'AP3_256_82',
#  'AP3_256_83',
#  'AP3_256_84',
#  'AP3_256_85',
#  'AP3_256_86',
#  'AP3_256_87',
#  'AP3_256_88',
#  'AP3_256_89',
#  'AP3_256_90',
#  'AP3_256_91',
#  'AP3_256_92',
#  'AP3_256_93',
#  'AP3_256_94',
#  'AP3_256_95',
#  'AP3_256_96',
#  'AP3_256_97',
#  'AP3_256_98',
#  'AP3_256_99',
#  'AP3_256_100',
#  'AP3_256_101',
#  'AP3_256_102',
#  'AP3_256_103',
#  'AP3_256_104',
#  'AP3_256_105',
#  'AP3_256_106',
#  'AP3_256_107',
#  'AP3_256_108',
#  'AP3_256_109',
#  'AP3_256_110',
#  'AP3_256_111',
#  'AP3_256_112',
#  'AP3_256_113',
#  'AP3_256_114',
#  'AP3_256_115',
#  'AP3_256_116',
#  'AP3_256_117',
#  'AP3_256_118',
#  'AP3_256_119',
#  'AP3_256_120',
#  'AP3_256_121',
#  'AP3_256_122',
#  'AP3_256_123',
#  'AP3_256_124',
#  'AP3_256_125',
#  'AP3_256_126',
#  'AP3_256_127',
#  'AP3_256_128',
#  'AP3_256_129',
#  'AP3_256_130',
#  'AP3_256_131',
#  'AP3_256_132',
#  'AP3_256_133',
#  'AP3_256_134',
#  'AP3_256_135',
#  'AP3_256_136',
#  'AP3_256_137',
#  'AP3_256_138',
#  'AP3_256_139',
#  'AP3_256_140',
#  'AP3_256_141',
#  'AP3_256_142',
#  'AP3_256_143',
#  'AP3_256_144',
#  'AP3_256_145',
#  'AP3_256_146',
#  'AP3_256_147',
#  'AP3_256_148',
#  'AP3_256_149',
#  'AP3_256_150',
#  'AP3_256_151',
#  'AP3_256_152',
#  'AP3_256_153',
#  'AP3_256_154',
#  'AP3_256_155',
#  'AP3_256_156',
#  'AP3_256_157',
#  'AP3_256_158',
#  'AP3_256_159',
#  'AP3_256_160',
#  'AP3_256_161',
#  'AP3_256_162',
#  'AP3_256_163',
#  'AP3_256_164',
#  'AP3_256_165',
#  'AP3_256_166',
#  'AP3_256_167',
#  'AP3_256_168',
#  'AP3_256_169',
#  'AP3_256_170',
#  'AP3_256_171',
#  'AP3_256_172',
#  'AP3_256_173',
#  'AP3_256_174',
#  'AP3_256_175',
#  'AP3_256_176',
#  'AP3_256_177',
#  'AP3_256_178',
#  'AP3_256_179',
#  'AP3_256_180',
#  'AP3_256_181',
#  'AP3_256_182',
#  'AP3_256_183',
#  'AP3_256_184',
#  'AP3_256_185',
#  'AP3_256_186',
#  'AP3_256_187',
#  'AP3_256_188',
#  'AP3_256_189',
#  'AP3_256_190',
#  'AP3_256_191',
#  'AP3_256_192',
#  'AP3_256_193',
#  'AP3_256_194',
#  'AP3_256_195',
#  'AP3_256_196',
#  'AP3_256_197',
#  'AP3_256_198',
#  'AP3_256_199',
#  'AP3_256_200',
#  'AP3_256_201',
#  'AP3_256_202',
#  'AP3_256_203',
#  'AP3_256_204',
#  'AP3_256_205',
#  'AP3_256_206',
#  'AP3_256_207',
#  'AP3_256_208',
#  'AP3_256_209',
#  'AP3_256_210',
#  'AP3_256_211',
#  'AP3_256_212',
#  'AP3_256_213',
#  'AP3_256_214',
#  'AP3_256_215',
#  'AP3_256_216',
#  'AP3_256_217',
#  'AP3_256_218',
#  'AP3_256_219',
#  'AP3_256_220',
#  'AP3_256_221',
#  'AP3_256_222',
#  'AP3_256_223',
#  'AP3_256_224',
#  'AP3_256_225',
#  'AP3_256_226',
#  'AP3_256_227',
#  'AP3_256_228',
#  'AP3_256_229',
#  'AP3_256_230',
#  'AP3_256_231',
#  'AP3_256_232',
#  'AP3_256_233',
#  'AP3_256_234',
#  'AP3_256_235',
#  'AP3_256_236',
#  'AP3_256_237',
#  'AP3_256_238',
#  'AP3_256_239',
#  'AP3_256_240',
#  'AP3_256_241',
#  'AP3_256_242',
#  'AP3_256_243',
#  'AP3_256_244',
#  'AP3_256_245',
#  'AP3_256_246',
#  'AP3_256_247',
#  'AP3_256_248',
#  'AP3_256_249',
#  'AP3_256_250',
#  'AP3_256_251',
#  'AP3_256_252',
#  'AP3_256_253',
#  'AP3_256_254',
#  'AP3_256_255']

# %%
len(feature_col)
# Out:
# 617

# %%
X = df_cat[feature_col]

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Lists to store the results
rmse_list = []
r2_list = []

for seed in range(30):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmse_list.append(rmse)
    r2_list.append(r2)
    
    print(f'Seed {seed} -> RMSE: {rmse}, R²: {r2}')

average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)


print(f'\nR²_mean: {average_r2}')
print(f'R²_sd: {std_r2}')

print(f'RMSE_mean: {average_rmse}')
print(f'RMSE_sd: {std_rmse}')
# Out:
# Seed 0 -> RMSE: 23.320352646998813, R²: 0.3702457259217944
# Seed 1 -> RMSE: 23.627521041354434, R²: 0.3140480491952503
# Seed 2 -> RMSE: 26.15362618402075, R²: 0.22993828042558706
# Seed 3 -> RMSE: 23.38395047837244, R²: 0.33615310848948543
# Seed 4 -> RMSE: 27.083197785320788, R²: 0.25400295036393317
# Seed 5 -> RMSE: 24.583669400511553, R²: 0.26267410395738244
# Seed 6 -> RMSE: 24.30040200824462, R²: 0.2658431709950887
# Seed 7 -> RMSE: 23.442535526390156, R²: 0.31374806563478197
# Seed 8 -> RMSE: 23.889827071239818, R²: 0.2772691752488602
# Seed 9 -> RMSE: 24.140276734649945, R²: 0.2572145327332662
# Seed 10 -> RMSE: 26.54530354055391, R²: 0.1544348798902052
# Seed 11 -> RMSE: 26.963769649995147, R²: 0.20895246322674166
# Seed 12 -> RMSE: 25.838455792304885, R²: 0.21588718145212904
# Seed 13 -> RMSE: 25.38186705792458, R²: 0.30177621592415516
# Seed 14 -> RMSE: 25.603808076835875, R²: 0.24478435840260093
# Seed 15 -> RMSE: 25.4651192744389, R²: 0.21314956155268172
# Seed 16 -> RMSE: 26.225271101308415, R²: 0.23041812263617156
# Seed 17 -> RMSE: 26.811570625432704, R²: 0.19812078654389764
# Seed 18 -> RMSE: 25.84772317631308, R²: 0.24458260419092503
# Seed 19 -> RMSE: 23.16426946012753, R²: 0.3485496059746819
# Seed 20 -> RMSE: 25.448930122022155, R²: 0.33425949220345963
# Seed 21 -> RMSE: 25.125420512080463, R²: 0.22036727956322355
# Seed 22 -> RMSE: 23.508623243593934, R²: 0.33406206041601405
# Seed 23 -> RMSE: 23.50253742196353, R²: 0.36341958582731493
# Seed 24 -> RMSE: 26.019318084246738, R²: 0.24297025908823633
# Seed 25 -> RMSE: 26.28904737525967, R²: 0.2730583198261136
# Seed 26 -> RMSE: 25.17826163011991, R²: 0.27764287028326085
# Seed 27 -> RMSE: 23.511523406967036, R²: 0.32619786635589954
# Seed 28 -> RMSE: 24.83747567705396, R²: 0.34951572852818646
# Seed 29 -> RMSE: 23.442337114000598, R²: 0.34900546466953397
#
# R²_mean: 0.2770763956506954
# R²_sd: 0.05576967691688063
# RMSE_mean: 24.954533040654876
# RMSE_sd: 1.2465346897842082

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
    if 'ReactSeq_all' in i:
        continue
    if 'AP3_256' in i:
        continue
#     if 'Drfp' in i:
#         continue
    if 'rxnfp_pretrained' in i:
        continue
    if 'rxnfp_ft_10k' in i:
        continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift',
#  'Drfp_0',
#  'Drfp_1',
#  'Drfp_2',
#  'Drfp_3',
#  'Drfp_4',
#  'Drfp_5',
#  'Drfp_6',
#  'Drfp_7',
#  'Drfp_8',
#  'Drfp_9',
#  'Drfp_10',
#  'Drfp_11',
#  'Drfp_12',
#  'Drfp_13',
#  'Drfp_14',
#  'Drfp_15',
#  'Drfp_16',
#  'Drfp_17',
#  'Drfp_18',
#  'Drfp_19',
#  'Drfp_20',
#  'Drfp_21',
#  'Drfp_22',
#  'Drfp_23',
#  'Drfp_24',
#  'Drfp_25',
#  'Drfp_26',
#  'Drfp_27',
#  'Drfp_28',
#  'Drfp_29',
#  'Drfp_30',
#  'Drfp_31',
#  'Drfp_32',
#  'Drfp_33',
#  'Drfp_34',
#  'Drfp_35',
#  'Drfp_36',
#  'Drfp_37',
#  'Drfp_38',
#  'Drfp_39',
#  'Drfp_40',
#  'Drfp_41',
#  'Drfp_42',
#  'Drfp_43',
#  'Drfp_44',
#  'Drfp_45',
#  'Drfp_46',
#  'Drfp_47',
#  'Drfp_48',
#  'Drfp_49',
#  'Drfp_50',
#  'Drfp_51',
#  'Drfp_52',
#  'Drfp_53',
#  'Drfp_54',
#  'Drfp_55',
#  'Drfp_56',
#  'Drfp_57',
#  'Drfp_58',
#  'Drfp_59',
#  'Drfp_60',
#  'Drfp_61',
#  'Drfp_62',
#  'Drfp_63',
#  'Drfp_64',
#  'Drfp_65',
#  'Drfp_66',
#  'Drfp_67',
#  'Drfp_68',
#  'Drfp_69',
#  'Drfp_70',
#  'Drfp_71',
#  'Drfp_72',
#  'Drfp_73',
#  'Drfp_74',
#  'Drfp_75',
#  'Drfp_76',
#  'Drfp_77',
#  'Drfp_78',
#  'Drfp_79',
#  'Drfp_80',
#  'Drfp_81',
#  'Drfp_82',
#  'Drfp_83',
#  'Drfp_84',
#  'Drfp_85',
#  'Drfp_86',
#  'Drfp_87',
#  'Drfp_88',
#  'Drfp_89',
#  'Drfp_90',
#  'Drfp_91',
#  'Drfp_92',
#  'Drfp_93',
#  'Drfp_94',
#  'Drfp_95',
#  'Drfp_96',
#  'Drfp_97',
#  'Drfp_98',
#  'Drfp_99',
#  'Drfp_100',
#  'Drfp_101',
#  'Drfp_102',
#  'Drfp_103',
#  'Drfp_104',
#  'Drfp_105',
#  'Drfp_106',
#  'Drfp_107',
#  'Drfp_108',
#  'Drfp_109',
#  'Drfp_110',
#  'Drfp_111',
#  'Drfp_112',
#  'Drfp_113',
#  'Drfp_114',
#  'Drfp_115',
#  'Drfp_116',
#  'Drfp_117',
#  'Drfp_118',
#  'Drfp_119',
#  'Drfp_120',
#  'Drfp_121',
#  'Drfp_122',
#  'Drfp_123',
#  'Drfp_124',
#  'Drfp_125',
#  'Drfp_126',
#  'Drfp_127',
#  'Drfp_128',
#  'Drfp_129',
#  'Drfp_130',
#  'Drfp_131',
#  'Drfp_132',
#  'Drfp_133',
#  'Drfp_134',
#  'Drfp_135',
#  'Drfp_136',
#  'Drfp_137',
#  'Drfp_138',
#  'Drfp_139',
#  'Drfp_140',
#  'Drfp_141',
#  'Drfp_142',
#  'Drfp_143',
#  'Drfp_144',
#  'Drfp_145',
#  'Drfp_146',
#  'Drfp_147',
#  'Drfp_148',
#  'Drfp_149',
#  'Drfp_150',
#  'Drfp_151',
#  'Drfp_152',
#  'Drfp_153',
#  'Drfp_154',
#  'Drfp_155',
#  'Drfp_156',
#  'Drfp_157',
#  'Drfp_158',
#  'Drfp_159',
#  'Drfp_160',
#  'Drfp_161',
#  'Drfp_162',
#  'Drfp_163',
#  'Drfp_164',
#  'Drfp_165',
#  'Drfp_166',
#  'Drfp_167',
#  'Drfp_168',
#  'Drfp_169',
#  'Drfp_170',
#  'Drfp_171',
#  'Drfp_172',
#  'Drfp_173',
#  'Drfp_174',
#  'Drfp_175',
#  'Drfp_176',
#  'Drfp_177',
#  'Drfp_178',
#  'Drfp_179',
#  'Drfp_180',
#  'Drfp_181',
#  'Drfp_182',
#  'Drfp_183',
#  'Drfp_184',
#  'Drfp_185',
#  'Drfp_186',
#  'Drfp_187',
#  'Drfp_188',
#  'Drfp_189',
#  'Drfp_190',
#  'Drfp_191',
#  'Drfp_192',
#  'Drfp_193',
#  'Drfp_194',
#  'Drfp_195',
#  'Drfp_196',
#  'Drfp_197',
#  'Drfp_198',
#  'Drfp_199',
#  'Drfp_200',
#  'Drfp_201',
#  'Drfp_202',
#  'Drfp_203',
#  'Drfp_204',
#  'Drfp_205',
#  'Drfp_206',
#  'Drfp_207',
#  'Drfp_208',
#  'Drfp_209',
#  'Drfp_210',
#  'Drfp_211',
#  'Drfp_212',
#  'Drfp_213',
#  'Drfp_214',
#  'Drfp_215',
#  'Drfp_216',
#  'Drfp_217',
#  'Drfp_218',
#  'Drfp_219',
#  'Drfp_220',
#  'Drfp_221',
#  'Drfp_222',
#  'Drfp_223',
#  'Drfp_224',
#  'Drfp_225',
#  'Drfp_226',
#  'Drfp_227',
#  'Drfp_228',
#  'Drfp_229',
#  'Drfp_230',
#  'Drfp_231',
#  'Drfp_232',
#  'Drfp_233',
#  'Drfp_234',
#  'Drfp_235',
#  'Drfp_236',
#  'Drfp_237',
#  'Drfp_238',
#  'Drfp_239',
#  'Drfp_240',
#  'Drfp_241',
#  'Drfp_242',
#  'Drfp_243',
#  'Drfp_244',
#  'Drfp_245',
#  'Drfp_246',
#  'Drfp_247',
#  'Drfp_248',
#  'Drfp_249',
#  'Drfp_250',
#  'Drfp_251',
#  'Drfp_252',
#  'Drfp_253',
#  'Drfp_254',
#  'Drfp_255',
#  'Drfp_256',
#  'Drfp_257',
#  'Drfp_258',
#  'Drfp_259',
#  'Drfp_260',
#  'Drfp_261',
#  'Drfp_262',
#  'Drfp_263',
#  'Drfp_264',
#  'Drfp_265',
#  'Drfp_266',
#  'Drfp_267',
#  'Drfp_268',
#  'Drfp_269',
#  'Drfp_270',
#  'Drfp_271',
#  'Drfp_272',
#  'Drfp_273',
#  'Drfp_274',
#  'Drfp_275',
#  'Drfp_276',
#  'Drfp_277',
#  'Drfp_278',
#  'Drfp_279',
#  'Drfp_280',
#  'Drfp_281',
#  'Drfp_282',
#  'Drfp_283',
#  'Drfp_284',
#  'Drfp_285',
#  'Drfp_286',
#  'Drfp_287',
#  'Drfp_288',
#  'Drfp_289',
#  'Drfp_290',
#  'Drfp_291',
#  'Drfp_292',
#  'Drfp_293',
#  'Drfp_294',
#  'Drfp_295',
#  'Drfp_296',
#  'Drfp_297',
#  'Drfp_298',
#  'Drfp_299',
#  'Drfp_300',
#  'Drfp_301',
#  'Drfp_302',
#  'Drfp_303',
#  'Drfp_304',
#  'Drfp_305',
#  'Drfp_306',
#  'Drfp_307',
#  'Drfp_308',
#  'Drfp_309',
#  'Drfp_310',
#  'Drfp_311',
#  'Drfp_312',
#  'Drfp_313',
#  'Drfp_314',
#  'Drfp_315',
#  'Drfp_316',
#  'Drfp_317',
#  'Drfp_318',
#  'Drfp_319',
#  'Drfp_320',
#  'Drfp_321',
#  'Drfp_322',
#  'Drfp_323',
#  'Drfp_324',
#  'Drfp_325',
#  'Drfp_326',
#  'Drfp_327',
#  'Drfp_328',
#  'Drfp_329',
#  'Drfp_330',
#  'Drfp_331',
#  'Drfp_332',
#  'Drfp_333',
#  'Drfp_334',
#  'Drfp_335',
#  'Drfp_336',
#  'Drfp_337',
#  'Drfp_338',
#  'Drfp_339',
#  'Drfp_340',
#  'Drfp_341',
#  'Drfp_342',
#  'Drfp_343',
#  'Drfp_344',
#  'Drfp_345',
#  'Drfp_346',
#  'Drfp_347',
#  'Drfp_348',
#  'Drfp_349',
#  'Drfp_350',
#  'Drfp_351',
#  'Drfp_352',
#  'Drfp_353',
#  'Drfp_354',
#  'Drfp_355',
#  'Drfp_356',
#  'Drfp_357',
#  'Drfp_358',
#  'Drfp_359',
#  'Drfp_360',
#  'Drfp_361',
#  'Drfp_362',
#  'Drfp_363',
#  'Drfp_364',
#  'Drfp_365',
#  'Drfp_366',
#  'Drfp_367',
#  'Drfp_368',
#  'Drfp_369',
#  'Drfp_370',
#  'Drfp_371',
#  'Drfp_372',
#  'Drfp_373',
#  'Drfp_374',
#  'Drfp_375',
#  'Drfp_376',
#  'Drfp_377',
#  'Drfp_378',
#  'Drfp_379',
#  'Drfp_380',
#  'Drfp_381',
#  'Drfp_382',
#  'Drfp_383',
#  'Drfp_384',
#  'Drfp_385',
#  'Drfp_386',
#  'Drfp_387',
#  'Drfp_388',
#  'Drfp_389',
#  'Drfp_390',
#  'Drfp_391',
#  'Drfp_392',
#  'Drfp_393',
#  'Drfp_394',
#  'Drfp_395',
#  'Drfp_396',
#  'Drfp_397',
#  'Drfp_398',
#  'Drfp_399',
#  'Drfp_400',
#  'Drfp_401',
#  'Drfp_402',
#  'Drfp_403',
#  'Drfp_404',
#  'Drfp_405',
#  'Drfp_406',
#  'Drfp_407',
#  'Drfp_408',
#  'Drfp_409',
#  'Drfp_410',
#  'Drfp_411',
#  'Drfp_412',
#  'Drfp_413',
#  'Drfp_414',
#  'Drfp_415',
#  'Drfp_416',
#  'Drfp_417',
#  'Drfp_418',
#  'Drfp_419',
#  'Drfp_420',
#  'Drfp_421',
#  'Drfp_422',
#  'Drfp_423',
#  'Drfp_424',
#  'Drfp_425',
#  'Drfp_426',
#  'Drfp_427',
#  'Drfp_428',
#  'Drfp_429',
#  'Drfp_430',
#  'Drfp_431',
#  'Drfp_432',
#  'Drfp_433',
#  'Drfp_434',
#  'Drfp_435',
#  'Drfp_436',
#  'Drfp_437',
#  'Drfp_438',
#  'Drfp_439',
#  'Drfp_440',
#  'Drfp_441',
#  'Drfp_442',
#  'Drfp_443',
#  'Drfp_444',
#  'Drfp_445',
#  'Drfp_446',
#  'Drfp_447',
#  'Drfp_448',
#  'Drfp_449',
#  'Drfp_450',
#  'Drfp_451',
#  'Drfp_452',
#  'Drfp_453',
#  'Drfp_454',
#  'Drfp_455',
#  'Drfp_456',
#  'Drfp_457',
#  'Drfp_458',
#  'Drfp_459',
#  'Drfp_460',
#  'Drfp_461',
#  'Drfp_462',
#  'Drfp_463',
#  'Drfp_464',
#  'Drfp_465',
#  'Drfp_466',
#  'Drfp_467',
#  'Drfp_468',
#  'Drfp_469',
#  'Drfp_470',
#  'Drfp_471',
#  'Drfp_472',
#  'Drfp_473',
#  'Drfp_474',
#  'Drfp_475',
#  'Drfp_476',
#  'Drfp_477',
#  'Drfp_478',
#  'Drfp_479',
#  'Drfp_480',
#  'Drfp_481',
#  'Drfp_482',
#  'Drfp_483',
#  'Drfp_484',
#  'Drfp_485',
#  'Drfp_486',
#  'Drfp_487',
#  'Drfp_488',
#  'Drfp_489',
#  'Drfp_490',
#  'Drfp_491',
#  'Drfp_492',
#  'Drfp_493',
#  'Drfp_494',
#  'Drfp_495',
#  'Drfp_496',
#  'Drfp_497',
#  'Drfp_498',
#  'Drfp_499',
#  'Drfp_500',
#  'Drfp_501',
#  'Drfp_502',
#  'Drfp_503',
#  'Drfp_504',
#  'Drfp_505',
#  'Drfp_506',
#  'Drfp_507',
#  'Drfp_508',
#  'Drfp_509',
#  'Drfp_510',
#  'Drfp_511',
#  'Drfp_512',
#  'Drfp_513',
#  'Drfp_514',
#  'Drfp_515',
#  'Drfp_516',
#  'Drfp_517',
#  'Drfp_518',
#  'Drfp_519',
#  'Drfp_520',
#  'Drfp_521',
#  'Drfp_522',
#  'Drfp_523',
#  'Drfp_524',
#  'Drfp_525',
#  'Drfp_526',
#  'Drfp_527',
#  'Drfp_528',
#  'Drfp_529',
#  'Drfp_530',
#  'Drfp_531',
#  'Drfp_532',
#  'Drfp_533',
#  'Drfp_534',
#  'Drfp_535',
#  'Drfp_536',
#  'Drfp_537',
#  'Drfp_538',
#  'Drfp_539',
#  'Drfp_540',
#  'Drfp_541',
#  'Drfp_542',
#  'Drfp_543',
#  'Drfp_544',
#  'Drfp_545',
#  'Drfp_546',
#  'Drfp_547',
#  'Drfp_548',
#  'Drfp_549',
#  'Drfp_550',
#  'Drfp_551',
#  'Drfp_552',
#  'Drfp_553',
#  'Drfp_554',
#  'Drfp_555',
#  'Drfp_556',
#  'Drfp_557',
#  'Drfp_558',
#  'Drfp_559',
#  'Drfp_560',
#  'Drfp_561',
#  'Drfp_562',
#  'Drfp_563',
#  'Drfp_564',
#  'Drfp_565',
#  'Drfp_566',
#  'Drfp_567',
#  'Drfp_568',
#  'Drfp_569',
#  'Drfp_570',
#  'Drfp_571',
#  'Drfp_572',
#  'Drfp_573',
#  'Drfp_574',
#  'Drfp_575',
#  'Drfp_576',
#  'Drfp_577',
#  'Drfp_578',
#  'Drfp_579',
#  'Drfp_580',
#  'Drfp_581',
#  'Drfp_582',
#  'Drfp_583',
#  'Drfp_584',
#  'Drfp_585',
#  'Drfp_586',
#  'Drfp_587',
#  'Drfp_588',
#  'Drfp_589',
#  'Drfp_590',
#  'Drfp_591',
#  'Drfp_592',
#  'Drfp_593',
#  'Drfp_594',
#  'Drfp_595',
#  'Drfp_596',
#  'Drfp_597',
#  'Drfp_598',
#  'Drfp_599',
#  'Drfp_600',
#  'Drfp_601',
#  'Drfp_602',
#  'Drfp_603',
#  'Drfp_604',
#  'Drfp_605',
#  'Drfp_606',
#  'Drfp_607',
#  'Drfp_608',
#  'Drfp_609',
#  'Drfp_610',
#  'Drfp_611',
#  'Drfp_612',
#  'Drfp_613',
#  'Drfp_614',
#  'Drfp_615',
#  'Drfp_616',
#  'Drfp_617',
#  'Drfp_618',
#  'Drfp_619',
#  'Drfp_620',
#  'Drfp_621',
#  'Drfp_622',
#  'Drfp_623',
#  'Drfp_624',
#  'Drfp_625',
#  'Drfp_626',
#  'Drfp_627',
#  'Drfp_628',
#  'Drfp_629',
#  'Drfp_630',
#  'Drfp_631',
#  'Drfp_632',
#  'Drfp_633',
#  'Drfp_634',
#  'Drfp_635',
#  'Drfp_636',
#  'Drfp_637',
#  'Drfp_638',
#  ...]

# %%
len(feature_col)
# Out:
# 2409

# %%
X = df_cat[feature_col]

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Lists to store the results
rmse_list = []
r2_list = []

for seed in range(30):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmse_list.append(rmse)
    r2_list.append(r2)
    
    print(f'Seed {seed} -> RMSE: {rmse}, R²: {r2}')

average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)


print(f'\nR²_mean: {average_r2}')
print(f'R²_sd: {std_r2}')

print(f'RMSE_mean: {average_rmse}')
print(f'RMSE_sd: {std_rmse}')
# Out:
# Seed 0 -> RMSE: 24.054275023513974, R²: 0.329983587689184
# Seed 1 -> RMSE: 24.83485398873062, R²: 0.24215463230664402
# Seed 2 -> RMSE: 26.557350494867233, R²: 0.20598043956025547
# Seed 3 -> RMSE: 23.261415115397213, R²: 0.34309219183196715
# Seed 4 -> RMSE: 27.417842735100265, R²: 0.23545370285027944
# Seed 5 -> RMSE: 25.61643469342024, R²: 0.19942238600003526
# Seed 6 -> RMSE: 25.32970037602184, R²: 0.20233225426664336
# Seed 7 -> RMSE: 24.40746010826084, R²: 0.2560913779759295
# Seed 8 -> RMSE: 23.82504700567275, R²: 0.28118339974974826
# Seed 9 -> RMSE: 25.35034643746755, R²: 0.18088155242058312
# Seed 10 -> RMSE: 26.946349314563882, R²: 0.1286923260256827
# Seed 11 -> RMSE: 27.70880606255474, R²: 0.16463362172950868
# Seed 12 -> RMSE: 26.021960333119168, R²: 0.20471010410537904
# Seed 13 -> RMSE: 26.775883168902766, R²: 0.2229747763290275
# Seed 14 -> RMSE: 26.35716015375393, R²: 0.1996884567206605
# Seed 15 -> RMSE: 26.204539260342376, R²: 0.16679125764049896
# Seed 16 -> RMSE: 27.446576531179243, R²: 0.1570705588844974
# Seed 17 -> RMSE: 27.997290557602803, R²: 0.12562757448001372
# Seed 18 -> RMSE: 26.43525410327563, R²: 0.2098503127189295
# Seed 19 -> RMSE: 23.666482826113874, R²: 0.31999583079010985
# Seed 20 -> RMSE: 26.40323456691288, R²: 0.2833944085755592
# Seed 21 -> RMSE: 25.456027838317492, R²: 0.19971504192504796
# Seed 22 -> RMSE: 24.19242561475219, R²: 0.2947579566964398
# Seed 23 -> RMSE: 24.79952421427686, R²: 0.29122161559504534
# Seed 24 -> RMSE: 26.982243259768666, R²: 0.18590098797484578
# Seed 25 -> RMSE: 26.702292776282373, R²: 0.25002466765423903
# Seed 26 -> RMSE: 25.72222131870927, R²: 0.24609361595677837
# Seed 27 -> RMSE: 24.473161997043974, R²: 0.269952677770985
# Seed 28 -> RMSE: 25.008378983260002, R²: 0.34053314216263797
# Seed 29 -> RMSE: 24.029285156292655, R²: 0.31599822090029195
#
# R²_mean: 0.2351400893095816
# R²_sd: 0.060702180982875824
# RMSE_mean: 25.666127467182566
# RMSE_sd: 1.2924074862532993

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
    if 'ReactSeq_all' in i:
        continue
    if 'AP3_256' in i:
        continue
    if 'Drfp' in i:
        continue
#     if 'rxnfp_pretrained' in i:
#         continue
    if 'rxnfp_ft_10k' in i:
        continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift',
#  'rxnfp_pretrained_0',
#  'rxnfp_pretrained_1',
#  'rxnfp_pretrained_2',
#  'rxnfp_pretrained_3',
#  'rxnfp_pretrained_4',
#  'rxnfp_pretrained_5',
#  'rxnfp_pretrained_6',
#  'rxnfp_pretrained_7',
#  'rxnfp_pretrained_8',
#  'rxnfp_pretrained_9',
#  'rxnfp_pretrained_10',
#  'rxnfp_pretrained_11',
#  'rxnfp_pretrained_12',
#  'rxnfp_pretrained_13',
#  'rxnfp_pretrained_14',
#  'rxnfp_pretrained_15',
#  'rxnfp_pretrained_16',
#  'rxnfp_pretrained_17',
#  'rxnfp_pretrained_18',
#  'rxnfp_pretrained_19',
#  'rxnfp_pretrained_20',
#  'rxnfp_pretrained_21',
#  'rxnfp_pretrained_22',
#  'rxnfp_pretrained_23',
#  'rxnfp_pretrained_24',
#  'rxnfp_pretrained_25',
#  'rxnfp_pretrained_26',
#  'rxnfp_pretrained_27',
#  'rxnfp_pretrained_28',
#  'rxnfp_pretrained_29',
#  'rxnfp_pretrained_30',
#  'rxnfp_pretrained_31',
#  'rxnfp_pretrained_32',
#  'rxnfp_pretrained_33',
#  'rxnfp_pretrained_34',
#  'rxnfp_pretrained_35',
#  'rxnfp_pretrained_36',
#  'rxnfp_pretrained_37',
#  'rxnfp_pretrained_38',
#  'rxnfp_pretrained_39',
#  'rxnfp_pretrained_40',
#  'rxnfp_pretrained_41',
#  'rxnfp_pretrained_42',
#  'rxnfp_pretrained_43',
#  'rxnfp_pretrained_44',
#  'rxnfp_pretrained_45',
#  'rxnfp_pretrained_46',
#  'rxnfp_pretrained_47',
#  'rxnfp_pretrained_48',
#  'rxnfp_pretrained_49',
#  'rxnfp_pretrained_50',
#  'rxnfp_pretrained_51',
#  'rxnfp_pretrained_52',
#  'rxnfp_pretrained_53',
#  'rxnfp_pretrained_54',
#  'rxnfp_pretrained_55',
#  'rxnfp_pretrained_56',
#  'rxnfp_pretrained_57',
#  'rxnfp_pretrained_58',
#  'rxnfp_pretrained_59',
#  'rxnfp_pretrained_60',
#  'rxnfp_pretrained_61',
#  'rxnfp_pretrained_62',
#  'rxnfp_pretrained_63',
#  'rxnfp_pretrained_64',
#  'rxnfp_pretrained_65',
#  'rxnfp_pretrained_66',
#  'rxnfp_pretrained_67',
#  'rxnfp_pretrained_68',
#  'rxnfp_pretrained_69',
#  'rxnfp_pretrained_70',
#  'rxnfp_pretrained_71',
#  'rxnfp_pretrained_72',
#  'rxnfp_pretrained_73',
#  'rxnfp_pretrained_74',
#  'rxnfp_pretrained_75',
#  'rxnfp_pretrained_76',
#  'rxnfp_pretrained_77',
#  'rxnfp_pretrained_78',
#  'rxnfp_pretrained_79',
#  'rxnfp_pretrained_80',
#  'rxnfp_pretrained_81',
#  'rxnfp_pretrained_82',
#  'rxnfp_pretrained_83',
#  'rxnfp_pretrained_84',
#  'rxnfp_pretrained_85',
#  'rxnfp_pretrained_86',
#  'rxnfp_pretrained_87',
#  'rxnfp_pretrained_88',
#  'rxnfp_pretrained_89',
#  'rxnfp_pretrained_90',
#  'rxnfp_pretrained_91',
#  'rxnfp_pretrained_92',
#  'rxnfp_pretrained_93',
#  'rxnfp_pretrained_94',
#  'rxnfp_pretrained_95',
#  'rxnfp_pretrained_96',
#  'rxnfp_pretrained_97',
#  'rxnfp_pretrained_98',
#  'rxnfp_pretrained_99',
#  'rxnfp_pretrained_100',
#  'rxnfp_pretrained_101',
#  'rxnfp_pretrained_102',
#  'rxnfp_pretrained_103',
#  'rxnfp_pretrained_104',
#  'rxnfp_pretrained_105',
#  'rxnfp_pretrained_106',
#  'rxnfp_pretrained_107',
#  'rxnfp_pretrained_108',
#  'rxnfp_pretrained_109',
#  'rxnfp_pretrained_110',
#  'rxnfp_pretrained_111',
#  'rxnfp_pretrained_112',
#  'rxnfp_pretrained_113',
#  'rxnfp_pretrained_114',
#  'rxnfp_pretrained_115',
#  'rxnfp_pretrained_116',
#  'rxnfp_pretrained_117',
#  'rxnfp_pretrained_118',
#  'rxnfp_pretrained_119',
#  'rxnfp_pretrained_120',
#  'rxnfp_pretrained_121',
#  'rxnfp_pretrained_122',
#  'rxnfp_pretrained_123',
#  'rxnfp_pretrained_124',
#  'rxnfp_pretrained_125',
#  'rxnfp_pretrained_126',
#  'rxnfp_pretrained_127',
#  'rxnfp_pretrained_128',
#  'rxnfp_pretrained_129',
#  'rxnfp_pretrained_130',
#  'rxnfp_pretrained_131',
#  'rxnfp_pretrained_132',
#  'rxnfp_pretrained_133',
#  'rxnfp_pretrained_134',
#  'rxnfp_pretrained_135',
#  'rxnfp_pretrained_136',
#  'rxnfp_pretrained_137',
#  'rxnfp_pretrained_138',
#  'rxnfp_pretrained_139',
#  'rxnfp_pretrained_140',
#  'rxnfp_pretrained_141',
#  'rxnfp_pretrained_142',
#  'rxnfp_pretrained_143',
#  'rxnfp_pretrained_144',
#  'rxnfp_pretrained_145',
#  'rxnfp_pretrained_146',
#  'rxnfp_pretrained_147',
#  'rxnfp_pretrained_148',
#  'rxnfp_pretrained_149',
#  'rxnfp_pretrained_150',
#  'rxnfp_pretrained_151',
#  'rxnfp_pretrained_152',
#  'rxnfp_pretrained_153',
#  'rxnfp_pretrained_154',
#  'rxnfp_pretrained_155',
#  'rxnfp_pretrained_156',
#  'rxnfp_pretrained_157',
#  'rxnfp_pretrained_158',
#  'rxnfp_pretrained_159',
#  'rxnfp_pretrained_160',
#  'rxnfp_pretrained_161',
#  'rxnfp_pretrained_162',
#  'rxnfp_pretrained_163',
#  'rxnfp_pretrained_164',
#  'rxnfp_pretrained_165',
#  'rxnfp_pretrained_166',
#  'rxnfp_pretrained_167',
#  'rxnfp_pretrained_168',
#  'rxnfp_pretrained_169',
#  'rxnfp_pretrained_170',
#  'rxnfp_pretrained_171',
#  'rxnfp_pretrained_172',
#  'rxnfp_pretrained_173',
#  'rxnfp_pretrained_174',
#  'rxnfp_pretrained_175',
#  'rxnfp_pretrained_176',
#  'rxnfp_pretrained_177',
#  'rxnfp_pretrained_178',
#  'rxnfp_pretrained_179',
#  'rxnfp_pretrained_180',
#  'rxnfp_pretrained_181',
#  'rxnfp_pretrained_182',
#  'rxnfp_pretrained_183',
#  'rxnfp_pretrained_184',
#  'rxnfp_pretrained_185',
#  'rxnfp_pretrained_186',
#  'rxnfp_pretrained_187',
#  'rxnfp_pretrained_188',
#  'rxnfp_pretrained_189',
#  'rxnfp_pretrained_190',
#  'rxnfp_pretrained_191',
#  'rxnfp_pretrained_192',
#  'rxnfp_pretrained_193',
#  'rxnfp_pretrained_194',
#  'rxnfp_pretrained_195',
#  'rxnfp_pretrained_196',
#  'rxnfp_pretrained_197',
#  'rxnfp_pretrained_198',
#  'rxnfp_pretrained_199',
#  'rxnfp_pretrained_200',
#  'rxnfp_pretrained_201',
#  'rxnfp_pretrained_202',
#  'rxnfp_pretrained_203',
#  'rxnfp_pretrained_204',
#  'rxnfp_pretrained_205',
#  'rxnfp_pretrained_206',
#  'rxnfp_pretrained_207',
#  'rxnfp_pretrained_208',
#  'rxnfp_pretrained_209',
#  'rxnfp_pretrained_210',
#  'rxnfp_pretrained_211',
#  'rxnfp_pretrained_212',
#  'rxnfp_pretrained_213',
#  'rxnfp_pretrained_214',
#  'rxnfp_pretrained_215',
#  'rxnfp_pretrained_216',
#  'rxnfp_pretrained_217',
#  'rxnfp_pretrained_218',
#  'rxnfp_pretrained_219',
#  'rxnfp_pretrained_220',
#  'rxnfp_pretrained_221',
#  'rxnfp_pretrained_222',
#  'rxnfp_pretrained_223',
#  'rxnfp_pretrained_224',
#  'rxnfp_pretrained_225',
#  'rxnfp_pretrained_226',
#  'rxnfp_pretrained_227',
#  'rxnfp_pretrained_228',
#  'rxnfp_pretrained_229',
#  'rxnfp_pretrained_230',
#  'rxnfp_pretrained_231',
#  'rxnfp_pretrained_232',
#  'rxnfp_pretrained_233',
#  'rxnfp_pretrained_234',
#  'rxnfp_pretrained_235',
#  'rxnfp_pretrained_236',
#  'rxnfp_pretrained_237',
#  'rxnfp_pretrained_238',
#  'rxnfp_pretrained_239',
#  'rxnfp_pretrained_240',
#  'rxnfp_pretrained_241',
#  'rxnfp_pretrained_242',
#  'rxnfp_pretrained_243',
#  'rxnfp_pretrained_244',
#  'rxnfp_pretrained_245',
#  'rxnfp_pretrained_246',
#  'rxnfp_pretrained_247',
#  'rxnfp_pretrained_248',
#  'rxnfp_pretrained_249',
#  'rxnfp_pretrained_250',
#  'rxnfp_pretrained_251',
#  'rxnfp_pretrained_252',
#  'rxnfp_pretrained_253',
#  'rxnfp_pretrained_254',
#  'rxnfp_pretrained_255']

# %%
len(feature_col)
# Out:
# 617

# %%
X = df_cat[feature_col]

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Lists to store the results
rmse_list = []
r2_list = []

for seed in range(30):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmse_list.append(rmse)
    r2_list.append(r2)
    
    print(f'Seed {seed} -> RMSE: {rmse}, R²: {r2}')

average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)


print(f'\nR²_mean: {average_r2}')
print(f'R²_sd: {std_r2}')

print(f'RMSE_mean: {average_rmse}')
print(f'RMSE_sd: {std_rmse}')
# Out:
# Seed 0 -> RMSE: 23.915792127638003, R²: 0.33767608511946645
# Seed 1 -> RMSE: 23.49268848374777, R²: 0.32185460311819447
# Seed 2 -> RMSE: 25.58082937731887, R²: 0.2632995202258501
# Seed 3 -> RMSE: 23.328918703125737, R²: 0.33927402554583397
# Seed 4 -> RMSE: 28.0327960762611, R²: 0.20077315524349604
# Seed 5 -> RMSE: 24.438918674010296, R²: 0.27133141579196796
# Seed 6 -> RMSE: 23.645426045604115, R²: 0.3048857152879527
# Seed 7 -> RMSE: 23.363018324587607, R²: 0.31839571005089895
# Seed 8 -> RMSE: 24.36605646483789, R²: 0.24816756401639162
# Seed 9 -> RMSE: 23.929185325020477, R²: 0.27014811206854616
# Seed 10 -> RMSE: 25.5891050864878, R²: 0.21425456975541113
# Seed 11 -> RMSE: 27.070204597440334, R²: 0.20269508326057817
# Seed 12 -> RMSE: 24.862463216981087, R²: 0.2740047971842492
# Seed 13 -> RMSE: 25.336903976239487, R²: 0.30424778241886874
# Seed 14 -> RMSE: 25.157957678329375, R²: 0.27085716180011987
# Seed 15 -> RMSE: 25.347943696138433, R²: 0.22037415215741496
# Seed 16 -> RMSE: 25.30810676738854, R²: 0.28330532903344663
# Seed 17 -> RMSE: 26.49127727246761, R²: 0.21716498872454015
# Seed 18 -> RMSE: 25.21434000150072, R²: 0.2811511150281387
# Seed 19 -> RMSE: 22.880000367546263, R²: 0.3644405379321246
# Seed 20 -> RMSE: 25.60441827464601, R²: 0.3260995429246538
# Seed 21 -> RMSE: 25.965446096028376, R²: 0.16736443693913516
# Seed 22 -> RMSE: 23.720975701828813, R²: 0.32197694181474146
# Seed 23 -> RMSE: 24.51626728142925, R²: 0.3073202976290631
# Seed 24 -> RMSE: 27.136558855392877, R²: 0.1765624451308746
# Seed 25 -> RMSE: 26.425126715632317, R²: 0.26551314209555943
# Seed 26 -> RMSE: 25.43454433076608, R²: 0.26286267451099143
# Seed 27 -> RMSE: 23.33091209449535, R²: 0.3365101596990956
# Seed 28 -> RMSE: 25.379310647533973, R²: 0.32082524697212444
# Seed 29 -> RMSE: 23.410068718402144, R²: 0.3507964201814001
#
# R²_mean: 0.2781377577220377
# R²_sd: 0.052399109222920105
# RMSE_mean: 24.942518699294226
# RMSE_sd: 1.281067843220354

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
    if 'ReactSeq_all' in i:
        continue
    if 'AP3_256' in i:
        continue
    if 'Drfp' in i:
        continue
    if 'rxnfp_pretrained' in i:
        continue
#     if 'rxnfp_ft_10k' in i:
#         continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift',
#  'rxnfp_ft_10k_0',
#  'rxnfp_ft_10k_1',
#  'rxnfp_ft_10k_2',
#  'rxnfp_ft_10k_3',
#  'rxnfp_ft_10k_4',
#  'rxnfp_ft_10k_5',
#  'rxnfp_ft_10k_6',
#  'rxnfp_ft_10k_7',
#  'rxnfp_ft_10k_8',
#  'rxnfp_ft_10k_9',
#  'rxnfp_ft_10k_10',
#  'rxnfp_ft_10k_11',
#  'rxnfp_ft_10k_12',
#  'rxnfp_ft_10k_13',
#  'rxnfp_ft_10k_14',
#  'rxnfp_ft_10k_15',
#  'rxnfp_ft_10k_16',
#  'rxnfp_ft_10k_17',
#  'rxnfp_ft_10k_18',
#  'rxnfp_ft_10k_19',
#  'rxnfp_ft_10k_20',
#  'rxnfp_ft_10k_21',
#  'rxnfp_ft_10k_22',
#  'rxnfp_ft_10k_23',
#  'rxnfp_ft_10k_24',
#  'rxnfp_ft_10k_25',
#  'rxnfp_ft_10k_26',
#  'rxnfp_ft_10k_27',
#  'rxnfp_ft_10k_28',
#  'rxnfp_ft_10k_29',
#  'rxnfp_ft_10k_30',
#  'rxnfp_ft_10k_31',
#  'rxnfp_ft_10k_32',
#  'rxnfp_ft_10k_33',
#  'rxnfp_ft_10k_34',
#  'rxnfp_ft_10k_35',
#  'rxnfp_ft_10k_36',
#  'rxnfp_ft_10k_37',
#  'rxnfp_ft_10k_38',
#  'rxnfp_ft_10k_39',
#  'rxnfp_ft_10k_40',
#  'rxnfp_ft_10k_41',
#  'rxnfp_ft_10k_42',
#  'rxnfp_ft_10k_43',
#  'rxnfp_ft_10k_44',
#  'rxnfp_ft_10k_45',
#  'rxnfp_ft_10k_46',
#  'rxnfp_ft_10k_47',
#  'rxnfp_ft_10k_48',
#  'rxnfp_ft_10k_49',
#  'rxnfp_ft_10k_50',
#  'rxnfp_ft_10k_51',
#  'rxnfp_ft_10k_52',
#  'rxnfp_ft_10k_53',
#  'rxnfp_ft_10k_54',
#  'rxnfp_ft_10k_55',
#  'rxnfp_ft_10k_56',
#  'rxnfp_ft_10k_57',
#  'rxnfp_ft_10k_58',
#  'rxnfp_ft_10k_59',
#  'rxnfp_ft_10k_60',
#  'rxnfp_ft_10k_61',
#  'rxnfp_ft_10k_62',
#  'rxnfp_ft_10k_63',
#  'rxnfp_ft_10k_64',
#  'rxnfp_ft_10k_65',
#  'rxnfp_ft_10k_66',
#  'rxnfp_ft_10k_67',
#  'rxnfp_ft_10k_68',
#  'rxnfp_ft_10k_69',
#  'rxnfp_ft_10k_70',
#  'rxnfp_ft_10k_71',
#  'rxnfp_ft_10k_72',
#  'rxnfp_ft_10k_73',
#  'rxnfp_ft_10k_74',
#  'rxnfp_ft_10k_75',
#  'rxnfp_ft_10k_76',
#  'rxnfp_ft_10k_77',
#  'rxnfp_ft_10k_78',
#  'rxnfp_ft_10k_79',
#  'rxnfp_ft_10k_80',
#  'rxnfp_ft_10k_81',
#  'rxnfp_ft_10k_82',
#  'rxnfp_ft_10k_83',
#  'rxnfp_ft_10k_84',
#  'rxnfp_ft_10k_85',
#  'rxnfp_ft_10k_86',
#  'rxnfp_ft_10k_87',
#  'rxnfp_ft_10k_88',
#  'rxnfp_ft_10k_89',
#  'rxnfp_ft_10k_90',
#  'rxnfp_ft_10k_91',
#  'rxnfp_ft_10k_92',
#  'rxnfp_ft_10k_93',
#  'rxnfp_ft_10k_94',
#  'rxnfp_ft_10k_95',
#  'rxnfp_ft_10k_96',
#  'rxnfp_ft_10k_97',
#  'rxnfp_ft_10k_98',
#  'rxnfp_ft_10k_99',
#  'rxnfp_ft_10k_100',
#  'rxnfp_ft_10k_101',
#  'rxnfp_ft_10k_102',
#  'rxnfp_ft_10k_103',
#  'rxnfp_ft_10k_104',
#  'rxnfp_ft_10k_105',
#  'rxnfp_ft_10k_106',
#  'rxnfp_ft_10k_107',
#  'rxnfp_ft_10k_108',
#  'rxnfp_ft_10k_109',
#  'rxnfp_ft_10k_110',
#  'rxnfp_ft_10k_111',
#  'rxnfp_ft_10k_112',
#  'rxnfp_ft_10k_113',
#  'rxnfp_ft_10k_114',
#  'rxnfp_ft_10k_115',
#  'rxnfp_ft_10k_116',
#  'rxnfp_ft_10k_117',
#  'rxnfp_ft_10k_118',
#  'rxnfp_ft_10k_119',
#  'rxnfp_ft_10k_120',
#  'rxnfp_ft_10k_121',
#  'rxnfp_ft_10k_122',
#  'rxnfp_ft_10k_123',
#  'rxnfp_ft_10k_124',
#  'rxnfp_ft_10k_125',
#  'rxnfp_ft_10k_126',
#  'rxnfp_ft_10k_127',
#  'rxnfp_ft_10k_128',
#  'rxnfp_ft_10k_129',
#  'rxnfp_ft_10k_130',
#  'rxnfp_ft_10k_131',
#  'rxnfp_ft_10k_132',
#  'rxnfp_ft_10k_133',
#  'rxnfp_ft_10k_134',
#  'rxnfp_ft_10k_135',
#  'rxnfp_ft_10k_136',
#  'rxnfp_ft_10k_137',
#  'rxnfp_ft_10k_138',
#  'rxnfp_ft_10k_139',
#  'rxnfp_ft_10k_140',
#  'rxnfp_ft_10k_141',
#  'rxnfp_ft_10k_142',
#  'rxnfp_ft_10k_143',
#  'rxnfp_ft_10k_144',
#  'rxnfp_ft_10k_145',
#  'rxnfp_ft_10k_146',
#  'rxnfp_ft_10k_147',
#  'rxnfp_ft_10k_148',
#  'rxnfp_ft_10k_149',
#  'rxnfp_ft_10k_150',
#  'rxnfp_ft_10k_151',
#  'rxnfp_ft_10k_152',
#  'rxnfp_ft_10k_153',
#  'rxnfp_ft_10k_154',
#  'rxnfp_ft_10k_155',
#  'rxnfp_ft_10k_156',
#  'rxnfp_ft_10k_157',
#  'rxnfp_ft_10k_158',
#  'rxnfp_ft_10k_159',
#  'rxnfp_ft_10k_160',
#  'rxnfp_ft_10k_161',
#  'rxnfp_ft_10k_162',
#  'rxnfp_ft_10k_163',
#  'rxnfp_ft_10k_164',
#  'rxnfp_ft_10k_165',
#  'rxnfp_ft_10k_166',
#  'rxnfp_ft_10k_167',
#  'rxnfp_ft_10k_168',
#  'rxnfp_ft_10k_169',
#  'rxnfp_ft_10k_170',
#  'rxnfp_ft_10k_171',
#  'rxnfp_ft_10k_172',
#  'rxnfp_ft_10k_173',
#  'rxnfp_ft_10k_174',
#  'rxnfp_ft_10k_175',
#  'rxnfp_ft_10k_176',
#  'rxnfp_ft_10k_177',
#  'rxnfp_ft_10k_178',
#  'rxnfp_ft_10k_179',
#  'rxnfp_ft_10k_180',
#  'rxnfp_ft_10k_181',
#  'rxnfp_ft_10k_182',
#  'rxnfp_ft_10k_183',
#  'rxnfp_ft_10k_184',
#  'rxnfp_ft_10k_185',
#  'rxnfp_ft_10k_186',
#  'rxnfp_ft_10k_187',
#  'rxnfp_ft_10k_188',
#  'rxnfp_ft_10k_189',
#  'rxnfp_ft_10k_190',
#  'rxnfp_ft_10k_191',
#  'rxnfp_ft_10k_192',
#  'rxnfp_ft_10k_193',
#  'rxnfp_ft_10k_194',
#  'rxnfp_ft_10k_195',
#  'rxnfp_ft_10k_196',
#  'rxnfp_ft_10k_197',
#  'rxnfp_ft_10k_198',
#  'rxnfp_ft_10k_199',
#  'rxnfp_ft_10k_200',
#  'rxnfp_ft_10k_201',
#  'rxnfp_ft_10k_202',
#  'rxnfp_ft_10k_203',
#  'rxnfp_ft_10k_204',
#  'rxnfp_ft_10k_205',
#  'rxnfp_ft_10k_206',
#  'rxnfp_ft_10k_207',
#  'rxnfp_ft_10k_208',
#  'rxnfp_ft_10k_209',
#  'rxnfp_ft_10k_210',
#  'rxnfp_ft_10k_211',
#  'rxnfp_ft_10k_212',
#  'rxnfp_ft_10k_213',
#  'rxnfp_ft_10k_214',
#  'rxnfp_ft_10k_215',
#  'rxnfp_ft_10k_216',
#  'rxnfp_ft_10k_217',
#  'rxnfp_ft_10k_218',
#  'rxnfp_ft_10k_219',
#  'rxnfp_ft_10k_220',
#  'rxnfp_ft_10k_221',
#  'rxnfp_ft_10k_222',
#  'rxnfp_ft_10k_223',
#  'rxnfp_ft_10k_224',
#  'rxnfp_ft_10k_225',
#  'rxnfp_ft_10k_226',
#  'rxnfp_ft_10k_227',
#  'rxnfp_ft_10k_228',
#  'rxnfp_ft_10k_229',
#  'rxnfp_ft_10k_230',
#  'rxnfp_ft_10k_231',
#  'rxnfp_ft_10k_232',
#  'rxnfp_ft_10k_233',
#  'rxnfp_ft_10k_234',
#  'rxnfp_ft_10k_235',
#  'rxnfp_ft_10k_236',
#  'rxnfp_ft_10k_237',
#  'rxnfp_ft_10k_238',
#  'rxnfp_ft_10k_239',
#  'rxnfp_ft_10k_240',
#  'rxnfp_ft_10k_241',
#  'rxnfp_ft_10k_242',
#  'rxnfp_ft_10k_243',
#  'rxnfp_ft_10k_244',
#  'rxnfp_ft_10k_245',
#  'rxnfp_ft_10k_246',
#  'rxnfp_ft_10k_247',
#  'rxnfp_ft_10k_248',
#  'rxnfp_ft_10k_249',
#  'rxnfp_ft_10k_250',
#  'rxnfp_ft_10k_251',
#  'rxnfp_ft_10k_252',
#  'rxnfp_ft_10k_253',
#  'rxnfp_ft_10k_254',
#  'rxnfp_ft_10k_255']

# %%
len(feature_col)
# Out:
# 617

# %%
X = df_cat[feature_col]

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Lists to store the results
rmse_list = []
r2_list = []

for seed in range(30):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmse_list.append(rmse)
    r2_list.append(r2)
    
    print(f'Seed {seed} -> RMSE: {rmse}, R²: {r2}')

average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)


print(f'\nR²_mean: {average_r2}')
print(f'R²_sd: {std_r2}')

print(f'RMSE_mean: {average_rmse}')
print(f'RMSE_sd: {std_rmse}')
# Out:
# Seed 0 -> RMSE: 23.887684566656255, R²: 0.3392319917868254
# Seed 1 -> RMSE: 24.381371724281347, R²: 0.26957832859101405
# Seed 2 -> RMSE: 27.26786089535613, R²: 0.1629260045632953
# Seed 3 -> RMSE: 23.56298462226657, R²: 0.3259489952492918
# Seed 4 -> RMSE: 27.652230449066547, R²: 0.22232603064094636
# Seed 5 -> RMSE: 24.54483475692046, R²: 0.2650017607138774
# Seed 6 -> RMSE: 24.228595198688282, R²: 0.2701755742609435
# Seed 7 -> RMSE: 23.971856026156086, R²: 0.2824077539244122
# Seed 8 -> RMSE: 24.051200550956107, R²: 0.2674722438141037
# Seed 9 -> RMSE: 24.48507364144408, R²: 0.2358445085249975
# Seed 10 -> RMSE: 26.00862440922718, R²: 0.18827964916277362
# Seed 11 -> RMSE: 26.87819137746334, R²: 0.21396578697109292
# Seed 12 -> RMSE: 25.994229654091374, R²: 0.20640422534071579
# Seed 13 -> RMSE: 26.106048481167925, R²: 0.2613651600207684
# Seed 14 -> RMSE: 26.16644293855574, R²: 0.21122846864257294
# Seed 15 -> RMSE: 26.24345097173779, R²: 0.16431491951001032
# Seed 16 -> RMSE: 26.173903448622756, R²: 0.2334299427229014
# Seed 17 -> RMSE: 27.726395415746275, R²: 0.1424661557341761
# Seed 18 -> RMSE: 25.729789252561098, R²: 0.25146027736523724
# Seed 19 -> RMSE: 23.228826260217016, R²: 0.344913475294367
# Seed 20 -> RMSE: 26.678983944816743, R²: 0.26834811500233113
# Seed 21 -> RMSE: 25.880555334587008, R²: 0.1727999316339015
# Seed 22 -> RMSE: 23.844965274005315, R²: 0.3148703622884159
# Seed 23 -> RMSE: 24.124097083119814, R²: 0.3293037134165039
# Seed 24 -> RMSE: 27.253610546016986, R²: 0.16944344135695621
# Seed 25 -> RMSE: 26.396898010692333, R²: 0.267081538618407
# Seed 26 -> RMSE: 25.65437177925713, R²: 0.2500656474706564
# Seed 27 -> RMSE: 23.54882069259806, R²: 0.32405841130161384
# Seed 28 -> RMSE: 25.8470255413233, R²: 0.29556158014395706
# Seed 29 -> RMSE: 24.030322171104746, R²: 0.31593918166732116
#
# R²_mean: 0.25220710585781286
# R²_sd: 0.05680917766734689
# RMSE_mean: 25.38497483395679
# RMSE_sd: 1.335453279356689

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
    if 'ReactSeq_MEO' in i:
        continue
#     if 'ReactSeq_all' in i:
#         continue
    if 'AP3_256' in i:
        continue
    if 'Drfp' in i:
        continue
    if 'rxnfp_pretrained' in i:
        continue
    if 'rxnfp_ft_10k' in i:
        continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift',
#  'ReactSeq_all_0',
#  'ReactSeq_all_1',
#  'ReactSeq_all_2',
#  'ReactSeq_all_3',
#  'ReactSeq_all_4',
#  'ReactSeq_all_5',
#  'ReactSeq_all_6',
#  'ReactSeq_all_7',
#  'ReactSeq_all_8',
#  'ReactSeq_all_9',
#  'ReactSeq_all_10',
#  'ReactSeq_all_11',
#  'ReactSeq_all_12',
#  'ReactSeq_all_13',
#  'ReactSeq_all_14',
#  'ReactSeq_all_15',
#  'ReactSeq_all_16',
#  'ReactSeq_all_17',
#  'ReactSeq_all_18',
#  'ReactSeq_all_19',
#  'ReactSeq_all_20',
#  'ReactSeq_all_21',
#  'ReactSeq_all_22',
#  'ReactSeq_all_23',
#  'ReactSeq_all_24',
#  'ReactSeq_all_25',
#  'ReactSeq_all_26',
#  'ReactSeq_all_27',
#  'ReactSeq_all_28',
#  'ReactSeq_all_29',
#  'ReactSeq_all_30',
#  'ReactSeq_all_31',
#  'ReactSeq_all_32',
#  'ReactSeq_all_33',
#  'ReactSeq_all_34',
#  'ReactSeq_all_35',
#  'ReactSeq_all_36',
#  'ReactSeq_all_37',
#  'ReactSeq_all_38',
#  'ReactSeq_all_39',
#  'ReactSeq_all_40',
#  'ReactSeq_all_41',
#  'ReactSeq_all_42',
#  'ReactSeq_all_43',
#  'ReactSeq_all_44',
#  'ReactSeq_all_45',
#  'ReactSeq_all_46',
#  'ReactSeq_all_47',
#  'ReactSeq_all_48',
#  'ReactSeq_all_49',
#  'ReactSeq_all_50',
#  'ReactSeq_all_51',
#  'ReactSeq_all_52',
#  'ReactSeq_all_53',
#  'ReactSeq_all_54',
#  'ReactSeq_all_55',
#  'ReactSeq_all_56',
#  'ReactSeq_all_57',
#  'ReactSeq_all_58',
#  'ReactSeq_all_59',
#  'ReactSeq_all_60',
#  'ReactSeq_all_61',
#  'ReactSeq_all_62',
#  'ReactSeq_all_63',
#  'ReactSeq_all_64',
#  'ReactSeq_all_65',
#  'ReactSeq_all_66',
#  'ReactSeq_all_67',
#  'ReactSeq_all_68',
#  'ReactSeq_all_69',
#  'ReactSeq_all_70',
#  'ReactSeq_all_71',
#  'ReactSeq_all_72',
#  'ReactSeq_all_73',
#  'ReactSeq_all_74',
#  'ReactSeq_all_75',
#  'ReactSeq_all_76',
#  'ReactSeq_all_77',
#  'ReactSeq_all_78',
#  'ReactSeq_all_79',
#  'ReactSeq_all_80',
#  'ReactSeq_all_81',
#  'ReactSeq_all_82',
#  'ReactSeq_all_83',
#  'ReactSeq_all_84',
#  'ReactSeq_all_85',
#  'ReactSeq_all_86',
#  'ReactSeq_all_87',
#  'ReactSeq_all_88',
#  'ReactSeq_all_89',
#  'ReactSeq_all_90',
#  'ReactSeq_all_91',
#  'ReactSeq_all_92',
#  'ReactSeq_all_93',
#  'ReactSeq_all_94',
#  'ReactSeq_all_95',
#  'ReactSeq_all_96',
#  'ReactSeq_all_97',
#  'ReactSeq_all_98',
#  'ReactSeq_all_99',
#  'ReactSeq_all_100',
#  'ReactSeq_all_101',
#  'ReactSeq_all_102',
#  'ReactSeq_all_103',
#  'ReactSeq_all_104',
#  'ReactSeq_all_105',
#  'ReactSeq_all_106',
#  'ReactSeq_all_107',
#  'ReactSeq_all_108',
#  'ReactSeq_all_109',
#  'ReactSeq_all_110',
#  'ReactSeq_all_111',
#  'ReactSeq_all_112',
#  'ReactSeq_all_113',
#  'ReactSeq_all_114',
#  'ReactSeq_all_115',
#  'ReactSeq_all_116',
#  'ReactSeq_all_117',
#  'ReactSeq_all_118',
#  'ReactSeq_all_119',
#  'ReactSeq_all_120',
#  'ReactSeq_all_121',
#  'ReactSeq_all_122',
#  'ReactSeq_all_123',
#  'ReactSeq_all_124',
#  'ReactSeq_all_125',
#  'ReactSeq_all_126',
#  'ReactSeq_all_127',
#  'ReactSeq_all_128',
#  'ReactSeq_all_129',
#  'ReactSeq_all_130',
#  'ReactSeq_all_131',
#  'ReactSeq_all_132',
#  'ReactSeq_all_133',
#  'ReactSeq_all_134',
#  'ReactSeq_all_135',
#  'ReactSeq_all_136',
#  'ReactSeq_all_137',
#  'ReactSeq_all_138',
#  'ReactSeq_all_139',
#  'ReactSeq_all_140',
#  'ReactSeq_all_141',
#  'ReactSeq_all_142',
#  'ReactSeq_all_143',
#  'ReactSeq_all_144',
#  'ReactSeq_all_145',
#  'ReactSeq_all_146',
#  'ReactSeq_all_147',
#  'ReactSeq_all_148',
#  'ReactSeq_all_149',
#  'ReactSeq_all_150',
#  'ReactSeq_all_151',
#  'ReactSeq_all_152',
#  'ReactSeq_all_153',
#  'ReactSeq_all_154',
#  'ReactSeq_all_155',
#  'ReactSeq_all_156',
#  'ReactSeq_all_157',
#  'ReactSeq_all_158',
#  'ReactSeq_all_159',
#  'ReactSeq_all_160',
#  'ReactSeq_all_161',
#  'ReactSeq_all_162',
#  'ReactSeq_all_163',
#  'ReactSeq_all_164',
#  'ReactSeq_all_165',
#  'ReactSeq_all_166',
#  'ReactSeq_all_167',
#  'ReactSeq_all_168',
#  'ReactSeq_all_169',
#  'ReactSeq_all_170',
#  'ReactSeq_all_171',
#  'ReactSeq_all_172',
#  'ReactSeq_all_173',
#  'ReactSeq_all_174',
#  'ReactSeq_all_175',
#  'ReactSeq_all_176',
#  'ReactSeq_all_177',
#  'ReactSeq_all_178',
#  'ReactSeq_all_179',
#  'ReactSeq_all_180',
#  'ReactSeq_all_181',
#  'ReactSeq_all_182',
#  'ReactSeq_all_183',
#  'ReactSeq_all_184',
#  'ReactSeq_all_185',
#  'ReactSeq_all_186',
#  'ReactSeq_all_187',
#  'ReactSeq_all_188',
#  'ReactSeq_all_189',
#  'ReactSeq_all_190',
#  'ReactSeq_all_191',
#  'ReactSeq_all_192',
#  'ReactSeq_all_193',
#  'ReactSeq_all_194',
#  'ReactSeq_all_195',
#  'ReactSeq_all_196',
#  'ReactSeq_all_197',
#  'ReactSeq_all_198',
#  'ReactSeq_all_199',
#  'ReactSeq_all_200',
#  'ReactSeq_all_201',
#  'ReactSeq_all_202',
#  'ReactSeq_all_203',
#  'ReactSeq_all_204',
#  'ReactSeq_all_205',
#  'ReactSeq_all_206',
#  'ReactSeq_all_207',
#  'ReactSeq_all_208',
#  'ReactSeq_all_209',
#  'ReactSeq_all_210',
#  'ReactSeq_all_211',
#  'ReactSeq_all_212',
#  'ReactSeq_all_213',
#  'ReactSeq_all_214',
#  'ReactSeq_all_215',
#  'ReactSeq_all_216',
#  'ReactSeq_all_217',
#  'ReactSeq_all_218',
#  'ReactSeq_all_219',
#  'ReactSeq_all_220',
#  'ReactSeq_all_221',
#  'ReactSeq_all_222',
#  'ReactSeq_all_223',
#  'ReactSeq_all_224',
#  'ReactSeq_all_225',
#  'ReactSeq_all_226',
#  'ReactSeq_all_227',
#  'ReactSeq_all_228',
#  'ReactSeq_all_229',
#  'ReactSeq_all_230',
#  'ReactSeq_all_231',
#  'ReactSeq_all_232',
#  'ReactSeq_all_233',
#  'ReactSeq_all_234',
#  'ReactSeq_all_235',
#  'ReactSeq_all_236',
#  'ReactSeq_all_237',
#  'ReactSeq_all_238',
#  'ReactSeq_all_239',
#  'ReactSeq_all_240',
#  'ReactSeq_all_241',
#  'ReactSeq_all_242',
#  'ReactSeq_all_243',
#  'ReactSeq_all_244',
#  'ReactSeq_all_245',
#  'ReactSeq_all_246',
#  'ReactSeq_all_247',
#  'ReactSeq_all_248',
#  'ReactSeq_all_249',
#  'ReactSeq_all_250',
#  'ReactSeq_all_251',
#  'ReactSeq_all_252',
#  'ReactSeq_all_253',
#  'ReactSeq_all_254',
#  'ReactSeq_all_255']

# %%
len(feature_col)
# Out:
# 617

# %%
X = df_cat[feature_col]

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Lists to store the results
rmse_list = []
r2_list = []

for seed in range(30):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmse_list.append(rmse)
    r2_list.append(r2)
    
    print(f'Seed {seed} -> RMSE: {rmse}, R²: {r2}')

average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)


print(f'\nR²_mean: {average_r2}')
print(f'R²_sd: {std_r2}')

print(f'RMSE_mean: {average_rmse}')
print(f'RMSE_sd: {std_rmse}')
# Out:
# Seed 0 -> RMSE: 24.114516052649012, R²: 0.3266234348969247
# Seed 1 -> RMSE: 24.355076698104103, R²: 0.2711529815856728
# Seed 2 -> RMSE: 25.855189676634662, R²: 0.24741221178245554
# Seed 3 -> RMSE: 23.94988261460911, R²: 0.3036317864724466
# Seed 4 -> RMSE: 27.555727264352466, R²: 0.22774454906901997
# Seed 5 -> RMSE: 24.15808575686502, R²: 0.28798177412316917
# Seed 6 -> RMSE: 23.05586598785461, R²: 0.3391166591975944
# Seed 7 -> RMSE: 23.65395163423275, R²: 0.30131434789066436
# Seed 8 -> RMSE: 23.945294749769392, R²: 0.27390918946437504
# Seed 9 -> RMSE: 23.753666691238312, R²: 0.2808156541002086
# Seed 10 -> RMSE: 25.694185170841887, R²: 0.207788089406734
# Seed 11 -> RMSE: 26.485657494938653, R²: 0.2367569066328814
# Seed 12 -> RMSE: 24.589293747272297, R²: 0.2898705005263448
# Seed 13 -> RMSE: 25.850473642215704, R²: 0.27575664724578974
# Seed 14 -> RMSE: 25.41104081226636, R²: 0.25611336263935713
# Seed 15 -> RMSE: 25.04461341131772, R²: 0.23892154759280393
# Seed 16 -> RMSE: 25.48612211387994, R²: 0.2731875154167912
# Seed 17 -> RMSE: 26.98869286959016, R²: 0.1874910634060245
# Seed 18 -> RMSE: 24.921985109689796, R²: 0.29772427249900724
# Seed 19 -> RMSE: 23.13743916987934, R²: 0.35005783232166077
# Seed 20 -> RMSE: 25.542681059007446, R²: 0.32934543422730667
# Seed 21 -> RMSE: 24.65950096907343, R²: 0.2490138168682604
# Seed 22 -> RMSE: 22.866012949378725, R²: 0.3699714117652375
# Seed 23 -> RMSE: 24.055695376742328, R²: 0.333101719250951
# Seed 24 -> RMSE: 26.27258312270036, R²: 0.22816108646754252
# Seed 25 -> RMSE: 25.844148756254718, R²: 0.2974546937422754
# Seed 26 -> RMSE: 25.06029088215414, R²: 0.2843961063380033
# Seed 27 -> RMSE: 23.579980057000334, R²: 0.32226844101670915
# Seed 28 -> RMSE: 25.367588213465535, R²: 0.3214525092873972
# Seed 29 -> RMSE: 23.759602932937337, R²: 0.33126525848379984
#
# R²_mean: 0.2846600267905803
# R²_sd: 0.04348975633312608
# RMSE_mean: 24.83382816623052
# RMSE_sd: 1.1691003269799118

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'mapped_rxn' == i:
        continue
#     if 'ReactSeq_MEO' in i:
#         continue
    if 'ReactSeq_all' in i:
        continue
    if 'AP3_256' in i:
        continue
    if 'Drfp' in i:
        continue
    if 'rxnfp_pretrained' in i:
        continue
    if 'rxnfp_ft_10k' in i:
        continue

    if 'amine_' in i and i != 'amine_amount':
        continue
    if 'halide_' in i:
        continue
    if 'product_' in i:
        continue
    feature_col.append(i)

# %%
feature_col
# Out:
# ['temperature',
#  'metal_amount',
#  'amine_amount',
#  'base_amount',
#  'ligand_amount',
#  'reaction_volume',
#  'solvent_1',
#  'solvent_2',
#  'solvent_MaxEStateIndex',
#  'solvent_MinEStateIndex',
#  'solvent_MaxAbsEStateIndex',
#  'solvent_MinAbsEStateIndex',
#  'solvent_qed',
#  'solvent_MolWt',
#  'solvent_HeavyAtomMolWt',
#  'solvent_ExactMolWt',
#  'solvent_NumValenceElectrons',
#  'solvent_MaxPartialCharge',
#  'solvent_MinPartialCharge',
#  'solvent_MaxAbsPartialCharge',
#  'solvent_MinAbsPartialCharge',
#  'solvent_FpDensityMorgan1',
#  'solvent_FpDensityMorgan2',
#  'solvent_FpDensityMorgan3',
#  'solvent_BCUT2D_MWHI',
#  'solvent_BCUT2D_MWLOW',
#  'solvent_BCUT2D_CHGHI',
#  'solvent_BCUT2D_CHGLO',
#  'solvent_BCUT2D_LOGPHI',
#  'solvent_BCUT2D_LOGPLOW',
#  'solvent_BCUT2D_MRHI',
#  'solvent_BCUT2D_MRLOW',
#  'solvent_BalabanJ',
#  'solvent_BertzCT',
#  'solvent_Chi0',
#  'solvent_Chi0n',
#  'solvent_Chi0v',
#  'solvent_Chi1',
#  'solvent_Chi1n',
#  'solvent_Chi1v',
#  'solvent_Chi2n',
#  'solvent_Chi2v',
#  'solvent_Chi3n',
#  'solvent_Chi3v',
#  'solvent_Chi4n',
#  'solvent_Chi4v',
#  'solvent_HallKierAlpha',
#  'solvent_Ipc',
#  'solvent_Kappa1',
#  'solvent_Kappa2',
#  'solvent_Kappa3',
#  'solvent_LabuteASA',
#  'solvent_PEOE_VSA1',
#  'solvent_PEOE_VSA10',
#  'solvent_PEOE_VSA12',
#  'solvent_PEOE_VSA14',
#  'solvent_PEOE_VSA2',
#  'solvent_PEOE_VSA4',
#  'solvent_PEOE_VSA6',
#  'solvent_PEOE_VSA7',
#  'solvent_PEOE_VSA8',
#  'solvent_PEOE_VSA9',
#  'solvent_SMR_VSA1',
#  'solvent_SMR_VSA10',
#  'solvent_SMR_VSA2',
#  'solvent_SMR_VSA3',
#  'solvent_SMR_VSA5',
#  'solvent_SMR_VSA6',
#  'solvent_SMR_VSA7',
#  'solvent_SMR_VSA9',
#  'solvent_SlogP_VSA1',
#  'solvent_SlogP_VSA10',
#  'solvent_SlogP_VSA11',
#  'solvent_SlogP_VSA2',
#  'solvent_SlogP_VSA3',
#  'solvent_SlogP_VSA4',
#  'solvent_SlogP_VSA5',
#  'solvent_SlogP_VSA6',
#  'solvent_TPSA',
#  'solvent_EState_VSA1',
#  'solvent_EState_VSA10',
#  'solvent_EState_VSA2',
#  'solvent_EState_VSA4',
#  'solvent_EState_VSA8',
#  'solvent_EState_VSA9',
#  'solvent_VSA_EState1',
#  'solvent_VSA_EState2',
#  'solvent_VSA_EState3',
#  'solvent_VSA_EState4',
#  'solvent_VSA_EState5',
#  'solvent_VSA_EState6',
#  'solvent_VSA_EState7',
#  'solvent_VSA_EState8',
#  'solvent_VSA_EState9',
#  'solvent_FractionCSP3',
#  'solvent_HeavyAtomCount',
#  'solvent_NHOHCount',
#  'solvent_NOCount',
#  'solvent_NumAliphaticHeterocycles',
#  'solvent_NumAliphaticRings',
#  'solvent_NumAromaticCarbocycles',
#  'solvent_NumAromaticRings',
#  'solvent_NumHAcceptors',
#  'solvent_NumHDonors',
#  'solvent_NumHeteroatoms',
#  'solvent_NumRotatableBonds',
#  'solvent_NumSaturatedHeterocycles',
#  'solvent_NumSaturatedRings',
#  'solvent_RingCount',
#  'solvent_MolLogP',
#  'solvent_MolMR',
#  'solvent_fr_Al_OH',
#  'solvent_fr_C_O',
#  'solvent_fr_C_O_noCOO',
#  'solvent_fr_NH0',
#  'solvent_fr_Ndealkylation2',
#  'solvent_fr_alkyl_halide',
#  'solvent_fr_amide',
#  'solvent_fr_benzene',
#  'solvent_fr_ester',
#  'solvent_fr_ether',
#  'solvent_fr_halogen',
#  'solvent_fr_methoxy',
#  'solvent_fr_nitrile',
#  'solvent_fr_para_hydroxylation',
#  'base_MaxEStateIndex',
#  'base_MinEStateIndex',
#  'base_MaxAbsEStateIndex',
#  'base_MinAbsEStateIndex',
#  'base_qed',
#  'base_MolWt',
#  'base_HeavyAtomMolWt',
#  'base_ExactMolWt',
#  'base_NumValenceElectrons',
#  'base_MaxPartialCharge',
#  'base_MinPartialCharge',
#  'base_MaxAbsPartialCharge',
#  'base_MinAbsPartialCharge',
#  'base_FpDensityMorgan1',
#  'base_FpDensityMorgan2',
#  'base_FpDensityMorgan3',
#  'base_BCUT2D_MWHI',
#  'base_BCUT2D_MWLOW',
#  'base_BCUT2D_CHGHI',
#  'base_BCUT2D_CHGLO',
#  'base_BCUT2D_LOGPHI',
#  'base_BCUT2D_LOGPLOW',
#  'base_BCUT2D_MRHI',
#  'base_BCUT2D_MRLOW',
#  'base_BalabanJ',
#  'base_BertzCT',
#  'base_Chi0',
#  'base_Chi0n',
#  'base_Chi0v',
#  'base_Chi1',
#  'base_Chi1n',
#  'base_Chi1v',
#  'base_Chi2n',
#  'base_Chi2v',
#  'base_Chi3n',
#  'base_Chi3v',
#  'base_Chi4n',
#  'base_Chi4v',
#  'base_HallKierAlpha',
#  'base_Ipc',
#  'base_Kappa1',
#  'base_Kappa2',
#  'base_Kappa3',
#  'base_LabuteASA',
#  'base_PEOE_VSA1',
#  'base_PEOE_VSA14',
#  'base_PEOE_VSA2',
#  'base_PEOE_VSA4',
#  'base_PEOE_VSA5',
#  'base_PEOE_VSA6',
#  'base_PEOE_VSA7',
#  'base_PEOE_VSA8',
#  'base_PEOE_VSA9',
#  'base_SMR_VSA1',
#  'base_SMR_VSA10',
#  'base_SMR_VSA3',
#  'base_SMR_VSA4',
#  'base_SMR_VSA5',
#  'base_SMR_VSA6',
#  'base_SMR_VSA7',
#  'base_SMR_VSA9',
#  'base_SlogP_VSA1',
#  'base_SlogP_VSA10',
#  'base_SlogP_VSA11',
#  'base_SlogP_VSA12',
#  'base_SlogP_VSA2',
#  'base_SlogP_VSA3',
#  'base_SlogP_VSA5',
#  'base_SlogP_VSA6',
#  'base_SlogP_VSA7',
#  'base_SlogP_VSA8',
#  'base_TPSA',
#  'base_EState_VSA1',
#  'base_EState_VSA10',
#  'base_EState_VSA2',
#  'base_EState_VSA8',
#  'base_EState_VSA9',
#  'base_VSA_EState1',
#  'base_VSA_EState2',
#  'base_VSA_EState3',
#  'base_VSA_EState4',
#  'base_VSA_EState5',
#  'base_VSA_EState6',
#  'base_VSA_EState7',
#  'base_VSA_EState8',
#  'base_VSA_EState9',
#  'base_FractionCSP3',
#  'base_HeavyAtomCount',
#  'base_NHOHCount',
#  'base_NOCount',
#  'base_NumAliphaticHeterocycles',
#  'base_NumAliphaticRings',
#  'base_NumAromaticCarbocycles',
#  'base_NumAromaticRings',
#  'base_NumHAcceptors',
#  'base_NumHeteroatoms',
#  'base_NumRotatableBonds',
#  'base_NumSaturatedHeterocycles',
#  'base_NumSaturatedRings',
#  'base_RingCount',
#  'base_MolLogP',
#  'base_MolMR',
#  'base_fr_COO2',
#  'base_fr_C_O',
#  'base_fr_C_O_noCOO',
#  'base_fr_Imine',
#  'base_fr_NH0',
#  'base_fr_amidine',
#  'base_fr_benzene',
#  'base_fr_bicyclic',
#  'base_fr_para_hydroxylation',
#  'base_fr_phos_acid',
#  'ligand_MaxEStateIndex',
#  'ligand_MinEStateIndex',
#  'ligand_MaxAbsEStateIndex',
#  'ligand_MinAbsEStateIndex',
#  'ligand_qed',
#  'ligand_MolWt',
#  'ligand_HeavyAtomMolWt',
#  'ligand_ExactMolWt',
#  'ligand_NumValenceElectrons',
#  'ligand_MaxPartialCharge',
#  'ligand_MinPartialCharge',
#  'ligand_MaxAbsPartialCharge',
#  'ligand_MinAbsPartialCharge',
#  'ligand_FpDensityMorgan1',
#  'ligand_FpDensityMorgan2',
#  'ligand_FpDensityMorgan3',
#  'ligand_BCUT2D_MWHI',
#  'ligand_BCUT2D_MWLOW',
#  'ligand_BCUT2D_CHGHI',
#  'ligand_BCUT2D_CHGLO',
#  'ligand_BCUT2D_LOGPHI',
#  'ligand_BCUT2D_LOGPLOW',
#  'ligand_BCUT2D_MRHI',
#  'ligand_BCUT2D_MRLOW',
#  'ligand_BalabanJ',
#  'ligand_BertzCT',
#  'ligand_Chi0',
#  'ligand_Chi0n',
#  'ligand_Chi0v',
#  'ligand_Chi1',
#  'ligand_Chi1n',
#  'ligand_Chi1v',
#  'ligand_Chi2n',
#  'ligand_Chi2v',
#  'ligand_Chi3n',
#  'ligand_Chi3v',
#  'ligand_Chi4n',
#  'ligand_Chi4v',
#  'ligand_HallKierAlpha',
#  'ligand_Ipc',
#  'ligand_Kappa1',
#  'ligand_Kappa2',
#  'ligand_Kappa3',
#  'ligand_LabuteASA',
#  'ligand_PEOE_VSA1',
#  'ligand_PEOE_VSA10',
#  'ligand_PEOE_VSA14',
#  'ligand_PEOE_VSA2',
#  'ligand_PEOE_VSA4',
#  'ligand_PEOE_VSA5',
#  'ligand_PEOE_VSA6',
#  'ligand_PEOE_VSA7',
#  'ligand_PEOE_VSA8',
#  'ligand_PEOE_VSA9',
#  'ligand_SMR_VSA1',
#  'ligand_SMR_VSA10',
#  'ligand_SMR_VSA3',
#  'ligand_SMR_VSA4',
#  'ligand_SMR_VSA5',
#  'ligand_SMR_VSA6',
#  'ligand_SMR_VSA7',
#  'ligand_SMR_VSA9',
#  'ligand_SlogP_VSA1',
#  'ligand_SlogP_VSA10',
#  'ligand_SlogP_VSA11',
#  'ligand_SlogP_VSA12',
#  'ligand_SlogP_VSA2',
#  'ligand_SlogP_VSA3',
#  'ligand_SlogP_VSA4',
#  'ligand_SlogP_VSA5',
#  'ligand_SlogP_VSA6',
#  'ligand_SlogP_VSA8',
#  'ligand_TPSA',
#  'ligand_EState_VSA1',
#  'ligand_EState_VSA10',
#  'ligand_EState_VSA11',
#  'ligand_EState_VSA2',
#  'ligand_EState_VSA9',
#  'ligand_VSA_EState1',
#  'ligand_VSA_EState2',
#  'ligand_VSA_EState3',
#  'ligand_VSA_EState4',
#  'ligand_VSA_EState5',
#  'ligand_VSA_EState6',
#  'ligand_VSA_EState7',
#  'ligand_VSA_EState8',
#  'ligand_VSA_EState9',
#  'ligand_FractionCSP3',
#  'ligand_HeavyAtomCount',
#  'ligand_NOCount',
#  'ligand_NumAliphaticCarbocycles',
#  'ligand_NumAliphaticHeterocycles',
#  'ligand_NumAliphaticRings',
#  'ligand_NumAromaticCarbocycles',
#  'ligand_NumAromaticHeterocycles',
#  'ligand_NumAromaticRings',
#  'ligand_NumHAcceptors',
#  'ligand_NumHeteroatoms',
#  'ligand_NumRotatableBonds',
#  'ligand_NumSaturatedCarbocycles',
#  'ligand_NumSaturatedHeterocycles',
#  'ligand_NumSaturatedRings',
#  'ligand_RingCount',
#  'ligand_MolLogP',
#  'ligand_MolMR',
#  'ligand_fr_Ar_N',
#  'ligand_fr_NH0',
#  'ligand_fr_alkyl_halide',
#  'ligand_fr_aniline',
#  'ligand_fr_benzene',
#  'ligand_fr_bicyclic',
#  'ligand_fr_ether',
#  'ligand_fr_furan',
#  'ligand_fr_halogen',
#  'ligand_fr_methoxy',
#  'ligand_fr_para_hydroxylation',
#  'ligand_molecular_weight',
#  'ligand_hardness',
#  'ligand_dipole_moment',
#  'ligand_electronegativity',
#  'ligand_E_HOMO',
#  'ligand_E_LOMO',
#  'ligand_.P1_electrostatic_charge',
#  'ligand_.P1_NMR_shift',
#  'ReactSeq_MEO_0',
#  'ReactSeq_MEO_1',
#  'ReactSeq_MEO_2',
#  'ReactSeq_MEO_3',
#  'ReactSeq_MEO_4',
#  'ReactSeq_MEO_5',
#  'ReactSeq_MEO_6',
#  'ReactSeq_MEO_7',
#  'ReactSeq_MEO_8',
#  'ReactSeq_MEO_9',
#  'ReactSeq_MEO_10',
#  'ReactSeq_MEO_11',
#  'ReactSeq_MEO_12',
#  'ReactSeq_MEO_13',
#  'ReactSeq_MEO_14',
#  'ReactSeq_MEO_15',
#  'ReactSeq_MEO_16',
#  'ReactSeq_MEO_17',
#  'ReactSeq_MEO_18',
#  'ReactSeq_MEO_19',
#  'ReactSeq_MEO_20',
#  'ReactSeq_MEO_21',
#  'ReactSeq_MEO_22',
#  'ReactSeq_MEO_23',
#  'ReactSeq_MEO_24',
#  'ReactSeq_MEO_25',
#  'ReactSeq_MEO_26',
#  'ReactSeq_MEO_27',
#  'ReactSeq_MEO_28',
#  'ReactSeq_MEO_29',
#  'ReactSeq_MEO_30',
#  'ReactSeq_MEO_31',
#  'ReactSeq_MEO_32',
#  'ReactSeq_MEO_33',
#  'ReactSeq_MEO_34',
#  'ReactSeq_MEO_35',
#  'ReactSeq_MEO_36',
#  'ReactSeq_MEO_37',
#  'ReactSeq_MEO_38',
#  'ReactSeq_MEO_39',
#  'ReactSeq_MEO_40',
#  'ReactSeq_MEO_41',
#  'ReactSeq_MEO_42',
#  'ReactSeq_MEO_43',
#  'ReactSeq_MEO_44',
#  'ReactSeq_MEO_45',
#  'ReactSeq_MEO_46',
#  'ReactSeq_MEO_47',
#  'ReactSeq_MEO_48',
#  'ReactSeq_MEO_49',
#  'ReactSeq_MEO_50',
#  'ReactSeq_MEO_51',
#  'ReactSeq_MEO_52',
#  'ReactSeq_MEO_53',
#  'ReactSeq_MEO_54',
#  'ReactSeq_MEO_55',
#  'ReactSeq_MEO_56',
#  'ReactSeq_MEO_57',
#  'ReactSeq_MEO_58',
#  'ReactSeq_MEO_59',
#  'ReactSeq_MEO_60',
#  'ReactSeq_MEO_61',
#  'ReactSeq_MEO_62',
#  'ReactSeq_MEO_63',
#  'ReactSeq_MEO_64',
#  'ReactSeq_MEO_65',
#  'ReactSeq_MEO_66',
#  'ReactSeq_MEO_67',
#  'ReactSeq_MEO_68',
#  'ReactSeq_MEO_69',
#  'ReactSeq_MEO_70',
#  'ReactSeq_MEO_71',
#  'ReactSeq_MEO_72',
#  'ReactSeq_MEO_73',
#  'ReactSeq_MEO_74',
#  'ReactSeq_MEO_75',
#  'ReactSeq_MEO_76',
#  'ReactSeq_MEO_77',
#  'ReactSeq_MEO_78',
#  'ReactSeq_MEO_79',
#  'ReactSeq_MEO_80',
#  'ReactSeq_MEO_81',
#  'ReactSeq_MEO_82',
#  'ReactSeq_MEO_83',
#  'ReactSeq_MEO_84',
#  'ReactSeq_MEO_85',
#  'ReactSeq_MEO_86',
#  'ReactSeq_MEO_87',
#  'ReactSeq_MEO_88',
#  'ReactSeq_MEO_89',
#  'ReactSeq_MEO_90',
#  'ReactSeq_MEO_91',
#  'ReactSeq_MEO_92',
#  'ReactSeq_MEO_93',
#  'ReactSeq_MEO_94',
#  'ReactSeq_MEO_95',
#  'ReactSeq_MEO_96',
#  'ReactSeq_MEO_97',
#  'ReactSeq_MEO_98',
#  'ReactSeq_MEO_99',
#  'ReactSeq_MEO_100',
#  'ReactSeq_MEO_101',
#  'ReactSeq_MEO_102',
#  'ReactSeq_MEO_103',
#  'ReactSeq_MEO_104',
#  'ReactSeq_MEO_105',
#  'ReactSeq_MEO_106',
#  'ReactSeq_MEO_107',
#  'ReactSeq_MEO_108',
#  'ReactSeq_MEO_109',
#  'ReactSeq_MEO_110',
#  'ReactSeq_MEO_111',
#  'ReactSeq_MEO_112',
#  'ReactSeq_MEO_113',
#  'ReactSeq_MEO_114',
#  'ReactSeq_MEO_115',
#  'ReactSeq_MEO_116',
#  'ReactSeq_MEO_117',
#  'ReactSeq_MEO_118',
#  'ReactSeq_MEO_119',
#  'ReactSeq_MEO_120',
#  'ReactSeq_MEO_121',
#  'ReactSeq_MEO_122',
#  'ReactSeq_MEO_123',
#  'ReactSeq_MEO_124',
#  'ReactSeq_MEO_125',
#  'ReactSeq_MEO_126',
#  'ReactSeq_MEO_127',
#  'ReactSeq_MEO_128',
#  'ReactSeq_MEO_129',
#  'ReactSeq_MEO_130',
#  'ReactSeq_MEO_131',
#  'ReactSeq_MEO_132',
#  'ReactSeq_MEO_133',
#  'ReactSeq_MEO_134',
#  'ReactSeq_MEO_135',
#  'ReactSeq_MEO_136',
#  'ReactSeq_MEO_137',
#  'ReactSeq_MEO_138',
#  'ReactSeq_MEO_139',
#  'ReactSeq_MEO_140',
#  'ReactSeq_MEO_141',
#  'ReactSeq_MEO_142',
#  'ReactSeq_MEO_143',
#  'ReactSeq_MEO_144',
#  'ReactSeq_MEO_145',
#  'ReactSeq_MEO_146',
#  'ReactSeq_MEO_147',
#  'ReactSeq_MEO_148',
#  'ReactSeq_MEO_149',
#  'ReactSeq_MEO_150',
#  'ReactSeq_MEO_151',
#  'ReactSeq_MEO_152',
#  'ReactSeq_MEO_153',
#  'ReactSeq_MEO_154',
#  'ReactSeq_MEO_155',
#  'ReactSeq_MEO_156',
#  'ReactSeq_MEO_157',
#  'ReactSeq_MEO_158',
#  'ReactSeq_MEO_159',
#  'ReactSeq_MEO_160',
#  'ReactSeq_MEO_161',
#  'ReactSeq_MEO_162',
#  'ReactSeq_MEO_163',
#  'ReactSeq_MEO_164',
#  'ReactSeq_MEO_165',
#  'ReactSeq_MEO_166',
#  'ReactSeq_MEO_167',
#  'ReactSeq_MEO_168',
#  'ReactSeq_MEO_169',
#  'ReactSeq_MEO_170',
#  'ReactSeq_MEO_171',
#  'ReactSeq_MEO_172',
#  'ReactSeq_MEO_173',
#  'ReactSeq_MEO_174',
#  'ReactSeq_MEO_175',
#  'ReactSeq_MEO_176',
#  'ReactSeq_MEO_177',
#  'ReactSeq_MEO_178',
#  'ReactSeq_MEO_179',
#  'ReactSeq_MEO_180',
#  'ReactSeq_MEO_181',
#  'ReactSeq_MEO_182',
#  'ReactSeq_MEO_183',
#  'ReactSeq_MEO_184',
#  'ReactSeq_MEO_185',
#  'ReactSeq_MEO_186',
#  'ReactSeq_MEO_187',
#  'ReactSeq_MEO_188',
#  'ReactSeq_MEO_189',
#  'ReactSeq_MEO_190',
#  'ReactSeq_MEO_191',
#  'ReactSeq_MEO_192',
#  'ReactSeq_MEO_193',
#  'ReactSeq_MEO_194',
#  'ReactSeq_MEO_195',
#  'ReactSeq_MEO_196',
#  'ReactSeq_MEO_197',
#  'ReactSeq_MEO_198',
#  'ReactSeq_MEO_199',
#  'ReactSeq_MEO_200',
#  'ReactSeq_MEO_201',
#  'ReactSeq_MEO_202',
#  'ReactSeq_MEO_203',
#  'ReactSeq_MEO_204',
#  'ReactSeq_MEO_205',
#  'ReactSeq_MEO_206',
#  'ReactSeq_MEO_207',
#  'ReactSeq_MEO_208',
#  'ReactSeq_MEO_209',
#  'ReactSeq_MEO_210',
#  'ReactSeq_MEO_211',
#  'ReactSeq_MEO_212',
#  'ReactSeq_MEO_213',
#  'ReactSeq_MEO_214',
#  'ReactSeq_MEO_215',
#  'ReactSeq_MEO_216',
#  'ReactSeq_MEO_217',
#  'ReactSeq_MEO_218',
#  'ReactSeq_MEO_219',
#  'ReactSeq_MEO_220',
#  'ReactSeq_MEO_221',
#  'ReactSeq_MEO_222',
#  'ReactSeq_MEO_223',
#  'ReactSeq_MEO_224',
#  'ReactSeq_MEO_225',
#  'ReactSeq_MEO_226',
#  'ReactSeq_MEO_227',
#  'ReactSeq_MEO_228',
#  'ReactSeq_MEO_229',
#  'ReactSeq_MEO_230',
#  'ReactSeq_MEO_231',
#  'ReactSeq_MEO_232',
#  'ReactSeq_MEO_233',
#  'ReactSeq_MEO_234',
#  'ReactSeq_MEO_235',
#  'ReactSeq_MEO_236',
#  'ReactSeq_MEO_237',
#  'ReactSeq_MEO_238',
#  'ReactSeq_MEO_239',
#  'ReactSeq_MEO_240',
#  'ReactSeq_MEO_241',
#  'ReactSeq_MEO_242',
#  'ReactSeq_MEO_243',
#  'ReactSeq_MEO_244',
#  'ReactSeq_MEO_245',
#  'ReactSeq_MEO_246',
#  'ReactSeq_MEO_247',
#  'ReactSeq_MEO_248',
#  'ReactSeq_MEO_249',
#  'ReactSeq_MEO_250',
#  'ReactSeq_MEO_251',
#  'ReactSeq_MEO_252',
#  'ReactSeq_MEO_253',
#  'ReactSeq_MEO_254',
#  'ReactSeq_MEO_255']

# %%
len(feature_col)
# Out:
# 617

# %%
X = df_cat[feature_col]

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Lists to store the results
rmse_list = []
r2_list = []

for seed in range(30):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmse_list.append(rmse)
    r2_list.append(r2)
    
    print(f'Seed {seed} -> RMSE: {rmse}, R²: {r2}')

average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)


print(f'\nR²_mean: {average_r2}')
print(f'R²_sd: {std_r2}')

print(f'RMSE_mean: {average_rmse}')
print(f'RMSE_sd: {std_rmse}')
# Out:
# Seed 0 -> RMSE: 23.82021232052216, R²: 0.34295948049600367
# Seed 1 -> RMSE: 24.484088495144036, R²: 0.2634109482855064
# Seed 2 -> RMSE: 25.88456660993788, R²: 0.24570104418983174
# Seed 3 -> RMSE: 23.44661453151535, R²: 0.33259040203836776
# Seed 4 -> RMSE: 26.764213140893947, R²: 0.27147210265122323
# Seed 5 -> RMSE: 24.066529676477153, R²: 0.29336846480948187
# Seed 6 -> RMSE: 23.912742883297827, R²: 0.2890800286900279
# Seed 7 -> RMSE: 23.447327686025687, R²: 0.3134674675783745
# Seed 8 -> RMSE: 23.412680066367646, R²: 0.30585080096563566
# Seed 9 -> RMSE: 23.8259481933589, R²: 0.27643209363804055
# Seed 10 -> RMSE: 25.394710253693038, R²: 0.226147495780612
# Seed 11 -> RMSE: 26.364698746590005, R²: 0.24371237803189372
# Seed 12 -> RMSE: 24.816723231516463, R²: 0.27667359664507696
# Seed 13 -> RMSE: 26.139367470152074, R²: 0.25947852663989857
# Seed 14 -> RMSE: 25.745289604471985, R²: 0.23641495681734015
# Seed 15 -> RMSE: 25.37772424565467, R²: 0.2185411573132754
# Seed 16 -> RMSE: 25.418210291170734, R²: 0.27705576949732424
# Seed 17 -> RMSE: 26.882368231964485, R²: 0.1938803723086434
# Seed 18 -> RMSE: 25.093643084916064, R²: 0.28801666726058717
# Seed 19 -> RMSE: 22.801325274266162, R²: 0.36880388842184086
# Seed 20 -> RMSE: 25.378362350761194, R²: 0.33794645963761005
# Seed 21 -> RMSE: 24.37096532437637, R²: 0.266485263871553
# Seed 22 -> RMSE: 23.174876519637476, R²: 0.35283618884295476
# Seed 23 -> RMSE: 23.829823707531798, R²: 0.34556664591273
# Seed 24 -> RMSE: 25.761808542337327, R²: 0.2578805440126759
# Seed 25 -> RMSE: 26.069032335667718, R²: 0.28517506435403017
# Seed 26 -> RMSE: 24.69033089086315, R²: 0.3053687777674765
# Seed 27 -> RMSE: 23.335797446298393, R²: 0.33623226909307913
# Seed 28 -> RMSE: 25.424284537814103, R²: 0.31841602512300526
# Seed 29 -> RMSE: 24.027914179263345, R²: 0.3160762693290856
#
# R²_mean: 0.2881680383334395
# R²_sd: 0.04252834696205904
# RMSE_mean: 24.77207266241624
# RMSE_sd: 1.1303656391240504

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'ReactSeq_all' in i:
        feature_col.append(i)
feature_col
# Out:
# ['ReactSeq_all_0',
#  'ReactSeq_all_1',
#  'ReactSeq_all_2',
#  'ReactSeq_all_3',
#  'ReactSeq_all_4',
#  'ReactSeq_all_5',
#  'ReactSeq_all_6',
#  'ReactSeq_all_7',
#  'ReactSeq_all_8',
#  'ReactSeq_all_9',
#  'ReactSeq_all_10',
#  'ReactSeq_all_11',
#  'ReactSeq_all_12',
#  'ReactSeq_all_13',
#  'ReactSeq_all_14',
#  'ReactSeq_all_15',
#  'ReactSeq_all_16',
#  'ReactSeq_all_17',
#  'ReactSeq_all_18',
#  'ReactSeq_all_19',
#  'ReactSeq_all_20',
#  'ReactSeq_all_21',
#  'ReactSeq_all_22',
#  'ReactSeq_all_23',
#  'ReactSeq_all_24',
#  'ReactSeq_all_25',
#  'ReactSeq_all_26',
#  'ReactSeq_all_27',
#  'ReactSeq_all_28',
#  'ReactSeq_all_29',
#  'ReactSeq_all_30',
#  'ReactSeq_all_31',
#  'ReactSeq_all_32',
#  'ReactSeq_all_33',
#  'ReactSeq_all_34',
#  'ReactSeq_all_35',
#  'ReactSeq_all_36',
#  'ReactSeq_all_37',
#  'ReactSeq_all_38',
#  'ReactSeq_all_39',
#  'ReactSeq_all_40',
#  'ReactSeq_all_41',
#  'ReactSeq_all_42',
#  'ReactSeq_all_43',
#  'ReactSeq_all_44',
#  'ReactSeq_all_45',
#  'ReactSeq_all_46',
#  'ReactSeq_all_47',
#  'ReactSeq_all_48',
#  'ReactSeq_all_49',
#  'ReactSeq_all_50',
#  'ReactSeq_all_51',
#  'ReactSeq_all_52',
#  'ReactSeq_all_53',
#  'ReactSeq_all_54',
#  'ReactSeq_all_55',
#  'ReactSeq_all_56',
#  'ReactSeq_all_57',
#  'ReactSeq_all_58',
#  'ReactSeq_all_59',
#  'ReactSeq_all_60',
#  'ReactSeq_all_61',
#  'ReactSeq_all_62',
#  'ReactSeq_all_63',
#  'ReactSeq_all_64',
#  'ReactSeq_all_65',
#  'ReactSeq_all_66',
#  'ReactSeq_all_67',
#  'ReactSeq_all_68',
#  'ReactSeq_all_69',
#  'ReactSeq_all_70',
#  'ReactSeq_all_71',
#  'ReactSeq_all_72',
#  'ReactSeq_all_73',
#  'ReactSeq_all_74',
#  'ReactSeq_all_75',
#  'ReactSeq_all_76',
#  'ReactSeq_all_77',
#  'ReactSeq_all_78',
#  'ReactSeq_all_79',
#  'ReactSeq_all_80',
#  'ReactSeq_all_81',
#  'ReactSeq_all_82',
#  'ReactSeq_all_83',
#  'ReactSeq_all_84',
#  'ReactSeq_all_85',
#  'ReactSeq_all_86',
#  'ReactSeq_all_87',
#  'ReactSeq_all_88',
#  'ReactSeq_all_89',
#  'ReactSeq_all_90',
#  'ReactSeq_all_91',
#  'ReactSeq_all_92',
#  'ReactSeq_all_93',
#  'ReactSeq_all_94',
#  'ReactSeq_all_95',
#  'ReactSeq_all_96',
#  'ReactSeq_all_97',
#  'ReactSeq_all_98',
#  'ReactSeq_all_99',
#  'ReactSeq_all_100',
#  'ReactSeq_all_101',
#  'ReactSeq_all_102',
#  'ReactSeq_all_103',
#  'ReactSeq_all_104',
#  'ReactSeq_all_105',
#  'ReactSeq_all_106',
#  'ReactSeq_all_107',
#  'ReactSeq_all_108',
#  'ReactSeq_all_109',
#  'ReactSeq_all_110',
#  'ReactSeq_all_111',
#  'ReactSeq_all_112',
#  'ReactSeq_all_113',
#  'ReactSeq_all_114',
#  'ReactSeq_all_115',
#  'ReactSeq_all_116',
#  'ReactSeq_all_117',
#  'ReactSeq_all_118',
#  'ReactSeq_all_119',
#  'ReactSeq_all_120',
#  'ReactSeq_all_121',
#  'ReactSeq_all_122',
#  'ReactSeq_all_123',
#  'ReactSeq_all_124',
#  'ReactSeq_all_125',
#  'ReactSeq_all_126',
#  'ReactSeq_all_127',
#  'ReactSeq_all_128',
#  'ReactSeq_all_129',
#  'ReactSeq_all_130',
#  'ReactSeq_all_131',
#  'ReactSeq_all_132',
#  'ReactSeq_all_133',
#  'ReactSeq_all_134',
#  'ReactSeq_all_135',
#  'ReactSeq_all_136',
#  'ReactSeq_all_137',
#  'ReactSeq_all_138',
#  'ReactSeq_all_139',
#  'ReactSeq_all_140',
#  'ReactSeq_all_141',
#  'ReactSeq_all_142',
#  'ReactSeq_all_143',
#  'ReactSeq_all_144',
#  'ReactSeq_all_145',
#  'ReactSeq_all_146',
#  'ReactSeq_all_147',
#  'ReactSeq_all_148',
#  'ReactSeq_all_149',
#  'ReactSeq_all_150',
#  'ReactSeq_all_151',
#  'ReactSeq_all_152',
#  'ReactSeq_all_153',
#  'ReactSeq_all_154',
#  'ReactSeq_all_155',
#  'ReactSeq_all_156',
#  'ReactSeq_all_157',
#  'ReactSeq_all_158',
#  'ReactSeq_all_159',
#  'ReactSeq_all_160',
#  'ReactSeq_all_161',
#  'ReactSeq_all_162',
#  'ReactSeq_all_163',
#  'ReactSeq_all_164',
#  'ReactSeq_all_165',
#  'ReactSeq_all_166',
#  'ReactSeq_all_167',
#  'ReactSeq_all_168',
#  'ReactSeq_all_169',
#  'ReactSeq_all_170',
#  'ReactSeq_all_171',
#  'ReactSeq_all_172',
#  'ReactSeq_all_173',
#  'ReactSeq_all_174',
#  'ReactSeq_all_175',
#  'ReactSeq_all_176',
#  'ReactSeq_all_177',
#  'ReactSeq_all_178',
#  'ReactSeq_all_179',
#  'ReactSeq_all_180',
#  'ReactSeq_all_181',
#  'ReactSeq_all_182',
#  'ReactSeq_all_183',
#  'ReactSeq_all_184',
#  'ReactSeq_all_185',
#  'ReactSeq_all_186',
#  'ReactSeq_all_187',
#  'ReactSeq_all_188',
#  'ReactSeq_all_189',
#  'ReactSeq_all_190',
#  'ReactSeq_all_191',
#  'ReactSeq_all_192',
#  'ReactSeq_all_193',
#  'ReactSeq_all_194',
#  'ReactSeq_all_195',
#  'ReactSeq_all_196',
#  'ReactSeq_all_197',
#  'ReactSeq_all_198',
#  'ReactSeq_all_199',
#  'ReactSeq_all_200',
#  'ReactSeq_all_201',
#  'ReactSeq_all_202',
#  'ReactSeq_all_203',
#  'ReactSeq_all_204',
#  'ReactSeq_all_205',
#  'ReactSeq_all_206',
#  'ReactSeq_all_207',
#  'ReactSeq_all_208',
#  'ReactSeq_all_209',
#  'ReactSeq_all_210',
#  'ReactSeq_all_211',
#  'ReactSeq_all_212',
#  'ReactSeq_all_213',
#  'ReactSeq_all_214',
#  'ReactSeq_all_215',
#  'ReactSeq_all_216',
#  'ReactSeq_all_217',
#  'ReactSeq_all_218',
#  'ReactSeq_all_219',
#  'ReactSeq_all_220',
#  'ReactSeq_all_221',
#  'ReactSeq_all_222',
#  'ReactSeq_all_223',
#  'ReactSeq_all_224',
#  'ReactSeq_all_225',
#  'ReactSeq_all_226',
#  'ReactSeq_all_227',
#  'ReactSeq_all_228',
#  'ReactSeq_all_229',
#  'ReactSeq_all_230',
#  'ReactSeq_all_231',
#  'ReactSeq_all_232',
#  'ReactSeq_all_233',
#  'ReactSeq_all_234',
#  'ReactSeq_all_235',
#  'ReactSeq_all_236',
#  'ReactSeq_all_237',
#  'ReactSeq_all_238',
#  'ReactSeq_all_239',
#  'ReactSeq_all_240',
#  'ReactSeq_all_241',
#  'ReactSeq_all_242',
#  'ReactSeq_all_243',
#  'ReactSeq_all_244',
#  'ReactSeq_all_245',
#  'ReactSeq_all_246',
#  'ReactSeq_all_247',
#  'ReactSeq_all_248',
#  'ReactSeq_all_249',
#  'ReactSeq_all_250',
#  'ReactSeq_all_251',
#  'ReactSeq_all_252',
#  'ReactSeq_all_253',
#  'ReactSeq_all_254',
#  'ReactSeq_all_255']

# %%
feature_col
# Out:
# ['ReactSeq_all_0',
#  'ReactSeq_all_1',
#  'ReactSeq_all_2',
#  'ReactSeq_all_3',
#  'ReactSeq_all_4',
#  'ReactSeq_all_5',
#  'ReactSeq_all_6',
#  'ReactSeq_all_7',
#  'ReactSeq_all_8',
#  'ReactSeq_all_9',
#  'ReactSeq_all_10',
#  'ReactSeq_all_11',
#  'ReactSeq_all_12',
#  'ReactSeq_all_13',
#  'ReactSeq_all_14',
#  'ReactSeq_all_15',
#  'ReactSeq_all_16',
#  'ReactSeq_all_17',
#  'ReactSeq_all_18',
#  'ReactSeq_all_19',
#  'ReactSeq_all_20',
#  'ReactSeq_all_21',
#  'ReactSeq_all_22',
#  'ReactSeq_all_23',
#  'ReactSeq_all_24',
#  'ReactSeq_all_25',
#  'ReactSeq_all_26',
#  'ReactSeq_all_27',
#  'ReactSeq_all_28',
#  'ReactSeq_all_29',
#  'ReactSeq_all_30',
#  'ReactSeq_all_31',
#  'ReactSeq_all_32',
#  'ReactSeq_all_33',
#  'ReactSeq_all_34',
#  'ReactSeq_all_35',
#  'ReactSeq_all_36',
#  'ReactSeq_all_37',
#  'ReactSeq_all_38',
#  'ReactSeq_all_39',
#  'ReactSeq_all_40',
#  'ReactSeq_all_41',
#  'ReactSeq_all_42',
#  'ReactSeq_all_43',
#  'ReactSeq_all_44',
#  'ReactSeq_all_45',
#  'ReactSeq_all_46',
#  'ReactSeq_all_47',
#  'ReactSeq_all_48',
#  'ReactSeq_all_49',
#  'ReactSeq_all_50',
#  'ReactSeq_all_51',
#  'ReactSeq_all_52',
#  'ReactSeq_all_53',
#  'ReactSeq_all_54',
#  'ReactSeq_all_55',
#  'ReactSeq_all_56',
#  'ReactSeq_all_57',
#  'ReactSeq_all_58',
#  'ReactSeq_all_59',
#  'ReactSeq_all_60',
#  'ReactSeq_all_61',
#  'ReactSeq_all_62',
#  'ReactSeq_all_63',
#  'ReactSeq_all_64',
#  'ReactSeq_all_65',
#  'ReactSeq_all_66',
#  'ReactSeq_all_67',
#  'ReactSeq_all_68',
#  'ReactSeq_all_69',
#  'ReactSeq_all_70',
#  'ReactSeq_all_71',
#  'ReactSeq_all_72',
#  'ReactSeq_all_73',
#  'ReactSeq_all_74',
#  'ReactSeq_all_75',
#  'ReactSeq_all_76',
#  'ReactSeq_all_77',
#  'ReactSeq_all_78',
#  'ReactSeq_all_79',
#  'ReactSeq_all_80',
#  'ReactSeq_all_81',
#  'ReactSeq_all_82',
#  'ReactSeq_all_83',
#  'ReactSeq_all_84',
#  'ReactSeq_all_85',
#  'ReactSeq_all_86',
#  'ReactSeq_all_87',
#  'ReactSeq_all_88',
#  'ReactSeq_all_89',
#  'ReactSeq_all_90',
#  'ReactSeq_all_91',
#  'ReactSeq_all_92',
#  'ReactSeq_all_93',
#  'ReactSeq_all_94',
#  'ReactSeq_all_95',
#  'ReactSeq_all_96',
#  'ReactSeq_all_97',
#  'ReactSeq_all_98',
#  'ReactSeq_all_99',
#  'ReactSeq_all_100',
#  'ReactSeq_all_101',
#  'ReactSeq_all_102',
#  'ReactSeq_all_103',
#  'ReactSeq_all_104',
#  'ReactSeq_all_105',
#  'ReactSeq_all_106',
#  'ReactSeq_all_107',
#  'ReactSeq_all_108',
#  'ReactSeq_all_109',
#  'ReactSeq_all_110',
#  'ReactSeq_all_111',
#  'ReactSeq_all_112',
#  'ReactSeq_all_113',
#  'ReactSeq_all_114',
#  'ReactSeq_all_115',
#  'ReactSeq_all_116',
#  'ReactSeq_all_117',
#  'ReactSeq_all_118',
#  'ReactSeq_all_119',
#  'ReactSeq_all_120',
#  'ReactSeq_all_121',
#  'ReactSeq_all_122',
#  'ReactSeq_all_123',
#  'ReactSeq_all_124',
#  'ReactSeq_all_125',
#  'ReactSeq_all_126',
#  'ReactSeq_all_127',
#  'ReactSeq_all_128',
#  'ReactSeq_all_129',
#  'ReactSeq_all_130',
#  'ReactSeq_all_131',
#  'ReactSeq_all_132',
#  'ReactSeq_all_133',
#  'ReactSeq_all_134',
#  'ReactSeq_all_135',
#  'ReactSeq_all_136',
#  'ReactSeq_all_137',
#  'ReactSeq_all_138',
#  'ReactSeq_all_139',
#  'ReactSeq_all_140',
#  'ReactSeq_all_141',
#  'ReactSeq_all_142',
#  'ReactSeq_all_143',
#  'ReactSeq_all_144',
#  'ReactSeq_all_145',
#  'ReactSeq_all_146',
#  'ReactSeq_all_147',
#  'ReactSeq_all_148',
#  'ReactSeq_all_149',
#  'ReactSeq_all_150',
#  'ReactSeq_all_151',
#  'ReactSeq_all_152',
#  'ReactSeq_all_153',
#  'ReactSeq_all_154',
#  'ReactSeq_all_155',
#  'ReactSeq_all_156',
#  'ReactSeq_all_157',
#  'ReactSeq_all_158',
#  'ReactSeq_all_159',
#  'ReactSeq_all_160',
#  'ReactSeq_all_161',
#  'ReactSeq_all_162',
#  'ReactSeq_all_163',
#  'ReactSeq_all_164',
#  'ReactSeq_all_165',
#  'ReactSeq_all_166',
#  'ReactSeq_all_167',
#  'ReactSeq_all_168',
#  'ReactSeq_all_169',
#  'ReactSeq_all_170',
#  'ReactSeq_all_171',
#  'ReactSeq_all_172',
#  'ReactSeq_all_173',
#  'ReactSeq_all_174',
#  'ReactSeq_all_175',
#  'ReactSeq_all_176',
#  'ReactSeq_all_177',
#  'ReactSeq_all_178',
#  'ReactSeq_all_179',
#  'ReactSeq_all_180',
#  'ReactSeq_all_181',
#  'ReactSeq_all_182',
#  'ReactSeq_all_183',
#  'ReactSeq_all_184',
#  'ReactSeq_all_185',
#  'ReactSeq_all_186',
#  'ReactSeq_all_187',
#  'ReactSeq_all_188',
#  'ReactSeq_all_189',
#  'ReactSeq_all_190',
#  'ReactSeq_all_191',
#  'ReactSeq_all_192',
#  'ReactSeq_all_193',
#  'ReactSeq_all_194',
#  'ReactSeq_all_195',
#  'ReactSeq_all_196',
#  'ReactSeq_all_197',
#  'ReactSeq_all_198',
#  'ReactSeq_all_199',
#  'ReactSeq_all_200',
#  'ReactSeq_all_201',
#  'ReactSeq_all_202',
#  'ReactSeq_all_203',
#  'ReactSeq_all_204',
#  'ReactSeq_all_205',
#  'ReactSeq_all_206',
#  'ReactSeq_all_207',
#  'ReactSeq_all_208',
#  'ReactSeq_all_209',
#  'ReactSeq_all_210',
#  'ReactSeq_all_211',
#  'ReactSeq_all_212',
#  'ReactSeq_all_213',
#  'ReactSeq_all_214',
#  'ReactSeq_all_215',
#  'ReactSeq_all_216',
#  'ReactSeq_all_217',
#  'ReactSeq_all_218',
#  'ReactSeq_all_219',
#  'ReactSeq_all_220',
#  'ReactSeq_all_221',
#  'ReactSeq_all_222',
#  'ReactSeq_all_223',
#  'ReactSeq_all_224',
#  'ReactSeq_all_225',
#  'ReactSeq_all_226',
#  'ReactSeq_all_227',
#  'ReactSeq_all_228',
#  'ReactSeq_all_229',
#  'ReactSeq_all_230',
#  'ReactSeq_all_231',
#  'ReactSeq_all_232',
#  'ReactSeq_all_233',
#  'ReactSeq_all_234',
#  'ReactSeq_all_235',
#  'ReactSeq_all_236',
#  'ReactSeq_all_237',
#  'ReactSeq_all_238',
#  'ReactSeq_all_239',
#  'ReactSeq_all_240',
#  'ReactSeq_all_241',
#  'ReactSeq_all_242',
#  'ReactSeq_all_243',
#  'ReactSeq_all_244',
#  'ReactSeq_all_245',
#  'ReactSeq_all_246',
#  'ReactSeq_all_247',
#  'ReactSeq_all_248',
#  'ReactSeq_all_249',
#  'ReactSeq_all_250',
#  'ReactSeq_all_251',
#  'ReactSeq_all_252',
#  'ReactSeq_all_253',
#  'ReactSeq_all_254',
#  'ReactSeq_all_255']

# %%
len(feature_col)
# Out:
# 256

# %%
X = df_cat[feature_col]

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Lists to store the results
rmse_list = []
r2_list = []

for seed in range(30):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmse_list.append(rmse)
    r2_list.append(r2)
    
    print(f'Seed {seed} -> RMSE: {rmse}, R²: {r2}')

average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)


print(f'\nR²_mean: {average_r2}')
print(f'R²_sd: {std_r2}')

print(f'RMSE_mean: {average_rmse}')
print(f'RMSE_sd: {std_rmse}')
# Out:
# Seed 0 -> RMSE: 25.6553560786333, R²: 0.23782097971570149
# Seed 1 -> RMSE: 23.892604786568494, R²: 0.29856993458482906
# Seed 2 -> RMSE: 25.223960715452016, R²: 0.2837110137941231
# Seed 3 -> RMSE: 25.20827398723064, R²: 0.2285311735100074
# Seed 4 -> RMSE: 28.64084554711641, R²: 0.1657256377142715
# Seed 5 -> RMSE: 25.854657732957907, R²: 0.18446301886365113
# Seed 6 -> RMSE: 23.966618365327314, R²: 0.28587301035372514
# Seed 7 -> RMSE: 25.05137493888376, R²: 0.21632218971470163
# Seed 8 -> RMSE: 24.510570841565936, R²: 0.23922292434361592
# Seed 9 -> RMSE: 24.206930770258523, R²: 0.25310704047862476
# Seed 10 -> RMSE: 25.70128242800347, R²: 0.20735037883934848
# Seed 11 -> RMSE: 27.037276671244506, R²: 0.20463357102137847
# Seed 12 -> RMSE: 26.23367293469809, R²: 0.19171663052046273
# Seed 13 -> RMSE: 26.752579265199827, R²: 0.22432672733732362
# Seed 14 -> RMSE: 26.29595564415689, R²: 0.2034009813933656
# Seed 15 -> RMSE: 24.554228175171787, R²: 0.26843429777965333
# Seed 16 -> RMSE: 26.115359163793933, R²: 0.2368553473641698
# Seed 17 -> RMSE: 26.390072527701268, R²: 0.22313489963497268
# Seed 18 -> RMSE: 25.72537675739312, R²: 0.2517169949513147
# Seed 19 -> RMSE: 25.015979954621898, R²: 0.24023518899540164
# Seed 20 -> RMSE: 27.93799952189769, R²: 0.19766352586134228
# Seed 21 -> RMSE: 25.52137172706218, R²: 0.19560121483314263
# Seed 22 -> RMSE: 23.93078856106501, R²: 0.3099296216234688
# Seed 23 -> RMSE: 25.879979233914906, R²: 0.22811675534585996
# Seed 24 -> RMSE: 27.514753117246435, R²: 0.15345049198700245
# Seed 25 -> RMSE: 26.812741652053745, R²: 0.2438075801337819
# Seed 26 -> RMSE: 26.48050513666736, R²: 0.20098853634450187
# Seed 27 -> RMSE: 24.602510058882658, R²: 0.26221524259281237
# Seed 28 -> RMSE: 27.0497380335181, R²: 0.22847852810988445
# Seed 29 -> RMSE: 25.486846510027267, R²: 0.23050157394771598
#
# R²_mean: 0.22986350038967188
# R²_sd: 0.03644419592835736
# RMSE_mean: 25.775007027943822
# RMSE_sd: 1.1788671617709088

# %%
feature_col = []
for i in df_cat.columns[12:]:
    if 'ReactSeq_MEO' in i:
        feature_col.append(i)
feature_col
# Out:
# ['ReactSeq_MEO_0',
#  'ReactSeq_MEO_1',
#  'ReactSeq_MEO_2',
#  'ReactSeq_MEO_3',
#  'ReactSeq_MEO_4',
#  'ReactSeq_MEO_5',
#  'ReactSeq_MEO_6',
#  'ReactSeq_MEO_7',
#  'ReactSeq_MEO_8',
#  'ReactSeq_MEO_9',
#  'ReactSeq_MEO_10',
#  'ReactSeq_MEO_11',
#  'ReactSeq_MEO_12',
#  'ReactSeq_MEO_13',
#  'ReactSeq_MEO_14',
#  'ReactSeq_MEO_15',
#  'ReactSeq_MEO_16',
#  'ReactSeq_MEO_17',
#  'ReactSeq_MEO_18',
#  'ReactSeq_MEO_19',
#  'ReactSeq_MEO_20',
#  'ReactSeq_MEO_21',
#  'ReactSeq_MEO_22',
#  'ReactSeq_MEO_23',
#  'ReactSeq_MEO_24',
#  'ReactSeq_MEO_25',
#  'ReactSeq_MEO_26',
#  'ReactSeq_MEO_27',
#  'ReactSeq_MEO_28',
#  'ReactSeq_MEO_29',
#  'ReactSeq_MEO_30',
#  'ReactSeq_MEO_31',
#  'ReactSeq_MEO_32',
#  'ReactSeq_MEO_33',
#  'ReactSeq_MEO_34',
#  'ReactSeq_MEO_35',
#  'ReactSeq_MEO_36',
#  'ReactSeq_MEO_37',
#  'ReactSeq_MEO_38',
#  'ReactSeq_MEO_39',
#  'ReactSeq_MEO_40',
#  'ReactSeq_MEO_41',
#  'ReactSeq_MEO_42',
#  'ReactSeq_MEO_43',
#  'ReactSeq_MEO_44',
#  'ReactSeq_MEO_45',
#  'ReactSeq_MEO_46',
#  'ReactSeq_MEO_47',
#  'ReactSeq_MEO_48',
#  'ReactSeq_MEO_49',
#  'ReactSeq_MEO_50',
#  'ReactSeq_MEO_51',
#  'ReactSeq_MEO_52',
#  'ReactSeq_MEO_53',
#  'ReactSeq_MEO_54',
#  'ReactSeq_MEO_55',
#  'ReactSeq_MEO_56',
#  'ReactSeq_MEO_57',
#  'ReactSeq_MEO_58',
#  'ReactSeq_MEO_59',
#  'ReactSeq_MEO_60',
#  'ReactSeq_MEO_61',
#  'ReactSeq_MEO_62',
#  'ReactSeq_MEO_63',
#  'ReactSeq_MEO_64',
#  'ReactSeq_MEO_65',
#  'ReactSeq_MEO_66',
#  'ReactSeq_MEO_67',
#  'ReactSeq_MEO_68',
#  'ReactSeq_MEO_69',
#  'ReactSeq_MEO_70',
#  'ReactSeq_MEO_71',
#  'ReactSeq_MEO_72',
#  'ReactSeq_MEO_73',
#  'ReactSeq_MEO_74',
#  'ReactSeq_MEO_75',
#  'ReactSeq_MEO_76',
#  'ReactSeq_MEO_77',
#  'ReactSeq_MEO_78',
#  'ReactSeq_MEO_79',
#  'ReactSeq_MEO_80',
#  'ReactSeq_MEO_81',
#  'ReactSeq_MEO_82',
#  'ReactSeq_MEO_83',
#  'ReactSeq_MEO_84',
#  'ReactSeq_MEO_85',
#  'ReactSeq_MEO_86',
#  'ReactSeq_MEO_87',
#  'ReactSeq_MEO_88',
#  'ReactSeq_MEO_89',
#  'ReactSeq_MEO_90',
#  'ReactSeq_MEO_91',
#  'ReactSeq_MEO_92',
#  'ReactSeq_MEO_93',
#  'ReactSeq_MEO_94',
#  'ReactSeq_MEO_95',
#  'ReactSeq_MEO_96',
#  'ReactSeq_MEO_97',
#  'ReactSeq_MEO_98',
#  'ReactSeq_MEO_99',
#  'ReactSeq_MEO_100',
#  'ReactSeq_MEO_101',
#  'ReactSeq_MEO_102',
#  'ReactSeq_MEO_103',
#  'ReactSeq_MEO_104',
#  'ReactSeq_MEO_105',
#  'ReactSeq_MEO_106',
#  'ReactSeq_MEO_107',
#  'ReactSeq_MEO_108',
#  'ReactSeq_MEO_109',
#  'ReactSeq_MEO_110',
#  'ReactSeq_MEO_111',
#  'ReactSeq_MEO_112',
#  'ReactSeq_MEO_113',
#  'ReactSeq_MEO_114',
#  'ReactSeq_MEO_115',
#  'ReactSeq_MEO_116',
#  'ReactSeq_MEO_117',
#  'ReactSeq_MEO_118',
#  'ReactSeq_MEO_119',
#  'ReactSeq_MEO_120',
#  'ReactSeq_MEO_121',
#  'ReactSeq_MEO_122',
#  'ReactSeq_MEO_123',
#  'ReactSeq_MEO_124',
#  'ReactSeq_MEO_125',
#  'ReactSeq_MEO_126',
#  'ReactSeq_MEO_127',
#  'ReactSeq_MEO_128',
#  'ReactSeq_MEO_129',
#  'ReactSeq_MEO_130',
#  'ReactSeq_MEO_131',
#  'ReactSeq_MEO_132',
#  'ReactSeq_MEO_133',
#  'ReactSeq_MEO_134',
#  'ReactSeq_MEO_135',
#  'ReactSeq_MEO_136',
#  'ReactSeq_MEO_137',
#  'ReactSeq_MEO_138',
#  'ReactSeq_MEO_139',
#  'ReactSeq_MEO_140',
#  'ReactSeq_MEO_141',
#  'ReactSeq_MEO_142',
#  'ReactSeq_MEO_143',
#  'ReactSeq_MEO_144',
#  'ReactSeq_MEO_145',
#  'ReactSeq_MEO_146',
#  'ReactSeq_MEO_147',
#  'ReactSeq_MEO_148',
#  'ReactSeq_MEO_149',
#  'ReactSeq_MEO_150',
#  'ReactSeq_MEO_151',
#  'ReactSeq_MEO_152',
#  'ReactSeq_MEO_153',
#  'ReactSeq_MEO_154',
#  'ReactSeq_MEO_155',
#  'ReactSeq_MEO_156',
#  'ReactSeq_MEO_157',
#  'ReactSeq_MEO_158',
#  'ReactSeq_MEO_159',
#  'ReactSeq_MEO_160',
#  'ReactSeq_MEO_161',
#  'ReactSeq_MEO_162',
#  'ReactSeq_MEO_163',
#  'ReactSeq_MEO_164',
#  'ReactSeq_MEO_165',
#  'ReactSeq_MEO_166',
#  'ReactSeq_MEO_167',
#  'ReactSeq_MEO_168',
#  'ReactSeq_MEO_169',
#  'ReactSeq_MEO_170',
#  'ReactSeq_MEO_171',
#  'ReactSeq_MEO_172',
#  'ReactSeq_MEO_173',
#  'ReactSeq_MEO_174',
#  'ReactSeq_MEO_175',
#  'ReactSeq_MEO_176',
#  'ReactSeq_MEO_177',
#  'ReactSeq_MEO_178',
#  'ReactSeq_MEO_179',
#  'ReactSeq_MEO_180',
#  'ReactSeq_MEO_181',
#  'ReactSeq_MEO_182',
#  'ReactSeq_MEO_183',
#  'ReactSeq_MEO_184',
#  'ReactSeq_MEO_185',
#  'ReactSeq_MEO_186',
#  'ReactSeq_MEO_187',
#  'ReactSeq_MEO_188',
#  'ReactSeq_MEO_189',
#  'ReactSeq_MEO_190',
#  'ReactSeq_MEO_191',
#  'ReactSeq_MEO_192',
#  'ReactSeq_MEO_193',
#  'ReactSeq_MEO_194',
#  'ReactSeq_MEO_195',
#  'ReactSeq_MEO_196',
#  'ReactSeq_MEO_197',
#  'ReactSeq_MEO_198',
#  'ReactSeq_MEO_199',
#  'ReactSeq_MEO_200',
#  'ReactSeq_MEO_201',
#  'ReactSeq_MEO_202',
#  'ReactSeq_MEO_203',
#  'ReactSeq_MEO_204',
#  'ReactSeq_MEO_205',
#  'ReactSeq_MEO_206',
#  'ReactSeq_MEO_207',
#  'ReactSeq_MEO_208',
#  'ReactSeq_MEO_209',
#  'ReactSeq_MEO_210',
#  'ReactSeq_MEO_211',
#  'ReactSeq_MEO_212',
#  'ReactSeq_MEO_213',
#  'ReactSeq_MEO_214',
#  'ReactSeq_MEO_215',
#  'ReactSeq_MEO_216',
#  'ReactSeq_MEO_217',
#  'ReactSeq_MEO_218',
#  'ReactSeq_MEO_219',
#  'ReactSeq_MEO_220',
#  'ReactSeq_MEO_221',
#  'ReactSeq_MEO_222',
#  'ReactSeq_MEO_223',
#  'ReactSeq_MEO_224',
#  'ReactSeq_MEO_225',
#  'ReactSeq_MEO_226',
#  'ReactSeq_MEO_227',
#  'ReactSeq_MEO_228',
#  'ReactSeq_MEO_229',
#  'ReactSeq_MEO_230',
#  'ReactSeq_MEO_231',
#  'ReactSeq_MEO_232',
#  'ReactSeq_MEO_233',
#  'ReactSeq_MEO_234',
#  'ReactSeq_MEO_235',
#  'ReactSeq_MEO_236',
#  'ReactSeq_MEO_237',
#  'ReactSeq_MEO_238',
#  'ReactSeq_MEO_239',
#  'ReactSeq_MEO_240',
#  'ReactSeq_MEO_241',
#  'ReactSeq_MEO_242',
#  'ReactSeq_MEO_243',
#  'ReactSeq_MEO_244',
#  'ReactSeq_MEO_245',
#  'ReactSeq_MEO_246',
#  'ReactSeq_MEO_247',
#  'ReactSeq_MEO_248',
#  'ReactSeq_MEO_249',
#  'ReactSeq_MEO_250',
#  'ReactSeq_MEO_251',
#  'ReactSeq_MEO_252',
#  'ReactSeq_MEO_253',
#  'ReactSeq_MEO_254',
#  'ReactSeq_MEO_255']

# %%
feature_col
# Out:
# ['ReactSeq_MEO_0',
#  'ReactSeq_MEO_1',
#  'ReactSeq_MEO_2',
#  'ReactSeq_MEO_3',
#  'ReactSeq_MEO_4',
#  'ReactSeq_MEO_5',
#  'ReactSeq_MEO_6',
#  'ReactSeq_MEO_7',
#  'ReactSeq_MEO_8',
#  'ReactSeq_MEO_9',
#  'ReactSeq_MEO_10',
#  'ReactSeq_MEO_11',
#  'ReactSeq_MEO_12',
#  'ReactSeq_MEO_13',
#  'ReactSeq_MEO_14',
#  'ReactSeq_MEO_15',
#  'ReactSeq_MEO_16',
#  'ReactSeq_MEO_17',
#  'ReactSeq_MEO_18',
#  'ReactSeq_MEO_19',
#  'ReactSeq_MEO_20',
#  'ReactSeq_MEO_21',
#  'ReactSeq_MEO_22',
#  'ReactSeq_MEO_23',
#  'ReactSeq_MEO_24',
#  'ReactSeq_MEO_25',
#  'ReactSeq_MEO_26',
#  'ReactSeq_MEO_27',
#  'ReactSeq_MEO_28',
#  'ReactSeq_MEO_29',
#  'ReactSeq_MEO_30',
#  'ReactSeq_MEO_31',
#  'ReactSeq_MEO_32',
#  'ReactSeq_MEO_33',
#  'ReactSeq_MEO_34',
#  'ReactSeq_MEO_35',
#  'ReactSeq_MEO_36',
#  'ReactSeq_MEO_37',
#  'ReactSeq_MEO_38',
#  'ReactSeq_MEO_39',
#  'ReactSeq_MEO_40',
#  'ReactSeq_MEO_41',
#  'ReactSeq_MEO_42',
#  'ReactSeq_MEO_43',
#  'ReactSeq_MEO_44',
#  'ReactSeq_MEO_45',
#  'ReactSeq_MEO_46',
#  'ReactSeq_MEO_47',
#  'ReactSeq_MEO_48',
#  'ReactSeq_MEO_49',
#  'ReactSeq_MEO_50',
#  'ReactSeq_MEO_51',
#  'ReactSeq_MEO_52',
#  'ReactSeq_MEO_53',
#  'ReactSeq_MEO_54',
#  'ReactSeq_MEO_55',
#  'ReactSeq_MEO_56',
#  'ReactSeq_MEO_57',
#  'ReactSeq_MEO_58',
#  'ReactSeq_MEO_59',
#  'ReactSeq_MEO_60',
#  'ReactSeq_MEO_61',
#  'ReactSeq_MEO_62',
#  'ReactSeq_MEO_63',
#  'ReactSeq_MEO_64',
#  'ReactSeq_MEO_65',
#  'ReactSeq_MEO_66',
#  'ReactSeq_MEO_67',
#  'ReactSeq_MEO_68',
#  'ReactSeq_MEO_69',
#  'ReactSeq_MEO_70',
#  'ReactSeq_MEO_71',
#  'ReactSeq_MEO_72',
#  'ReactSeq_MEO_73',
#  'ReactSeq_MEO_74',
#  'ReactSeq_MEO_75',
#  'ReactSeq_MEO_76',
#  'ReactSeq_MEO_77',
#  'ReactSeq_MEO_78',
#  'ReactSeq_MEO_79',
#  'ReactSeq_MEO_80',
#  'ReactSeq_MEO_81',
#  'ReactSeq_MEO_82',
#  'ReactSeq_MEO_83',
#  'ReactSeq_MEO_84',
#  'ReactSeq_MEO_85',
#  'ReactSeq_MEO_86',
#  'ReactSeq_MEO_87',
#  'ReactSeq_MEO_88',
#  'ReactSeq_MEO_89',
#  'ReactSeq_MEO_90',
#  'ReactSeq_MEO_91',
#  'ReactSeq_MEO_92',
#  'ReactSeq_MEO_93',
#  'ReactSeq_MEO_94',
#  'ReactSeq_MEO_95',
#  'ReactSeq_MEO_96',
#  'ReactSeq_MEO_97',
#  'ReactSeq_MEO_98',
#  'ReactSeq_MEO_99',
#  'ReactSeq_MEO_100',
#  'ReactSeq_MEO_101',
#  'ReactSeq_MEO_102',
#  'ReactSeq_MEO_103',
#  'ReactSeq_MEO_104',
#  'ReactSeq_MEO_105',
#  'ReactSeq_MEO_106',
#  'ReactSeq_MEO_107',
#  'ReactSeq_MEO_108',
#  'ReactSeq_MEO_109',
#  'ReactSeq_MEO_110',
#  'ReactSeq_MEO_111',
#  'ReactSeq_MEO_112',
#  'ReactSeq_MEO_113',
#  'ReactSeq_MEO_114',
#  'ReactSeq_MEO_115',
#  'ReactSeq_MEO_116',
#  'ReactSeq_MEO_117',
#  'ReactSeq_MEO_118',
#  'ReactSeq_MEO_119',
#  'ReactSeq_MEO_120',
#  'ReactSeq_MEO_121',
#  'ReactSeq_MEO_122',
#  'ReactSeq_MEO_123',
#  'ReactSeq_MEO_124',
#  'ReactSeq_MEO_125',
#  'ReactSeq_MEO_126',
#  'ReactSeq_MEO_127',
#  'ReactSeq_MEO_128',
#  'ReactSeq_MEO_129',
#  'ReactSeq_MEO_130',
#  'ReactSeq_MEO_131',
#  'ReactSeq_MEO_132',
#  'ReactSeq_MEO_133',
#  'ReactSeq_MEO_134',
#  'ReactSeq_MEO_135',
#  'ReactSeq_MEO_136',
#  'ReactSeq_MEO_137',
#  'ReactSeq_MEO_138',
#  'ReactSeq_MEO_139',
#  'ReactSeq_MEO_140',
#  'ReactSeq_MEO_141',
#  'ReactSeq_MEO_142',
#  'ReactSeq_MEO_143',
#  'ReactSeq_MEO_144',
#  'ReactSeq_MEO_145',
#  'ReactSeq_MEO_146',
#  'ReactSeq_MEO_147',
#  'ReactSeq_MEO_148',
#  'ReactSeq_MEO_149',
#  'ReactSeq_MEO_150',
#  'ReactSeq_MEO_151',
#  'ReactSeq_MEO_152',
#  'ReactSeq_MEO_153',
#  'ReactSeq_MEO_154',
#  'ReactSeq_MEO_155',
#  'ReactSeq_MEO_156',
#  'ReactSeq_MEO_157',
#  'ReactSeq_MEO_158',
#  'ReactSeq_MEO_159',
#  'ReactSeq_MEO_160',
#  'ReactSeq_MEO_161',
#  'ReactSeq_MEO_162',
#  'ReactSeq_MEO_163',
#  'ReactSeq_MEO_164',
#  'ReactSeq_MEO_165',
#  'ReactSeq_MEO_166',
#  'ReactSeq_MEO_167',
#  'ReactSeq_MEO_168',
#  'ReactSeq_MEO_169',
#  'ReactSeq_MEO_170',
#  'ReactSeq_MEO_171',
#  'ReactSeq_MEO_172',
#  'ReactSeq_MEO_173',
#  'ReactSeq_MEO_174',
#  'ReactSeq_MEO_175',
#  'ReactSeq_MEO_176',
#  'ReactSeq_MEO_177',
#  'ReactSeq_MEO_178',
#  'ReactSeq_MEO_179',
#  'ReactSeq_MEO_180',
#  'ReactSeq_MEO_181',
#  'ReactSeq_MEO_182',
#  'ReactSeq_MEO_183',
#  'ReactSeq_MEO_184',
#  'ReactSeq_MEO_185',
#  'ReactSeq_MEO_186',
#  'ReactSeq_MEO_187',
#  'ReactSeq_MEO_188',
#  'ReactSeq_MEO_189',
#  'ReactSeq_MEO_190',
#  'ReactSeq_MEO_191',
#  'ReactSeq_MEO_192',
#  'ReactSeq_MEO_193',
#  'ReactSeq_MEO_194',
#  'ReactSeq_MEO_195',
#  'ReactSeq_MEO_196',
#  'ReactSeq_MEO_197',
#  'ReactSeq_MEO_198',
#  'ReactSeq_MEO_199',
#  'ReactSeq_MEO_200',
#  'ReactSeq_MEO_201',
#  'ReactSeq_MEO_202',
#  'ReactSeq_MEO_203',
#  'ReactSeq_MEO_204',
#  'ReactSeq_MEO_205',
#  'ReactSeq_MEO_206',
#  'ReactSeq_MEO_207',
#  'ReactSeq_MEO_208',
#  'ReactSeq_MEO_209',
#  'ReactSeq_MEO_210',
#  'ReactSeq_MEO_211',
#  'ReactSeq_MEO_212',
#  'ReactSeq_MEO_213',
#  'ReactSeq_MEO_214',
#  'ReactSeq_MEO_215',
#  'ReactSeq_MEO_216',
#  'ReactSeq_MEO_217',
#  'ReactSeq_MEO_218',
#  'ReactSeq_MEO_219',
#  'ReactSeq_MEO_220',
#  'ReactSeq_MEO_221',
#  'ReactSeq_MEO_222',
#  'ReactSeq_MEO_223',
#  'ReactSeq_MEO_224',
#  'ReactSeq_MEO_225',
#  'ReactSeq_MEO_226',
#  'ReactSeq_MEO_227',
#  'ReactSeq_MEO_228',
#  'ReactSeq_MEO_229',
#  'ReactSeq_MEO_230',
#  'ReactSeq_MEO_231',
#  'ReactSeq_MEO_232',
#  'ReactSeq_MEO_233',
#  'ReactSeq_MEO_234',
#  'ReactSeq_MEO_235',
#  'ReactSeq_MEO_236',
#  'ReactSeq_MEO_237',
#  'ReactSeq_MEO_238',
#  'ReactSeq_MEO_239',
#  'ReactSeq_MEO_240',
#  'ReactSeq_MEO_241',
#  'ReactSeq_MEO_242',
#  'ReactSeq_MEO_243',
#  'ReactSeq_MEO_244',
#  'ReactSeq_MEO_245',
#  'ReactSeq_MEO_246',
#  'ReactSeq_MEO_247',
#  'ReactSeq_MEO_248',
#  'ReactSeq_MEO_249',
#  'ReactSeq_MEO_250',
#  'ReactSeq_MEO_251',
#  'ReactSeq_MEO_252',
#  'ReactSeq_MEO_253',
#  'ReactSeq_MEO_254',
#  'ReactSeq_MEO_255']

# %%
len(feature_col)
# Out:
# 256

# %%
X = df_cat[feature_col]

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Lists to store the results
rmse_list = []
r2_list = []

for seed in range(30):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    model = RandomForestRegressor(n_estimators=100, random_state=seed)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmse_list.append(rmse)
    r2_list.append(r2)
    
    print(f'Seed {seed} -> RMSE: {rmse}, R²: {r2}')

average_rmse = np.mean(rmse_list)
average_r2 = np.mean(r2_list)

std_rmse = np.std(rmse_list)
std_r2 = np.std(r2_list)


print(f'\nR²_mean: {average_r2}')
print(f'R²_sd: {std_r2}')

print(f'RMSE_mean: {average_rmse}')
print(f'RMSE_sd: {std_rmse}')
# Out:
# Seed 0 -> RMSE: 25.321039624321205, R²: 0.2575555545454472
# Seed 1 -> RMSE: 23.34571692270007, R²: 0.3303130920753957
# Seed 2 -> RMSE: 25.55289712943633, R²: 0.2649074794909725
# Seed 3 -> RMSE: 25.705387264205925, R²: 0.19780405383072774
# Seed 4 -> RMSE: 27.96171481314088, R²: 0.20482113022121828
# Seed 5 -> RMSE: 25.533884748843054, R²: 0.2045738564118933
# Seed 6 -> RMSE: 23.599001485678723, R²: 0.30761255941162424
# Seed 7 -> RMSE: 24.848862608149023, R²: 0.22894129317542922
# Seed 8 -> RMSE: 24.835300443113898, R²: 0.21893099847781505
# Seed 9 -> RMSE: 24.752554865700453, R²: 0.21905765353223294
# Seed 10 -> RMSE: 25.653510590611617, R²: 0.21029428930045568
# Seed 11 -> RMSE: 27.452240278361415, R²: 0.18003191545344066
# Seed 12 -> RMSE: 25.647163674225048, R²: 0.22745438724367217
# Seed 13 -> RMSE: 27.27039627622354, R²: 0.19400860347851767
# Seed 14 -> RMSE: 27.05102612854537, R²: 0.15699657758417063
# Seed 15 -> RMSE: 24.85180458214118, R²: 0.2505949390223763
# Seed 16 -> RMSE: 25.14980143149356, R²: 0.2922433147280932
# Seed 17 -> RMSE: 26.404867893689605, R²: 0.22226357004857367
# Seed 18 -> RMSE: 25.5785387950159, R²: 0.2602348698094239
# Seed 19 -> RMSE: 24.471258457389467, R²: 0.27296261642878217
# Seed 20 -> RMSE: 27.165144511710835, R²: 0.24143995472292357
# Seed 21 -> RMSE: 25.176443271066795, R²: 0.21719762893444527
# Seed 22 -> RMSE: 24.39228771351397, R²: 0.28305732108550474
# Seed 23 -> RMSE: 25.95171567785495, R²: 0.22383167448379593
# Seed 24 -> RMSE: 27.24537616985067, R²: 0.1699452524427445
# Seed 25 -> RMSE: 26.412912978683572, R²: 0.2661919472498552
# Seed 26 -> RMSE: 26.244457633302737, R²: 0.2151698405313046
# Seed 27 -> RMSE: 24.5194830585702, R²: 0.2671864990703128
# Seed 28 -> RMSE: 26.580187554775957, R²: 0.25503139218588533
# Seed 29 -> RMSE: 24.783363872338057, R²: 0.2723943958000866
#
# R²_mean: 0.23710162202590404
# R²_sd: 0.03993215304558885
# RMSE_mean: 25.64861134848848
# RMSE_sd: 1.1308046829098617
